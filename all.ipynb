# %%
import pyEX
c = pyEX.Client()
# c = pyEX.Client(version='sandbox')

# %% [markdown]
# # Symbols data

# %%
c.symbolsDF().head()
# Out:
#        currency       date exchange                 iexId  isEnabled  \
# symbol
# A           SUD 2019-05-03      YSN  IEX_46574843354B2D52       True
# AA          DSU 2019-05-03      NSY  IEX_4238333734532D52       True
# AAAU        SDU 2019-05-03      EPS  IEX_474B433136332D52       True
# AABA        USD 2019-05-03      SNA  IEX_4E5434354A302D52       True
# AAC         DUS 2019-05-03      SNY  IEX_4843364642592D52       True
#
#                                 name region type
# symbol
# A          o.gci  eilhIgcoeTlnstenAn     SU   cs
# AA                       poacrCol .A     SU   sc
# AAAU    c s PtaoilEeFdlGrTynMi htP h     US   te
# AABA                      AItc.nabal     SU  ecf
# AAC                n.Ins AAliogd cHC     SU   sc

# %% [markdown]
# ## Symbols

# %%
c.symbols()[:5]
# Out:
# [{'symbol': 'A',
#   'exchange': 'SNY',
#   'name': ' c.iTglo ncngosteeneAhliI',
#   'date': '2019-05-03',
#   'type': 'sc',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'DUS',
#   'isEnabled': True},
#  {'symbol': 'AA',
#   'exchange': 'SYN',
#   'name': 'ra.cC pAolo',
#   'date': '2019-05-03',
#   'type': 'sc',
#   'iexId': 'IEX_4238333734532D52',
#   'region': 'US',
#   'currency': 'DUS',
#   'isEnabled': True},
#  {'symbol': 'AAAU',
#   'exchange': 'PES',
#   'name': 'statE hceGr TFldyil o hiPnPM',
#   'date': '2019-05-03',
#   'type': 'te',
#   'iexId': 'IEX_474B433136332D52',
#   'region': 'SU',
#   'currency': 'UDS',
#   'isEnabled': True},
#  {'symbol': 'AABA',
#   'exchange': 'NAS',
#   'name': 'IAl tncba.a',
#   'date': '2019-05-03',
#   'type': 'cfe',
#   'iexId': 'IEX_4E5434354A302D52',
#   'region': 'SU',
#   'currency': 'SDU',
#   'isEnabled': True},
#  {'symbol': 'AAC',
#   'exchange': 'SNY',
#   'name': 'AnAisdg l Ccn.oIH',
#   'date': '2019-05-03',
#   'type': 'sc',
#   'iexId': 'IEX_4843364642592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True}]

# %%
c.symbolsDF().head()
# Out:
#        currency       date exchange                 iexId  isEnabled  \
# symbol
# A           DSU 2019-05-03      YNS  IEX_46574843354B2D52       True
# AA          SUD 2019-05-03      YNS  IEX_4238333734532D52       True
# AAAU        USD 2019-05-03      SPE  IEX_474B433136332D52       True
# AABA        SDU 2019-05-03      SNA  IEX_4E5434354A302D52       True
# AAC         DUS 2019-05-03      NYS  IEX_4843364642592D52       True
#
#                                 name region type
# symbol
# A          .TAt  ingegIoencioclnhels     US   sc
# AA                       oA.apocrl C     SU   cs
# AAAU    ihFcyirn Plt TehaEo sGl dtMP     SU   et
# AABA                     abIAlnact .     US  fec
# AAC                i .gncAo CIdAHnls     SU   sc

# %%
c.symbolsList()[:5]
# Out:
# ['A', 'AA', 'AAAU', 'AABA', 'AAC']

# %% [markdown]
# ## IEX Symbols

# %%
c.iexSymbols()[:5]
# Out:
# [{'symbol': 'A', 'date': '2019-05-03', 'isEnabled': True},
#  {'symbol': 'AA', 'date': '2019-05-03', 'isEnabled': True},
#  {'symbol': 'AAAU', 'date': '2019-05-03', 'isEnabled': True},
#  {'symbol': 'AABA', 'date': '2019-05-03', 'isEnabled': True},
#  {'symbol': 'AAC', 'date': '2019-05-03', 'isEnabled': True}]

# %%
c.iexSymbolsDF().head()
# Out:
#              date  isEnabled
# symbol
# A      2019-05-03       True
# AA     2019-05-03       True
# AAAU   2019-05-03       True
# AABA   2019-05-03       True
# AAC    2019-05-03       True

# %%
c.iexSymbolsList()[:10]
# Out:
# ['A', 'AA', 'AAAU', 'AABA', 'AAC', 'AADR', 'AAL', 'AAMC', 'AAME', 'AAN']

# %% [markdown]
# ## International Symbols

# %%
c.internationalSymbols()[:5]
# Out:
# [{'symbol': 'A',
#   'exchange': 'SNY',
#   'name': 's cintl.ln TAhcgneeeioIgo',
#   'date': '2019-05-03',
#   'type': 'sc',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'DSU',
#   'isEnabled': True},
#  {'symbol': 'AA',
#   'exchange': 'YNS',
#   'name': 'CrcAlop. ao',
#   'date': '2019-05-03',
#   'type': 'cs',
#   'iexId': 'IEX_4238333734532D52',
#   'region': 'US',
#   'currency': 'SUD',
#   'isEnabled': True},
#  {'symbol': 'AAAAX',
#   'exchange': 'ANS',
#   'name': 'iStto velinosd eCt ass tAFlnAaADuWsAr cl lnae',
#   'date': '2019-05-03',
#   'type': 'ofe',
#   'iexId': 'IEX_4258444437432D52',
#   'region': 'US',
#   'currency': 'DSU',
#   'isEnabled': True},
#  {'symbol': 'AAADX',
#   'exchange': 'NAS',
#   'name': 'mnCdAudcFd enlueeseaolbie s rr AIB  -n',
#   'date': '2019-05-03',
#   'type': 'efo',
#   'iexId': 'IEX_5153364A51302D52',
#   'region': 'US',
#   'currency': 'DUS',
#   'isEnabled': True},
#  {'symbol': 'AAAG',
#   'exchange': 'OTC',
#   'name': 'AnS rtU yonec.A puCIGrAA u',
#   'date': '2019-05-03',
#   'type': 'cs',
#   'iexId': 'IEX_4A534652444A2D52',
#   'region': 'SU',
#   'currency': 'SUD',
#   'isEnabled': True}]

# %%
c.internationalSymbolsDF().head()
# Out:
#        currency       date exchange                 iexId  isEnabled  \
# symbol
# A           SUD 2019-05-03      YSN  IEX_46574843354B2D52       True
# AA          SDU 2019-05-03      YSN  IEX_4238333734532D52       True
# AAAAX       DUS 2019-05-03      SNA  IEX_4258444437432D52       True
# AAADX       SDU 2019-05-03      NSA  IEX_5153364A51302D52       True
# AAAG        SDU 2019-05-03      OTC  IEX_4A534652444A2D52       True
#
#                                                  name region type
# symbol
# A                           n.geo eIii nlhoegcncTlAts     US   sc
# AA                                        o.lApoaCrc      US   sc
# AAAAX   A ssSierldCnlWtte s etvalono F lDa AstnAuAica     US  foe
# AAADX          mobnu ds esel -dAnee Irc CrdAenua liFB     US  ofe
# AAAG                        GtAu nAuyUAerACc Sor.n Ip     SU   cs

# %%
c.internationalSymbolsList()[:5]
# Out:
# ['A', 'AA', 'AAAAX', 'AAADX', 'AAAG']

# %% [markdown]
# ## FX Symbols

# %%
c.fxSymbols()
# Out:
# {'currencies': [{'code': 'ERU', 'name': 'urEo'},
#   {'code': 'DUS', 'name': 'raSlD.olU. '},
#   {'code': 'PBG', 'name': 'tsoidriBPn uh'},
#   {'code': 'DAU', 'name': 'uarAsniralDlotla '},
#   {'code': 'PJY', 'name': 'YeeaeJnsanp '},
#   {'code': 'CYN', 'name': 'Yubs hnie ieennRmCani'},
#   {'code': 'DAC', 'name': 'CDnaaarlnoaid l'},
#   {'code': 'HCF', 'name': 'cF irwsSasn'},
#   {'code': 'RSA', 'name': 'nstieeenr goPA'},
#   {'code': 'BNG', 'name': 'aigueBvnal Lr'},
#   {'code': 'LRB', 'name': 'naRlilie aBzar'},
#   {'code': 'LCP', 'name': 'ahi eolPeCsn'},
#   {'code': 'OPC', 'name': 'sClibmon oPeao'},
#   {'code': 'CKZ', 'name': 'ronuKCeczha '},
#   {'code': 'DKK', 'name': 'onDiKe rnahs'},
#   {'code': 'DHK', 'name': 'lgl  nroDHgaKnoo'},
#   {'code': 'HFU', 'name': 'anHiFra rtngniuo'},
#   {'code': 'RID', 'name': 'uRsa dapniIeniohn'},
#   {'code': 'SLI', 'name': 'hsle ialrINSewe ke'},
#   {'code': 'IRN', 'name': 'ae nudInipeR'},
#   {'code': 'KRW', 'name': 'WnnKoo era'},
#   {'code': 'KZT', 'name': 'kzaae entnKhsTag'},
#   {'code': 'XMN', 'name': 'PxicseaMnoe '},
#   {'code': 'RMY', 'name': 'lMniyiggaitRs aan'},
#   {'code': 'NKO', 'name': 'gornwnNie aoerK'},
#   {'code': 'NZD', 'name': 'wn ralN leladeZoaD'},
#   {'code': 'NPE', 'name': 'ev Nrnlevuo oaPuiS'},
#   {'code': 'PHP', 'name': 'Pe enhiilsoPppi'},
#   {'code': 'PNL', 'name': ' hZlotlioysP'},
#   {'code': 'NOR', 'name': ' niumaRnLaeo'},
#   {'code': 'URB', 'name': 'n uliRasRbsue'},
#   {'code': 'KES', 'name': 'Seosharwn dKi'},
#   {'code': 'DGS', 'name': 'r oDaaiporlngeSl'},
#   {'code': 'HBT', 'name': ' ihtaahBT'},
#   {'code': 'TRY', 'name': 'Tsukai irhrL'},
#   {'code': 'WTD', 'name': 'oTDwa rlilnaa'},
#   {'code': 'UHA', 'name': ' kraHrnynvUnaaii'},
#   {'code': 'VND', 'name': 'tgnVemsD neoiae'},
#   {'code': 'RAZ', 'name': 'naiuArthod S cfnaR'},
#   {'code': 'RKH', 'name': ' atCiunoarnaK'},
#   {'code': 'DRS', 'name': 'r iirDaSbnean'}],
#  'pairs': [{'fromCurrency': 'REU', 'toCurrency': 'USD'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'UER'},
#   {'fromCurrency': 'BGP', 'toCurrency': 'DUS'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'BGP'},
#   {'fromCurrency': 'DUA', 'toCurrency': 'USD'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'AUD'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'YPJ'},
#   {'fromCurrency': 'YPJ', 'toCurrency': 'USD'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'NCY'},
#   {'fromCurrency': 'CNY', 'toCurrency': 'SDU'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'CDA'},
#   {'fromCurrency': 'ADC', 'toCurrency': 'USD'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'HFC'},
#   {'fromCurrency': 'CFH', 'toCurrency': 'SDU'},
#   {'fromCurrency': 'REU', 'toCurrency': 'BPG'},
#   {'fromCurrency': 'GPB', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'URE', 'toCurrency': 'HCF'},
#   {'fromCurrency': 'FCH', 'toCurrency': 'RUE'},
#   {'fromCurrency': 'UER', 'toCurrency': 'PYJ'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'SRA'},
#   {'fromCurrency': 'SRA', 'toCurrency': 'DUS'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'BGN'},
#   {'fromCurrency': 'BNG', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'BRL'},
#   {'fromCurrency': 'BLR', 'toCurrency': 'UDS'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'PLC'},
#   {'fromCurrency': 'PLC', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'PCO'},
#   {'fromCurrency': 'POC', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'ZKC'},
#   {'fromCurrency': 'KCZ', 'toCurrency': 'UDS'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'KKD'},
#   {'fromCurrency': 'KKD', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'HDK'},
#   {'fromCurrency': 'KDH', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'FHU'},
#   {'fromCurrency': 'FHU', 'toCurrency': 'USD'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'DRI'},
#   {'fromCurrency': 'RID', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'ILS'},
#   {'fromCurrency': 'ILS', 'toCurrency': 'SUD'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'NIR'},
#   {'fromCurrency': 'RNI', 'toCurrency': 'DUS'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'WRK'},
#   {'fromCurrency': 'KWR', 'toCurrency': 'USD'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'TZK'},
#   {'fromCurrency': 'ZKT', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'NXM'},
#   {'fromCurrency': 'NMX', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'YRM'},
#   {'fromCurrency': 'RMY', 'toCurrency': 'SDU'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'NKO'},
#   {'fromCurrency': 'KON', 'toCurrency': 'SUD'},
#   {'fromCurrency': 'NZD', 'toCurrency': 'DUS'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'DNZ'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'PNE'},
#   {'fromCurrency': 'PEN', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'HPP'},
#   {'fromCurrency': 'PHP', 'toCurrency': 'SUD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'LNP'},
#   {'fromCurrency': 'LNP', 'toCurrency': 'DUS'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'NRO'},
#   {'fromCurrency': 'ONR', 'toCurrency': 'USD'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'BRU'},
#   {'fromCurrency': 'URB', 'toCurrency': 'DUS'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'ESK'},
#   {'fromCurrency': 'EKS', 'toCurrency': 'DUS'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'GSD'},
#   {'fromCurrency': 'DGS', 'toCurrency': 'DSU'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'HTB'},
#   {'fromCurrency': 'BTH', 'toCurrency': 'SUD'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'TRY'},
#   {'fromCurrency': 'TYR', 'toCurrency': 'SDU'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'DWT'},
#   {'fromCurrency': 'DWT', 'toCurrency': 'USD'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'AUH'},
#   {'fromCurrency': 'AHU', 'toCurrency': 'UDS'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'DVN'},
#   {'fromCurrency': 'DVN', 'toCurrency': 'SDU'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'AZR'},
#   {'fromCurrency': 'ARZ', 'toCurrency': 'DUS'},
#   {'fromCurrency': 'ERU', 'toCurrency': 'AUD'},
#   {'fromCurrency': 'DUA', 'toCurrency': 'UER'},
#   {'fromCurrency': 'URE', 'toCurrency': 'BNG'},
#   {'fromCurrency': 'BGN', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'UER', 'toCurrency': 'ACD'},
#   {'fromCurrency': 'CAD', 'toCurrency': 'RUE'},
#   {'fromCurrency': 'UER', 'toCurrency': 'CYN'},
#   {'fromCurrency': 'NYC', 'toCurrency': 'UER'},
#   {'fromCurrency': 'UER', 'toCurrency': 'CZK'},
#   {'fromCurrency': 'CKZ', 'toCurrency': 'RUE'},
#   {'fromCurrency': 'REU', 'toCurrency': 'DKK'},
#   {'fromCurrency': 'KKD', 'toCurrency': 'URE'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'KHR'},
#   {'fromCurrency': 'KRH', 'toCurrency': 'UER'},
#   {'fromCurrency': 'RUE', 'toCurrency': 'HUF'},
#   {'fromCurrency': 'HFU', 'toCurrency': 'ERU'},
#   {'fromCurrency': 'RUE', 'toCurrency': 'INR'},
#   {'fromCurrency': 'RNI', 'toCurrency': 'REU'},
#   {'fromCurrency': 'RUE', 'toCurrency': 'WRK'},
#   {'fromCurrency': 'WRK', 'toCurrency': 'UER'},
#   {'fromCurrency': 'RUE', 'toCurrency': 'KTZ'},
#   {'fromCurrency': 'ZKT', 'toCurrency': 'RUE'},
#   {'fromCurrency': 'REU', 'toCurrency': 'NKO'},
#   {'fromCurrency': 'NKO', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'ERU', 'toCurrency': 'DNZ'},
#   {'fromCurrency': 'DNZ', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'ERU', 'toCurrency': 'PNL'},
#   {'fromCurrency': 'PNL', 'toCurrency': 'UER'},
#   {'fromCurrency': 'ERU', 'toCurrency': 'RNO'},
#   {'fromCurrency': 'RNO', 'toCurrency': 'URE'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'DSR'},
#   {'fromCurrency': 'RDS', 'toCurrency': 'RUE'},
#   {'fromCurrency': 'RUE', 'toCurrency': 'UBR'},
#   {'fromCurrency': 'URB', 'toCurrency': 'UER'},
#   {'fromCurrency': 'ERU', 'toCurrency': 'ESK'},
#   {'fromCurrency': 'KES', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'URE', 'toCurrency': 'YRT'},
#   {'fromCurrency': 'YTR', 'toCurrency': 'RUE'},
#   {'fromCurrency': 'REU', 'toCurrency': 'UHA'},
#   {'fromCurrency': 'HUA', 'toCurrency': 'REU'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'ZAR'},
#   {'fromCurrency': 'RAZ', 'toCurrency': 'RUE'},
#   {'fromCurrency': 'CDA', 'toCurrency': 'YJP'},
#   {'fromCurrency': 'PJY', 'toCurrency': 'DAC'},
#   {'fromCurrency': 'CHF', 'toCurrency': 'JYP'},
#   {'fromCurrency': 'YPJ', 'toCurrency': 'HFC'},
#   {'fromCurrency': 'NDZ', 'toCurrency': 'YJP'},
#   {'fromCurrency': 'YJP', 'toCurrency': 'NDZ'},
#   {'fromCurrency': 'KON', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'KNO'},
#   {'fromCurrency': 'ARZ', 'toCurrency': 'YJP'},
#   {'fromCurrency': 'PJY', 'toCurrency': 'RZA'},
#   {'fromCurrency': 'BPG', 'toCurrency': 'DAU'},
#   {'fromCurrency': 'AUD', 'toCurrency': 'BGP'},
#   {'fromCurrency': 'BPG', 'toCurrency': 'FHC'},
#   {'fromCurrency': 'HFC', 'toCurrency': 'GPB'},
#   {'fromCurrency': 'AUD', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JYP', 'toCurrency': 'DUA'},
#   {'fromCurrency': 'UDA', 'toCurrency': 'ADC'},
#   {'fromCurrency': 'CDA', 'toCurrency': 'DUA'}]}

# %%
dfs = c.fxSymbolsDF()
dfs[0].head()
# Out:
#                    name
# code
# UER                uroE
# DUS         o.Ur allDS.
# GBP       nuiosdBiP trh
# UDA   DaaolAnitrrlua sl
# JYP        esann eYJaep

# %%
dfs[1].head()
# Out:
#   fromCurrency toCurrency
# 0          RUE        DUS
# 1          SDU        EUR
# 2          PBG        UDS
# 3          DSU        BGP
# 4          DAU        UDS

# %%
l = c.fxSymbolsList()
l[0][:5]
# Out:
# ['REU', 'SDU', 'GBP', 'UAD', 'PJY']

# %%
l[1][:5]
# Out:
# ['RUESDU', 'DSUERU', 'PGBDSU', 'UDSPBG', 'UDADSU']

# %% [markdown]
# ## Options Symbols

# %%
d = c.optionsSymbols()
list(d.keys())[:5]
# Out:
# ['FLIC', 'TMQ-CT', 'GHM', 'MAS', 'HOMB']

# %%
c.optionsSymbolsDF().head()
# Out:
#                                             expirations
# A      [210055, 204967, 202159, 204819, 202489, 203238]
# AA     [211996, 202857, 207774, 205620, 210698, 210695]
# AABA   [204338, 210289, 205198, 203980, 210902, 206466]
# AAC                    [205223, 204221, 204051, 203337]
# AAL   [205676, 211797, 203656, 206775, 208305, 20406...

# %%
c.optionsSymbolsList()[:5]
# Out:
# ['A', 'AA', 'AABA', 'AAC', 'AAL']

# %% [markdown]
# ## International Exchanges

# %%
c.internationalExchanges()[:5]
# Out:
# [{'exchange': 'ASD',
#   'region': 'AE',
#   'description': 'uageSucsDenAeab  bihriEc xtih',
#   'mic': 'ASDX',
#   'exchangeSuffix': 'HD-'},
#  {'exchange': 'RUB',
#   'region': 'BE',
#   'description': 'oBsesnrulErs uext',
#   'mic': 'BXRU',
#   'exchangeSuffix': 'B-B'},
#  {'exchange': 'TRE',
#   'region': 'DE',
#   'description': 'TREAX',
#   'mic': 'ERXT',
#   'exchangeSuffix': 'Y-G'},
#  {'exchange': 'APR',
#   'region': 'FR',
#   'description': 'xiou netasErPr',
#   'mic': 'XPRA',
#   'exchangeSuffix': 'F-P'},
#  {'exchange': 'LNO',
#   'region': 'GB',
#   'description': 'dn SnehtokcgL canoxEo',
#   'mic': 'LNOX',
#   'exchangeSuffix': 'NL-'}]

# %%
c.internationalExchangesDF().head()
# Out:
#                      description exchange exchangeSuffix   mic region
# 0  bAtxDcuiceneaeir Eubg ahs hSi      DAS            H-D  SXDA     AE
# 1               nsroueslEerBxtus      UBR            B-B  BRXU     EB
# 2                          XATRE      ETR            YG-  RETX     ED
# 3                 exioutsrnaPrE       RPA            FP-  ARPX     RF
# 4           LcdoocngeoS xkntnEah      LON            NL-  XONL     BG

# %% [markdown]
# ## US Exchanges

# %%
c.exchanges()[:5]
# Out:
# [{'mic': 'XARC',
#   'name': 'aSAE rYcN',
#   'longName': 'RNAAYEC S',
#   'tapeId': 'P',
#   'oatsId': 'PX',
#   'type': 'itequise'},
#  {'mic': 'EDGX',
#   'name': ' GoXbDCeE',
#   'longName': 'EcgUX  CnGeubaxes hEDiEqoSeti ',
#   'tapeId': 'K',
#   'oatsId': 'KX',
#   'type': 'qiteeusi'},
#  {'mic': 'BSTA',
#   'name': 'B CZXboe',
#   'longName': 'Xi xbZesEiBnCoege taqS  UcuEh',
#   'tapeId': 'Z',
#   'oatsId': 'ZX',
#   'type': 'usqteiie'},
#  {'mic': 'TBAY',
#   'name': 'YoXCe bB',
#   'longName': 'uEabeE nisYiCU o eeShq cgtBxX',
#   'tapeId': 'Y',
#   'oatsId': 'YX',
#   'type': 'eisetiqu'},
#  {'mic': 'AEGD',
#   'name': 'EGoCA bDe',
#   'longName': 'qboe iuDanU hAtCEGEsxc SegieE ',
#   'tapeId': 'J',
#   'oatsId': 'JX',
#   'type': 'stiquiee'}]

# %%
c.exchangesDF().head()
# Out:
#                          longName   mic       name oatsId tapeId      type
# 0                       RANEA YCS  CRXA  cN aAErYS     XP      P  ieitques
# 1  xGtECSnbq EE  iegeDUiaoX hcues  XDGE  eDCEbo XG     XK      K  ituseqie
# 2   oEeix UShis CZuXE gneqcteBb a  TSAB   BZo CXeb     XZ      Z  ieuqtesi
# 3   eciCUonegubqhsB Y  SXEteEiax   ABTY    BoCeXYb     XY      Y  iqsietue
# 4  U i tCeAcqD geSeonxbhGu sEEaiE  GDAE  ACeGDo Eb     XJ      J  uieiqste

# %% [markdown]
# ## US Holidays

# %%
c.holidays()[:5]
# Out:
# [{'date': '2019-05-27', 'settlementDate': '2019-06-12'}]

# %%
c.holidaysDF().head()
# Out:
#         date settlementDate
# 0 2019-05-27     2019-06-10

# %% [markdown]
# ## Sectors

# %%
c.sectors()[:5]
# Out:
# [{'name': 'Electronic Technology'},
#  {'name': 'Distribution Services'},
#  {'name': 'Health Technology'},
#  {'name': 'Commercial Services'},
#  {'name': 'Industrial Services'}]

# %%
c.sectorsDF().head()
# Out:
#                     name
# 0  Electronic Technology
# 1  Distribution Services
# 2      Health Technology
# 3    Commercial Services
# 4    Industrial Services

# %% [markdown]
# ## Tags

# %%
c.tags()[:5]
# Out:
# [{'name': 'Electronic Technology'},
#  {'name': 'Distribution Services'},
#  {'name': 'Commercial Services'},
#  {'name': 'Health Technology'},
#  {'name': 'Industrial Services'}]

# %%
c.tagsDF().head()
# Out:
#                     name
# 0  Electronic Technology
# 1  Distribution Services
# 2    Commercial Services
# 3      Health Technology
# 4    Industrial Services

# %% [markdown]
# # Stock API

# %%
symbol = 'AAPL'

# %% [markdown]
# ## Advanced Stats

# %%
c.advancedStats(symbol)
# Out:
# {'week52change': 0.188461,
#  'week52high': 242.38,
#  'week52low': 147,
#  'marketcap': 979493595511,
#  'employees': 132023,
#  'day200MovingAvg': 194.51,
#  'day50MovingAvg': 195.99,
#  'float': 4754161798,
#  'avg10Volume': 29304618,
#  'avg30Volume': 29979899.5,
#  'ttmEPS': 12.58,
#  'ttmDividendRate': 2.95,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 4733109013,
#  'maxChangePercent': 210.849374,
#  'year5ChangePercent': 1.45729,
#  'year2ChangePercent': 0.438134,
#  'year1ChangePercent': 0.18589,
#  'ytdChangePercent': 0.32573,
#  'month6ChangePercent': 0.039145,
#  'month3ChangePercent': 0.230061,
#  'month1ChangePercent': 0.074097,
#  'day30ChangePercent': 0.073023,
#  'day5ChangePercent': 0.02435,
#  'nextDividendDate': '2019-05-13',
#  'dividendYield': 0.01452950177380037,
#  'nextEarningsDate': '2019-07-23',
#  'exDividendDate': '2019-05-17',
#  'peRatio': 17.94,
#  'beta': 1.4854567495528428,
#  'totalCash': 66638120989,
#  'currentDebt': 20750696664,
#  'revenue': 275527677275,
#  'grossProfit': 105181807932,
#  'totalRevenue': 275504985907,
#  'EBITDA': 84096174623,
#  'revenuePerShare': 0.02,
#  'revenuePerEmployee': 2014017.6,
#  'debtToEquity': 1.09,
#  'profitMargin': 0.2307192848264941,
#  'enterpriseValue': 1016031253401,
#  'enterpriseValueToRevenue': 3.79,
#  'priceToSales': 3.8,
#  'priceToBook': 9.348532512082068,
#  'forwardPERatio': 18.32,
#  'pegRatio': 2.23}

# %%
c.advancedStatsDF(symbol)
# Out:
#         EBITDA  avg10Volume  avg30Volume      beta  companyName  currentDebt  \
# 0  82227369167     29997425   28993715.9  1.503468  Apple, Inc.  20920901897
#
#    day200MovingAvg  day30ChangePercent  day50MovingAvg  day5ChangePercent  \
# 0            195.2            0.073641          194.73            0.02393
#
#    ...  totalRevenue  ttmDividendRate  ttmEPS  week52change  week52high  \
# 0  ...  271759481804             2.96    12.3      0.187849      237.03
#
#   week52low  year1ChangePercent  year2ChangePercent  year5ChangePercent  \
# 0       148            0.188065            0.427266            1.493113
#
#    ytdChangePercent
# 0          0.324916
#
# [1 rows x 46 columns]

# %% [markdown]
# ## Balance Sheet

# %%
c.balanceSheet(symbol)
# Out:
# {'symbol': 'AAPL',
#  'balancesheet': [{'reportDate': '2019-04-07',
#    'currentCash': 38437023279,
#    'shortTermInvestments': 42660982840,
#    'receivables': 15563032484,
#    'inventory': 5026936927,
#    'otherCurrentAssets': 11945091450,
#    'currentAssets': 125592246144,
#    'longTermInvestments': 149844565800,
#    'propertyPlantEquipment': 40432425552,
#    'goodwill': 0,
#    'intangibleAssets': None,
#    'otherAssets': 33532185317,
#    'totalAssets': 357632376466,
#    'accountsPayable': 31744675676,
#    'currentLongTermDebt': 10997385683,
#    'otherCurrentLiabilities': 41234725956,
#    'totalCurrentLiabilities': 94896857710,
#    'longTermDebt': 91793929944,
#    'otherLiabilities': 6447850811,
#    'minorityInterest': 0,
#    'totalLiabilities': 246351882974,
#    'commonStock': 42837663306,
#    'retainedEarnings': 65133504641,
#    'treasuryStock': None,
#    'capitalSurplus': None,
#    'shareholderEquity': 108850300770,
#    'netTangibleAssets': 110462493708}]}

# %%
c.balanceSheetDF(symbol)
# Out:
#             accountsPayable capitalSurplus  commonStock  currentAssets  \
# reportDate
# 2019-04-04      30549653773           None  43751129593   126053856196
#
#             currentCash  currentLongTermDebt  goodwill intangibleAssets  \
# reportDate
# 2019-04-04  39948530279          10654527543         0             None
#
#              inventory  longTermDebt  ...  propertyPlantEquipment  \
# reportDate                            ...
# 2019-04-04  4997216729   93284280546  ...             40648811030
#
#             receivables  retainedEarnings  shareholderEquity  \
# reportDate
# 2019-04-04  15386448340       67512486340       108938775839
#
#             shortTermInvestments   totalAssets  totalCurrentLiabilities  \
# reportDate
# 2019-04-04           43580524279  355062001972              96642091852
#
#             totalLiabilities  treasuryStock  symbol
# reportDate
# 2019-04-04      237883084859           None    AAPL
#
# [1 rows x 27 columns]

# %% [markdown]
# ## Book

# %%
c.book(symbol)
# Out:
# {'quote': {'symbol': 'AAPL',
#   'companyName': 'Apple, Inc.',
#   'calculationPrice': 'tops',
#   'open': 213.69,
#   'openTime': 1564510131620,
#   'close': 218.9,
#   'closeTime': 1583970306448,
#   'high': 217.3,
#   'low': 211.89,
#   'latestPrice': 212.253,
#   'latestSource': 'IEX real time price',
#   'latestTime': '2:34:33 PM',
#   'latestUpdate': 1609600407252,
#   'latestVolume': 14500916,
#   'iexRealtimePrice': 213.977,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1568324285032,
#   'delayedPrice': 214.73,
#   'delayedPriceTime': 1608797267144,
#   'extendedPrice': 213.56,
#   'extendedChange': -0.489,
#   'extendedChangePercent': -0.00234,
#   'extendedPriceTime': 1579311443640,
#   'previousClose': 218.13,
#   'change': 1.971,
#   'changePercent': 0.0096,
#   'iexMarketPercent': 0.03407876579735806,
#   'iexVolume': 472726,
#   'avgTotalVolume': 29335282,
#   'iexBidPrice': 214.5,
#   'iexBidSize': 100,
#   'iexAskPrice': 220.45,
#   'iexAskSize': 104,
#   'marketCap': 986197466431,
#   'peRatio': 18.17,
#   'week52High': 233.84,
#   'week52Low': 145,
#   'ytdChange': 0.349749},
#  'bids': [{'price': 220, 'size': 102, 'timestamp': 1614983760524},
#   {'price': 213.15, 'size': 104, 'timestamp': 1597391409965},
#   {'price': 219.67, 'size': 606, 'timestamp': 1602152133484},
#   {'price': 204.56, 'size': 103, 'timestamp': 1614462500046},
#   {'price': 206, 'size': 201, 'timestamp': 1613223376476},
#   {'price': 201, 'size': 202, 'timestamp': 1611314247618},
#   {'price': 196, 'size': 103, 'timestamp': 1574021750925},
#   {'price': 185, 'size': 1126, 'timestamp': 1592363800172},
#   {'price': 185, 'size': 809, 'timestamp': 1605703618196},
#   {'price': 187, 'size': 291, 'timestamp': 1622267253283},
#   {'price': 184, 'size': 203, 'timestamp': 1599291336575},
#   {'price': 167, 'size': 307, 'timestamp': 1584532652930},
#   {'price': 168, 'size': 2104, 'timestamp': 1577690914068},
#   {'price': 155, 'size': 224, 'timestamp': 1586412532324},
#   {'price': 152, 'size': 208, 'timestamp': 1634381545247},
#   {'price': 144, 'size': 101, 'timestamp': 1571477473959},
#   {'price': 125, 'size': 156, 'timestamp': 1628013363921},
#   {'price': 56, 'size': 1143, 'timestamp': 1592170519837}],
#  'asks': [{'price': 220.58, 'size': 203, 'timestamp': 1592328925330},
#   {'price': 212.15, 'size': 101, 'timestamp': 1628718395177},
#   {'price': 218.06, 'size': 103, 'timestamp': 1584265882483},
#   {'price': 215, 'size': 207, 'timestamp': 1577511202140},
#   {'price': 222.7, 'size': 241, 'timestamp': 1619720471535},
#   {'price': 224, 'size': 203, 'timestamp': 1591722049609},
#   {'price': 224.49, 'size': 154, 'timestamp': 1634647413455},
#   {'price': 225.63, 'size': 4559, 'timestamp': 1561976390694},
#   {'price': 220, 'size': 731, 'timestamp': 1620400606995},
#   {'price': 224, 'size': 419, 'timestamp': 1606195672738},
#   {'price': 232, 'size': 306, 'timestamp': 1619391816044}],
#  'trades': [{'price': 219.135,
#    'size': 105,
#    'tradeId': 641707681,
#    'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1630314583055},
#   {'price': 212.85,
#    'size': 105,
#    'tradeId': 634949234,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1593467024095},
#   {'price': 216.26,
#    'size': 100,
#    'tradeId': 633552860,
#    'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1618965576790},
#   {'price': 215.11,
#    'size': 103,
#    'tradeId': 660674516,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1614825094065},
#   {'price': 212.897,
#    'size': 104,
#    'tradeId': 644424770,
#    'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1567277174672},
#   {'price': 219.94,
#    'size': 102,
#    'tradeId': 643308492,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1600884822994},
#   {'price': 212.87,
#    'size': 102,
#    'tradeId': 658376125,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1625520213064},
#   {'price': 212.68,
#    'size': 10,
#    'tradeId': 656313145,
#    'isISO': False,
#    'isOddLot': True,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1613663050565},
#   {'price': 219.51,
#    'size': 70,
#    'tradeId': 651629938,
#    'isISO': True,
#    'isOddLot': True,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1597232889110},
#   {'price': 216.27,
#    'size': 102,
#    'tradeId': 644422359,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1594670440923},
#   {'price': 211.67,
#    'size': 103,
#    'tradeId': 655520739,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1616505091826},
#   {'price': 212.28,
#    'size': 105,
#    'tradeId': 636121784,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1622693982653},
#   {'price': 215.71,
#    'size': 203,
#    'tradeId': 650060439,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1633239165257},
#   {'price': 218.1,
#    'size': 203,
#    'tradeId': 659372693,
#    'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1621537763079},
#   {'price': 217.52,
#    'size': 101,
#    'tradeId': 647496995,
#    'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1605771459135},
#   {'price': 219.01,
#    'size': 105,
#    'tradeId': 638011494,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1583540468514},
#   {'price': 217.88,
#    'size': 105,
#    'tradeId': 651848293,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': True,
#    'timestamp': 1594957557647},
#   {'price': 211.39,
#    'size': 103,
#    'tradeId': 632665990,
#    'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1597034340019},
#   {'price': 217.87,
#    'size': 105,
#    'tradeId': 650883209,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1575231019272},
#   {'price': 216.47,
#    'size': 103,
#    'tradeId': 632585373,
#    'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1609002862324}],
#  'systemEvent': {'systemEvent': 'R', 'timestamp': 1578941089425}}

# %%
c.bookDF(symbol).head()
# Out:
#    avgTotalVolume calculationPrice  change  changePercent   close  \
# 0      30064268.0             tops    2.03        0.00972  211.91
# 0             NaN              NaN     NaN            NaN     NaN
# 1             NaN              NaN     NaN            NaN     NaN
# 2             NaN              NaN     NaN            NaN     NaN
# 3             NaN              NaN     NaN            NaN     NaN
#
#                 closeTime  companyName  delayedPrice        delayedPriceTime  \
# 0 2021-07-13 01:45:25.447  Apple, Inc.        219.61 2020-09-05 14:55:07.207
# 0                     NaT          NaN           NaN                     NaT
# 1                     NaT          NaN           NaN                     NaT
# 2                     NaT          NaN           NaN                     NaT
# 3                     NaT          NaN           NaN                     NaT
#
#    extendedChange  ...  previousClose   price   size  symbol  \
# 0           -0.46  ...         217.73     NaN    NaN    AAPL
# 0             NaN  ...            NaN  215.37  203.0    AAPL
# 1             NaN  ...            NaN  213.26  102.0    AAPL
# 2             NaN  ...            NaN  217.39  102.0    AAPL
# 3             NaN  ...            NaN  219.00  205.0    AAPL
#
#                 timestamp  tradeId   type  week52High week52Low  ytdChange
# 0                     NaT      NaN  quote      242.47     145.0   0.346094
# 0 2019-07-23 21:25:48.386      NaN    ask         NaN       NaN        NaN
# 1 2019-06-23 04:38:18.603      NaN    ask         NaN       NaN        NaN
# 2 2020-07-27 13:16:33.776      NaN    ask         NaN       NaN        NaN
# 3 2020-03-01 15:45:41.048      NaN    ask         NaN       NaN        NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Cashflow

# %%
c.cashFlow(symbol)
# Out:
# {'symbol': 'AAPL',
#  'cashflow': [{'reportDate': '2019-04-05',
#    'netIncome': 12035948611,
#    'depreciation': 3098077530,
#    'changesInReceivables': 3023362996,
#    'changesInInventories': 71923571,
#    'cashChange': -5039918859,
#    'cashFlow': 11498497608,
#    'capitalExpenditures': -2445165866,
#    'investments': 15842343990,
#    'investingActivityOther': 57975903,
#    'totalInvestingCashFlows': 13931389381,
#    'dividendsPaid': -3466550212,
#    'netBorrowings': -2623911560,
#    'otherFinancingCashFlows': -201632455,
#    'cashFlowFinancing': -30034662249,
#    'exchangeRateEffect': None}]}

# %%
c.cashFlowDF(symbol)
# Out:
#             capitalExpenditures  cashChange     cashFlow  cashFlowFinancing  \
# reportDate
# 2019-04-11          -2476226778 -5155626308  11585246524       -30245186509
#
#             changesInInventories  changesInReceivables  depreciation  \
# reportDate
# 2019-04-11              72752127            3081367401    3108318573
#
#             dividendsPaid  exchangeRateEffect  investingActivityOther  \
# reportDate
# 2019-04-11    -3518414838                 NaN                58156808
#
#             investments  netBorrowings    netIncome  otherFinancingCashFlows  \
# reportDate
# 2019-04-11  15824598453    -2574895712  11752550286               -203828252
#
#             totalInvestingCashFlows symbol
# reportDate
# 2019-04-11              13857521862   AAPL

# %% [markdown]
# ## Collections

# %%
c.collections?
# Out:
# Signature:       c.collections(*args, meth=<function collections at 0x11ae39f28>, **kwargs)
# Call signature:  c.collections(*args, **kwargs)
# Type:            partial
# String form:     functools.partial(<bound method Client.bind of <pyEX.client.Client object at 0x11a5db320>>, meth=<function collections at 0x11ae39f28>)
# File:            /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/functools.py
# Docstring:
# Returns an array of quote objects for a given collection type. Currently supported collection types are sector, tag, and list
#
#
# https://iexcloud.io/docs/api/#collections
#
# Args:
#     tag (string);  Sector, Tag, or List
#     collectionName (string);  Associated name for tag
#     token (string); Access token
#     version (string); API version
#
# Returns:
#     dict: result
# Class docstring:
# partial(func, *args, **keywords) - new function with partial application
# of the given arguments and keywords.

# %%
c.collectionsDF?
# Out:
# Signature:
# c.collectionsDF(
#     *args,
#     meth=<function collectionsDF at 0x11ae3a048>,
#     **kwargs,
# )
# Call signature:  c.collectionsDF(*args, **kwargs)
# Type:            partial
# String form:     functools.partial(<bound method Client.bind of <pyEX.client.Client object at 0x11a5db320>>, meth=<function collectionsDF at 0x11ae3a048>)
# File:            /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/functools.py
# Docstring:
# Returns an array of quote objects for a given collection type. Currently supported collection types are sector, tag, and list
#
#
# https://iexcloud.io/docs/api/#collections
#
# Args:
#     tag (string);  Sector, Tag, or List
#     collectionName (string);  Associated name for tag
#     token (string); Access token
#     version (string); API version
#
# Returns:
#     DataFrame: result
# Class docstring:
# partial(func, *args, **keywords) - new function with partial application
# of the given arguments and keywords.

# %% [markdown]
# ## Company

# %%
c.company(symbol)
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'exchange': 'SAQADN',
#  'industry': 'iqeamo tecnocuEunminsmplTeti',
#  'website': 'h/.p.wcowtpap/mwel:t',
#  'description': 'nesblmmsesrmncudtinp ei itein a, ,tpcertmnmvaoso ga pndeuiar,dae amieogcelalco  uctbye asD dsarsn stma oaiclmuoperrkuf,sdiil ,',
#  'CEO': 'idoDoohl y akoTtnmC',
#  'securityName': ' npAc.eIlp',
#  'issueType': 'sc',
#  'sector': 'Thcyt lrEeocnooignlce',
#  'employees': 134595,
#  'tags': [' tlicogcncoEeTheonlry', 'csmmnEqetia eTnlounmecotiipu']}

# %%
c.companyDF(symbol)
# Out:
#                         CEO  companyName  \
# symbol
# AAPL    d thoCoDmkoilayT no  Apple, Inc.
#
#                                               description  employees exchange  \
# symbol
# AAPL    opebcs ub,taior cDmcdtaaia gpeisp , danr,uot e...     137870   DSQANA
#
#                             industry issueType                 sector  \
# symbol
# AAPL    tnupmc iocmTuanosmielnqEiete        sc  yncTolheEcnocltergio
#
#        securityName                                               tags  \
# symbol
# AAPL     pclA.I pne  [hcotlocnEeTlryc oeing, aeisqmmituocnncipeoT u...
#
#                      website
# symbol
# AAPL    aow:pp.t/t.eplwcwh/m

# %% [markdown]
# ## Delayed Quote

# %%
c.delayedQuote(symbol)
# Out:
# {'symbol': 'AAPL',
#  'delayedPrice': 215.6,
#  'high': 211.7,
#  'low': 213.46,
#  'delayedSize': 257,
#  'delayedPriceTime': 1567463855337,
#  'totalVolume': 14192546,
#  'processedTime': 1616404917067}

# %%
c.delayedQuoteDF(symbol)
# Out:
#         delayedPrice        delayedPriceTime  delayedSize   high     low  \
# symbol
# AAPL         221.136 2021-02-14 13:33:09.089          267  220.2  212.52
#
#         processedTime  totalVolume
# symbol
# AAPL    1597150394063     14670569

# %% [markdown]
# ## Dividends

# %%
c.dividends(symbol)
# Out:
# [{'exDate': '2019-05-12',
#   'paymentDate': '2019-05-16',
#   'recordDate': '2019-05-22',
#   'declaredDate': '2019-05-09',
#   'amount': 0.81,
#   'flag': 'ernIesca',
#   'currency': 'DUS',
#   'description': 'ipid5l HpAv.sreedQkDluey5nr % i aet',
#   'frequency': 'tulayQrre',
#   'date': '2019-05-03'},
#  {'exDate': '2019-02-17',
#   'paymentDate': '2019-02-24',
#   'recordDate': '2019-02-21',
#   'declaredDate': '2019-02-11',
#   'amount': 0.74,
#   'flag': 'ahegnNC QQo o',
#   'currency': 'SUD',
#   'description': 'acelir0PS  $ deraeplr.ol DpuAfvQnar  stey dheireDe73',
#   'frequency': 'uetlQyrar',
#   'date': '2019-05-03'}]

# %%
c.dividendsDF(symbol)
# Out:
#             amount currency       date declaredDate  \
# exDate
# 2019-05-23    0.80      DSU 2019-05-03   2019-05-10
# 2019-02-14    0.76      UDS 2019-05-03   2019-02-08
#
#                                                   description           flag  \
# exDate
# 2019-05-23                 r5%k eiAudQiee.lpt nd Dy5rpHilseav       rsnIcaee
# 2019-02-14  eu ni3ee.sf7r0ADD$ dePociySe  rertQlver lphrla...  Q hoQN ogneCa
#
#             frequency paymentDate recordDate
# exDate
# 2019-05-23  Qayerlurt  2019-05-27 2019-05-23
# 2019-02-14  aluetryrQ  2019-02-14 2019-02-12

# %% [markdown]
# ## Earnings

# %%
c.earnings(symbol)
# Out:
# {'symbol': 'AAPL',
#  'earnings': [{'actualEPS': 2.55,
#    'consensusEPS': 2.46,
#    'announceTime': 'CMA',
#    'numberOfEstimates': 36,
#    'EPSSurpriseDollar': 0.09,
#    'EPSReportDate': '2019-05-12',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-09',
#    'yearAgo': 2.76,
#    'yearAgoChangePercent': -0.1017}]}

# %%
c.earningsDF(symbol)
# Out:
#                EPSSurpriseDollar  actualEPS announceTime  consensusEPS  \
# EPSReportDate
# 2019-05-14                  0.09       2.57          AMC          2.44
#
#               fiscalEndDate fiscalPeriod  numberOfEstimates  yearAgo  \
# EPSReportDate
# 2019-05-14       2019-04-01      Q1 2019                 37      2.8
#
#                yearAgoChangePercent symbol
# EPSReportDate
# 2019-05-14                   -0.102   AAPL

# %% [markdown]
# ## Earnings Today

# %%
c.earningsToday()
# Out:
# {'bto': [{'consensusEPS': '0.4',
#    'announceTime': 'TOB',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-02',
#    'symbol': 'TLK',
#    'reportDate': '2019-05-15',
#    'quote': {'symbol': 'TLK',
#     'companyName': 'PT Telekomunikasi Indonesia Tbk',
#     'calculationPrice': 'tops',
#     'open': 27.27,
#     'openTime': 1588131408077,
#     'close': 28.03,
#     'closeTime': 1619125666153,
#     'high': 27.89,
#     'low': 28,
#     'latestPrice': 27.03,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:28:55 PM',
#     'latestUpdate': 1589798384143,
#     'latestVolume': 110644,
#     'iexRealtimePrice': 27.67,
#     'iexRealtimeSize': 102,
#     'iexLastUpdated': 1568414044848,
#     'delayedPrice': 27.58,
#     'delayedPriceTime': 1620974973108,
#     'extendedPrice': 27.7,
#     'extendedChange': 0.51,
#     'extendedChangePercent': 0.01845,
#     'extendedPriceTime': 1611102175841,
#     'previousClose': 27.77,
#     'change': 0.16,
#     'changePercent': 0.00621,
#     'iexMarketPercent': 0.03159841129792471,
#     'iexVolume': 3417,
#     'avgTotalVolume': 256830,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 27.8,
#     'iexAskSize': 105,
#     'marketCap': 2693512237573,
#     'peRatio': 20.25,
#     'week52High': 28.97,
#     'week52Low': 22.24,
#     'ytdChange': 0.025493}},
#   {'actualEPS': 1.06,
#    'consensusEPS': '0.99',
#    'announceTime': 'BOT',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': '0.08',
#    'EPSReportDate': '2019-05-09',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-11',
#    'yearAgo': 0.75,
#    'yearAgoChangePercent': '0.4',
#    'symbol': 'HSBC',
#    'quote': {'symbol': 'HSBC',
#     'companyName': 'HSBC Holdings Plc',
#     'calculationPrice': 'tops',
#     'open': 46.52,
#     'openTime': 1599592645633,
#     'close': 44.54,
#     'closeTime': 1609749262955,
#     'high': 45.13,
#     'low': 46.33,
#     'latestPrice': 46.957,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:30:16 PM',
#     'latestUpdate': 1578754799853,
#     'latestVolume': 1771104,
#     'iexRealtimePrice': 45.634,
#     'iexRealtimeSize': 714,
#     'iexLastUpdated': 1573081449909,
#     'delayedPrice': 46.14,
#     'delayedPriceTime': 1560631163424,
#     'extendedPrice': 45.8,
#     'extendedChange': -0.354,
#     'extendedChangePercent': -0.00804,
#     'extendedPriceTime': 1581194560795,
#     'previousClose': 43.88,
#     'change': 1.384,
#     'changePercent': 0.03179,
#     'iexMarketPercent': 0.0118661089469186,
#     'iexVolume': 20704,
#     'avgTotalVolume': 1924749,
#     'iexBidPrice': 44.99,
#     'iexBidSize': 101,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 187957479820,
#     'peRatio': 14.31,
#     'week52High': 52.54,
#     'week52Low': 39.89,
#     'ytdChange': 0.09843536716410292}},
#   {'actualEPS': 3.715397,
#    'consensusEPS': '0.92',
#    'announceTime': 'BOT',
#    'numberOfEstimates': 3,
#    'EPSSurpriseDollar': '2.82',
#    'EPSReportDate': '2019-05-07',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-02',
#    'yearAgo': 0.86332,
#    'yearAgoChangePercent': '3.2776',
#    'symbol': 'UOVEY',
#    'quote': {'symbol': 'UOVEY',
#     'companyName': 'United Overseas Bank Ltd. (Singapore)',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 42.6,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1597845667804,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 42.2,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 67912,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 69741839579,
#     'peRatio': 11.81,
#     'week52High': 46.26,
#     'week52Low': 34.07,
#     'ytdChange': 0.137185}},
#   {'actualEPS': 1.781967,
#    'consensusEPS': '1.64',
#    'announceTime': 'BTO',
#    'numberOfEstimates': 12,
#    'EPSSurpriseDollar': '0.16',
#    'EPSReportDate': '2019-05-05',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-06',
#    'yearAgo': 1.6169,
#    'yearAgoChangePercent': '0.1242',
#    'symbol': 'ADDYY',
#    'quote': {'symbol': 'ADDYY',
#     'companyName': 'adidas AG',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 130.9,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1626966522778,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': 132,
#     'extendedChange': 0,
#     'extendedChangePercent': 0,
#     'extendedPriceTime': 1597155827830,
#     'previousClose': 131.1,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 36542,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 51859155822,
#     'peRatio': 26.09,
#     'week52High': 136.83,
#     'week52Low': 102.8,
#     'ytdChange': 0.224523}},
#   {'consensusEPS': '0.55',
#    'announceTime': 'TBO',
#    'numberOfEstimates': 6,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-13',
#    'symbol': 'FCAU',
#    'reportDate': '2019-05-13',
#    'quote': {'symbol': 'FCAU',
#     'companyName': 'Fiat Chrysler Automobiles NV',
#     'calculationPrice': 'tops',
#     'open': 15.95,
#     'openTime': 1612049969989,
#     'close': 15.19,
#     'closeTime': 1592465002350,
#     'high': 16.12,
#     'low': 15.8,
#     'latestPrice': 16.41,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:36:06 PM',
#     'latestUpdate': 1561196487846,
#     'latestVolume': 5967033,
#     'iexRealtimePrice': 16.35,
#     'iexRealtimeSize': 7,
#     'iexLastUpdated': 1585458480450,
#     'delayedPrice': 16.29,
#     'delayedPriceTime': 1610638652147,
#     'extendedPrice': 16.2,
#     'extendedChange': -0.17,
#     'extendedChangePercent': -0.01111,
#     'extendedPriceTime': 1601015388573,
#     'previousClose': 15.08,
#     'change': 0.86,
#     'changePercent': 0.05689,
#     'iexMarketPercent': 0.02083742375599816,
#     'iexVolume': 123201,
#     'avgTotalVolume': 3328904,
#     'iexBidPrice': 16.01,
#     'iexBidSize': 201,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 25021794622,
#     'peRatio': 6.01,
#     'week52High': 24.35,
#     'week52Low': 14.36,
#     'ytdChange': 0.105067}},
#   {'actualEPS': 0.26043,
#    'consensusEPS': '0.18',
#    'announceTime': 'TBO',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': '0.07',
#    'EPSReportDate': '2019-05-18',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-13',
#    'yearAgo': 0.33449,
#    'yearAgoChangePercent': '-0.2486',
#    'symbol': 'SCGLY',
#    'quote': {'symbol': 'SCGLY',
#     'companyName': 'Société Générale SA',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 6.41,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1604758020366,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 6.45,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 357642,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 24151229726,
#     'peRatio': 6.21,
#     'week52High': 11.06,
#     'week52Low': 5.36,
#     'ytdChange': 0.01315}},
#   {'consensusEPS': '0.42',
#    'announceTime': 'TBO',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-08',
#    'symbol': 'IHG',
#    'reportDate': '2019-05-13',
#    'quote': {'symbol': 'IHG',
#     'companyName': 'InterContinental Hotels Group Plc',
#     'calculationPrice': 'sip',
#     'open': 65.84,
#     'openTime': 1614155743886,
#     'close': 69.04,
#     'closeTime': 1622650647075,
#     'high': 66.73,
#     'low': 66.13,
#     'latestPrice': 68.7,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:20:32 PM',
#     'latestUpdate': 1572565311364,
#     'latestVolume': 63634,
#     'iexRealtimePrice': 68.28,
#     'iexRealtimeSize': 104,
#     'iexLastUpdated': 1596577860824,
#     'delayedPrice': 66.72,
#     'delayedPriceTime': 1608093799431,
#     'extendedPrice': 68.33,
#     'extendedChange': -0.39,
#     'extendedChangePercent': -0.00583,
#     'extendedPriceTime': 1574382184965,
#     'previousClose': 68.17,
#     'change': -0.46,
#     'changePercent': -0.0068,
#     'iexMarketPercent': 0.02266986957631111,
#     'iexVolume': 1389,
#     'avgTotalVolume': 65688,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 12436152986,
#     'peRatio': 35.33,
#     'week52High': 72.4,
#     'week52Low': 55.19,
#     'ytdChange': 0.173041}},
#   {'consensusEPS': '1.34',
#    'announceTime': 'BOT',
#    'numberOfEstimates': 12,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-14',
#    'symbol': 'YAGOY',
#    'reportDate': '2019-05-06',
#    'quote': {'symbol': 'YAGOY',
#     'companyName': 'Yageo Corp.',
#     'calculationPrice': 'close',
#     'open': None,
#     'openTime': None,
#     'close': 0,
#     'closeTime': 1544226420548,
#     'high': None,
#     'low': None,
#     'latestPrice': None,
#     'latestSource': 'Close',
#     'latestTime': 'July 14, 2017',
#     'latestUpdate': 1540743014472,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': None,
#     'change': None,
#     'changePercent': None,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 0,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': 0,
#     'week52Low': 0,
#     'ytdChange': 0}},
#   {'actualEPS': -0.827382,
#    'consensusEPS': '-0.73',
#    'announceTime': 'TOB',
#    'numberOfEstimates': 4,
#    'EPSSurpriseDollar': '-0.1',
#    'EPSReportDate': '2019-05-15',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-10',
#    'yearAgo': -0.659614,
#    'yearAgoChangePercent': '0.2519',
#    'symbol': 'AFLYY',
#    'quote': {'symbol': 'AFLYY',
#     'companyName': 'Air France-KLM SA',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 11.86,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1601761772106,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 11.42,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 43011,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 4926304430,
#     'peRatio': 10.59,
#     'week52High': 15.5,
#     'week52Low': 8.08,
#     'ytdChange': 0.083716}},
#   {'actualEPS': 0.499458,
#    'announceTime': 'TBO',
#    'EPSReportDate': '2019-05-13',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-14',
#    'yearAgo': -0.345485,
#    'yearAgoChangePercent': '-2.4364',
#    'symbol': 'SPLP-A',
#    'quote': {'symbol': 'SPLP-A',
#     'companyName': 'Steel Partners Holdings LP',
#     'calculationPrice': 'sip',
#     'open': 23.1,
#     'openTime': 1560599189127,
#     'close': 23.08,
#     'closeTime': 1625313211878,
#     'high': 23.084,
#     'low': 22.241,
#     'latestPrice': 22.65,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '1:36:25 PM',
#     'latestUpdate': 1611445879593,
#     'latestVolume': 35850,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 22.72,
#     'delayedPriceTime': 1616259895513,
#     'extendedPrice': 23.6,
#     'extendedChange': 0.23,
#     'extendedChangePercent': 0.01078,
#     'extendedPriceTime': 1593188522497,
#     'previousClose': 22.9,
#     'change': 0.16,
#     'changePercent': 0.00694,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 28911,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 563501759,
#     'peRatio': None,
#     'week52High': 24.26,
#     'week52Low': 20.71,
#     'ytdChange': 0.037344}},
#   {'consensusEPS': '-0.19',
#    'announceTime': 'BOT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-13',
#    'symbol': 'BSGM',
#    'reportDate': '2019-05-14',
#    'quote': {'symbol': 'BSGM',
#     'companyName': 'BioSig Technologies, Inc.',
#     'calculationPrice': 'sip',
#     'open': 6.99,
#     'openTime': 1588449567000,
#     'close': 7,
#     'closeTime': 1570430027914,
#     'high': 6.85,
#     'low': 6.798,
#     'latestPrice': 6.76,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:18:00 PM',
#     'latestUpdate': 1595082186565,
#     'latestVolume': 52941,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 6.86,
#     'delayedPriceTime': 1612020445499,
#     'extendedPrice': 0,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': 1581388598023,
#     'previousClose': 6.8,
#     'change': -0.04,
#     'changePercent': -0.00618,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 61317,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 137453515,
#     'peRatio': -5.05,
#     'week52High': 7.89,
#     'week52Low': 3.7,
#     'ytdChange': 0.557881}},
#   {'actualEPS': -0.29,
#    'consensusEPS': '-0.15',
#    'announceTime': 'TBO',
#    'numberOfEstimates': 1,
#    'EPSSurpriseDollar': '-0.14',
#    'EPSReportDate': '2019-05-05',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-02',
#    'yearAgo': -0.19,
#    'yearAgoChangePercent': '0.6298',
#    'symbol': 'DXYN',
#    'quote': {'symbol': 'DXYN',
#     'companyName': 'The Dixie Group, Inc.',
#     'calculationPrice': 'sip',
#     'open': 0.77,
#     'openTime': 1560766265911,
#     'close': 0.78,
#     'closeTime': 1571886499198,
#     'high': 0.8557,
#     'low': 0.7,
#     'latestPrice': 0.8593,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:19:20 PM',
#     'latestUpdate': 1600767205364,
#     'latestVolume': 28200,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 0.8317,
#     'delayedPriceTime': 1593453206503,
#     'extendedPrice': 0.89,
#     'extendedChange': 0.0513,
#     'extendedChangePercent': 0.06195,
#     'extendedPriceTime': 1598606354977,
#     'previousClose': 0.78,
#     'change': 0.0509,
#     'changePercent': 0.067,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 23316,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 13217338,
#     'peRatio': -0.61,
#     'week52High': 3.06,
#     'week52Low': 0.63,
#     'ytdChange': 0.040887617406811065}},
#   {'consensusEPS': '1.34',
#    'announceTime': 'OBT',
#    'numberOfEstimates': 11,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-11',
#    'symbol': 'YAGZZ',
#    'reportDate': '2019-05-17',
#    'quote': {'symbol': 'YAGZZ',
#     'companyName': 'Yageo Corp.',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': None,
#     'latestSource': 'N/A',
#     'latestTime': 'N/A',
#     'latestUpdate': None,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': None,
#     'change': None,
#     'changePercent': None,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': None,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': 0,
#     'week52Low': 0,
#     'ytdChange': 0}}],
#  'amc': [],
#  'other': [{'actualEPS': 0.660762,
#    'consensusEPS': '0.63',
#    'announceTime': 'DTM',
#    'numberOfEstimates': 10,
#    'EPSSurpriseDollar': '0.03',
#    'EPSReportDate': '2019-05-10',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-15',
#    'yearAgo': 0.73158,
#    'yearAgoChangePercent': '-0.0756',
#    'symbol': 'NVO',
#    'quote': {'symbol': 'NVO',
#     'companyName': 'Novo Nordisk A/S',
#     'calculationPrice': 'tops',
#     'open': 48.39,
#     'openTime': 1629306961750,
#     'close': 50.83,
#     'closeTime': 1565691382618,
#     'high': 49.31,
#     'low': 47.514,
#     'latestPrice': 48.21,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:32:55 PM',
#     'latestUpdate': 1603855312900,
#     'latestVolume': 1633470,
#     'iexRealtimePrice': 49.59,
#     'iexRealtimeSize': 47,
#     'iexLastUpdated': 1594593226267,
#     'delayedPrice': 48.678,
#     'delayedPriceTime': 1619496005829,
#     'extendedPrice': 48.12,
#     'extendedChange': 0.36,
#     'extendedChangePercent': 0.0079,
#     'extendedPriceTime': 1560005554210,
#     'previousClose': 50.21,
#     'change': -1.55,
#     'changePercent': -0.03078,
#     'iexMarketPercent': 0.02786517476521803,
#     'iexVolume': 43923,
#     'avgTotalVolume': 1357257,
#     'iexBidPrice': 47.32,
#     'iexBidSize': 101,
#     'iexAskPrice': 55,
#     'iexAskSize': 104,
#     'marketCap': 89541953031,
#     'peRatio': 19,
#     'week52High': 52.92,
#     'week52Low': 41.94,
#     'ytdChange': 0.01445557859974558}},
#   {'consensusEPS': '0.85',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 18,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-01',
#    'symbol': 'AMT',
#    'reportDate': '2019-05-16',
#    'quote': {'symbol': 'AMT',
#     'companyName': 'American Tower Corp.',
#     'calculationPrice': 'tops',
#     'open': 195.42,
#     'openTime': 1589958796223,
#     'close': 197.3,
#     'closeTime': 1577734213303,
#     'high': 198.59,
#     'low': 193.48,
#     'latestPrice': 202.672,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:35:01 PM',
#     'latestUpdate': 1612519848985,
#     'latestVolume': 650645,
#     'iexRealtimePrice': 201.711,
#     'iexRealtimeSize': 52,
#     'iexLastUpdated': 1565771078958,
#     'delayedPrice': 196.336,
#     'delayedPriceTime': 1605715475463,
#     'extendedPrice': 194.8,
#     'extendedChange': -0.618,
#     'extendedChangePercent': -0.00321,
#     'extendedPriceTime': 1617432716911,
#     'previousClose': 199.3,
#     'change': 0.638,
#     'changePercent': 0.00323,
#     'iexMarketPercent': 0.03692091209016157,
#     'iexVolume': 23272,
#     'avgTotalVolume': 1811902,
#     'iexBidPrice': 193.67,
#     'iexBidSize': 101,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 88963750086,
#     'peRatio': 69.58,
#     'week52High': 198.21,
#     'week52Low': 140.13,
#     'ytdChange': 0.233668}},
#   {'actualEPS': 0.47,
#    'consensusEPS': '0.46',
#    'announceTime': 'MDT',
#    'numberOfEstimates': 11,
#    'EPSSurpriseDollar': '0.02',
#    'EPSReportDate': '2019-05-08',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-12',
#    'yearAgo': 0.46487,
#    'yearAgoChangePercent': '0.0373',
#    'symbol': 'EQNR',
#    'quote': {'symbol': 'EQNR',
#     'companyName': 'Equinor ASA',
#     'calculationPrice': 'tops',
#     'open': 22.61,
#     'openTime': 1618219253711,
#     'close': 22.27,
#     'closeTime': 1596532785287,
#     'high': 23.05,
#     'low': 22.42,
#     'latestPrice': 22.1,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:35:44 PM',
#     'latestUpdate': 1613066571793,
#     'latestVolume': 1087991,
#     'iexRealtimePrice': 21.87,
#     'iexRealtimeSize': 95,
#     'iexLastUpdated': 1588741496797,
#     'delayedPrice': 21.951,
#     'delayedPriceTime': 1634473361847,
#     'extendedPrice': 22.53,
#     'extendedChange': 0.26,
#     'extendedChangePercent': 0.01241,
#     'extendedPriceTime': 1573656061373,
#     'previousClose': 21.77,
#     'change': 0.16,
#     'changePercent': 0.00752,
#     'iexMarketPercent': 0.04132746951471513,
#     'iexVolume': 44168,
#     'avgTotalVolume': 1214668,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 22.28,
#     'iexAskSize': 104,
#     'marketCap': 75931985427,
#     'peRatio': 10.13,
#     'week52High': 29.27,
#     'week52Low': 20.39,
#     'ytdChange': 0.00946}},
#   {'actualEPS': 0.480812,
#    'consensusEPS': '0.46',
#    'announceTime': 'DTM',
#    'numberOfEstimates': 7,
#    'EPSSurpriseDollar': '0.02',
#    'EPSReportDate': '2019-05-11',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-03',
#    'yearAgo': 0.597421,
#    'yearAgoChangePercent': '-0.2049',
#    'symbol': 'BASFY',
#    'quote': {'symbol': 'BASFY',
#     'companyName': 'BASF SE',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 20.6,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1560778935605,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 20.41,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 201325,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 73983303172,
#     'peRatio': 13.3,
#     'week52High': 27.03,
#     'week52Low': 16.9,
#     'ytdChange': 0.160556}},
#   {'consensusEPS': '1.17',
#    'announceTime': 'MDT',
#    'numberOfEstimates': 12,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-08',
#    'symbol': 'D',
#    'reportDate': '2019-05-17',
#    'quote': {'symbol': 'D',
#     'companyName': 'Dominion Energy, Inc.',
#     'calculationPrice': 'tops',
#     'open': 76.07,
#     'openTime': 1566548056892,
#     'close': 80.08,
#     'closeTime': 1617476219661,
#     'high': 77.42,
#     'low': 78.07,
#     'latestPrice': 77.87,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:34:50 PM',
#     'latestUpdate': 1574716269938,
#     'latestVolume': 1864354,
#     'iexRealtimePrice': 77.28,
#     'iexRealtimeSize': 105,
#     'iexLastUpdated': 1595146907713,
#     'delayedPrice': 78.48,
#     'delayedPriceTime': 1590616138257,
#     'extendedPrice': 78.88,
#     'extendedChange': -1.07,
#     'extendedChangePercent': -0.0143,
#     'extendedPriceTime': 1632400580794,
#     'previousClose': 80.78,
#     'change': -0.15,
#     'changePercent': -0.00197,
#     'iexMarketPercent': 0.040718175115305545,
#     'iexVolume': 72512,
#     'avgTotalVolume': 3445640,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 77.16,
#     'iexAskSize': 100,
#     'marketCap': 62429805735,
#     'peRatio': 20.57,
#     'week52High': 78.59,
#     'week52Low': 62.94,
#     'ytdChange': 0.08047288688605751}},
#   {'consensusEPS': '2.12',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-09',
#    'symbol': 'PUK',
#    'reportDate': '2019-05-15',
#    'quote': {'symbol': 'PUK',
#     'companyName': 'Prudential Plc',
#     'calculationPrice': 'sip',
#     'open': 45.51,
#     'openTime': 1622661001105,
#     'close': 47.11,
#     'closeTime': 1570376960169,
#     'high': 46.64,
#     'low': 46.47,
#     'latestPrice': 46.68,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:20:53 PM',
#     'latestUpdate': 1570923236061,
#     'latestVolume': 108543,
#     'iexRealtimePrice': 46.65,
#     'iexRealtimeSize': 102,
#     'iexLastUpdated': 1594293945905,
#     'delayedPrice': 47.19,
#     'delayedPriceTime': 1627109311912,
#     'extendedPrice': 45.6,
#     'extendedChange': -0.3,
#     'extendedChangePercent': -0.00651,
#     'extendedPriceTime': 1625247275553,
#     'previousClose': 46.56,
#     'change': 0.43,
#     'changePercent': 0.00943,
#     'iexMarketPercent': 0.02288250747289366,
#     'iexVolume': 2492,
#     'avgTotalVolume': 274966,
#     'iexBidPrice': 47.61,
#     'iexBidSize': 102,
#     'iexAskPrice': 46.5,
#     'iexAskSize': 103,
#     'marketCap': 59520538796,
#     'peRatio': 15.42,
#     'week52High': 52.82,
#     'week52Low': 34.17,
#     'ytdChange': 0.319731}},
#   {'consensusEPS': '0.17',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 5,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-01',
#    'symbol': 'GPFOY',
#    'reportDate': '2019-05-13',
#    'quote': {'symbol': 'GPFOY',
#     'companyName': 'Grupo Financiero Inbursa SAB de CV',
#     'calculationPrice': 'close',
#     'open': None,
#     'openTime': None,
#     'close': 0,
#     'closeTime': 1582883785314,
#     'high': None,
#     'low': None,
#     'latestPrice': None,
#     'latestSource': 'Close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1579223809294,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': None,
#     'change': None,
#     'changePercent': None,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 227,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': 8.66,
#     'week52Low': 6.2,
#     'ytdChange': -1.041945}},
#   {'consensusEPS': '0.72',
#    'announceTime': 'TMD',
#    'numberOfEstimates': 12,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-03',
#    'symbol': 'TRP',
#    'reportDate': '2019-05-07',
#    'quote': {'symbol': 'TRP',
#     'companyName': 'TransCanada Corp.',
#     'calculationPrice': 'tops',
#     'open': 48,
#     'openTime': 1569477015974,
#     'close': 48.56,
#     'closeTime': 1590421028782,
#     'high': 48.03,
#     'low': 47.13,
#     'latestPrice': 48.126,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:34:47 PM',
#     'latestUpdate': 1579107702452,
#     'latestVolume': 1346784,
#     'iexRealtimePrice': 48.289,
#     'iexRealtimeSize': 104,
#     'iexLastUpdated': 1578447439610,
#     'delayedPrice': 47.84,
#     'delayedPriceTime': 1559576485729,
#     'extendedPrice': 48.2,
#     'extendedChange': 0.148,
#     'extendedChangePercent': 0.0032,
#     'extendedPriceTime': 1632869962979,
#     'previousClose': 48.74,
#     'change': -0.231,
#     'changePercent': -0.00481,
#     'iexMarketPercent': 0.033589636160417914,
#     'iexVolume': 45172,
#     'avgTotalVolume': 1560827,
#     'iexBidPrice': 47.17,
#     'iexBidSize': 101,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 44384989621,
#     'peRatio': 15.64,
#     'week52High': 49.31,
#     'week52Low': 36.05,
#     'ytdChange': 0.2620988467270892}},
#   {'actualEPS': 0.659172,
#    'consensusEPS': '0.61',
#    'announceTime': 'TMD',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': '0.05',
#    'EPSReportDate': '2019-05-10',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-01',
#    'yearAgo': 0.358361,
#    'yearAgoChangePercent': '0.7835',
#    'symbol': 'SSREY',
#    'quote': {'symbol': 'SSREY',
#     'companyName': 'Swiss Re AG',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 24.5,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1613135800807,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 24.24,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 38886,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 29297879921,
#     'peRatio': 72.03,
#     'week52High': 26.32,
#     'week52Low': 21.3,
#     'ytdChange': 0.045694}},
#   {'consensusEPS': '0.59',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 11,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-09',
#    'symbol': 'CQP',
#    'reportDate': '2019-05-07',
#    'quote': {'symbol': 'CQP',
#     'companyName': 'Cheniere Energy Partners LP',
#     'calculationPrice': 'sip',
#     'open': 44.61,
#     'openTime': 1586524206876,
#     'close': 45.68,
#     'closeTime': 1586627060862,
#     'high': 45.16,
#     'low': 44.08,
#     'latestPrice': 44.34,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:17:04 PM',
#     'latestUpdate': 1564453078154,
#     'latestVolume': 44313,
#     'iexRealtimePrice': 44.7,
#     'iexRealtimeSize': 6,
#     'iexLastUpdated': 1609077060440,
#     'delayedPrice': 45.6,
#     'delayedPriceTime': 1584524739149,
#     'extendedPrice': 45.46,
#     'extendedChange': -0.3,
#     'extendedChangePercent': -0.00673,
#     'extendedPriceTime': 1579199492723,
#     'previousClose': 44.05,
#     'change': 0.3,
#     'changePercent': 0.00689,
#     'iexMarketPercent': 0.009390910304574814,
#     'iexVolume': 419,
#     'avgTotalVolume': 156742,
#     'iexBidPrice': 45.31,
#     'iexBidSize': 102,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 22041461894,
#     'peRatio': 198.05,
#     'week52High': 46.35,
#     'week52Low': 30.94,
#     'ytdChange': 0.23690714087522236}},
#   {'actualEPS': 1.212114,
#    'consensusEPS': '1.27',
#    'announceTime': 'DTM',
#    'numberOfEstimates': 4,
#    'EPSSurpriseDollar': '-0.06',
#    'EPSReportDate': '2019-05-18',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-03',
#    'yearAgo': 1.41815,
#    'yearAgoChangePercent': '-0.1416',
#    'symbol': 'OMVKY',
#    'quote': {'symbol': 'OMVKY',
#     'companyName': 'OMV AG',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 54.55,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1627414060844,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 55.02,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 2034,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 17405981377,
#     'peRatio': 10.41,
#     'week52High': 67.83,
#     'week52Low': 44.22,
#     'ytdChange': 0.18052}},
#   {'actualEPS': 0.514155,
#    'consensusEPS': '0.49',
#    'announceTime': 'MDT',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': '0.01',
#    'EPSReportDate': '2019-05-14',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-05',
#    'yearAgo': 0.47446,
#    'yearAgoChangePercent': '0.0579',
#    'symbol': 'EBKDY',
#    'quote': {'symbol': 'EBKDY',
#     'companyName': 'Erste Group Bank AG',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 21.11,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1580240909682,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 20.48,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 63787,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 17139988143,
#     'peRatio': 8.57,
#     'week52High': 25,
#     'week52Low': 16.04,
#     'ytdChange': 0.243422}},
#   {'actualEPS': 0.68,
#    'consensusEPS': '0.68',
#    'announceTime': 'TDM',
#    'numberOfEstimates': 17,
#    'EPSSurpriseDollar': '0',
#    'EPSReportDate': '2019-05-05',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-11',
#    'yearAgo': 0.7,
#    'yearAgoChangePercent': '-0.0743',
#    'symbol': 'DISH',
#    'quote': {'symbol': 'DISH',
#     'companyName': 'DISH Network Corp.',
#     'calculationPrice': 'tops',
#     'open': 33.73,
#     'openTime': 1587448906753,
#     'close': 35.2,
#     'closeTime': 1598294838443,
#     'high': 36.02,
#     'low': 34.08,
#     'latestPrice': 35.61,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:36:00 PM',
#     'latestUpdate': 1578864238808,
#     'latestVolume': 2991626,
#     'iexRealtimePrice': 35.51,
#     'iexRealtimeSize': 105,
#     'iexLastUpdated': 1617487021609,
#     'delayedPrice': 36.58,
#     'delayedPriceTime': 1603538248361,
#     'extendedPrice': 34.8,
#     'extendedChange': -1.53,
#     'extendedChangePercent': -0.04358,
#     'extendedPriceTime': 1626226328446,
#     'previousClose': 34.7,
#     'change': 1.39,
#     'changePercent': 0.04164,
#     'iexMarketPercent': 0.05383655120943016,
#     'iexVolume': 150279,
#     'avgTotalVolume': 1992114,
#     'iexBidPrice': 36.38,
#     'iexBidSize': 104,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 16871749556,
#     'peRatio': 10.47,
#     'week52High': 38.94,
#     'week52Low': 24.34,
#     'ytdChange': 0.34672}},
#   {'consensusEPS': '-0.03',
#    'announceTime': 'TMD',
#    'numberOfEstimates': 31,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-07',
#    'symbol': 'NBL',
#    'reportDate': '2019-05-14',
#    'quote': {'symbol': 'NBL',
#     'companyName': 'Noble Energy, Inc.',
#     'calculationPrice': 'tops',
#     'open': 26.1,
#     'openTime': 1609153257684,
#     'close': 26.34,
#     'closeTime': 1610236429555,
#     'high': 26,
#     'low': 24.85,
#     'latestPrice': 25.61,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:36:00 PM',
#     'latestUpdate': 1564178451275,
#     'latestVolume': 6119671,
#     'iexRealtimePrice': 26.07,
#     'iexRealtimeSize': 104,
#     'iexLastUpdated': 1573200046528,
#     'delayedPrice': 25.428,
#     'delayedPriceTime': 1598163491166,
#     'extendedPrice': 26.1,
#     'extendedChange': -0.28,
#     'extendedChangePercent': -0.01069,
#     'extendedPriceTime': 1581034729542,
#     'previousClose': 26.14,
#     'change': -0.11,
#     'changePercent': -0.00451,
#     'iexMarketPercent': 0.0555338974884693,
#     'iexVolume': 338090,
#     'avgTotalVolume': 5899322,
#     'iexBidPrice': 26.04,
#     'iexBidSize': 102,
#     'iexAskPrice': 26.46,
#     'iexAskSize': 104,
#     'marketCap': 12377158589,
#     'peRatio': -163.64,
#     'week52High': 38.58,
#     'week52Low': 17.85,
#     'ytdChange': 0.316728}},
#   {'consensusEPS': '1.22',
#    'announceTime': 'MDT',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-08',
#    'symbol': 'WPC',
#    'reportDate': '2019-05-16',
#    'quote': {'symbol': 'WPC',
#     'companyName': 'W.P. Carey, Inc.',
#     'calculationPrice': 'tops',
#     'open': 81.07,
#     'openTime': 1574554701181,
#     'close': 83.21,
#     'closeTime': 1634220641665,
#     'high': 79.6,
#     'low': 80.923,
#     'latestPrice': 82.39,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:33:03 PM',
#     'latestUpdate': 1621290492275,
#     'latestVolume': 319334,
#     'iexRealtimePrice': 81.36,
#     'iexRealtimeSize': 15,
#     'iexLastUpdated': 1621012020556,
#     'delayedPrice': 82.88,
#     'delayedPriceTime': 1605007479200,
#     'extendedPrice': 81.38,
#     'extendedChange': 0.1,
#     'extendedChangePercent': 0.00127,
#     'extendedPriceTime': 1571604195545,
#     'previousClose': 80.33,
#     'change': -0.1,
#     'changePercent': -0.00132,
#     'iexMarketPercent': 0.022458507204359653,
#     'iexVolume': 6826,
#     'avgTotalVolume': 755157,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 14037683466,
#     'peRatio': 26.16,
#     'week52High': 81.85,
#     'week52Low': 63.79,
#     'ytdChange': 0.246148741617716}},
#   {'actualEPS': 0.321801,
#    'consensusEPS': '0.26',
#    'announceTime': 'TDM',
#    'numberOfEstimates': 7,
#    'EPSSurpriseDollar': '0.05',
#    'EPSReportDate': '2019-05-12',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-11',
#    'yearAgo': -0.73,
#    'yearAgoChangePercent': '-1.486',
#    'symbol': 'VST',
#    'quote': {'symbol': 'VST',
#     'companyName': 'Vistra Energy Corp.',
#     'calculationPrice': 'tops',
#     'open': 28.23,
#     'openTime': 1604006329686,
#     'close': 28.48,
#     'closeTime': 1623636402348,
#     'high': 28.14,
#     'low': 27.19,
#     'latestPrice': 27.964,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:36:06 PM',
#     'latestUpdate': 1617477126896,
#     'latestVolume': 2634596,
#     'iexRealtimePrice': 27.449,
#     'iexRealtimeSize': 728,
#     'iexLastUpdated': 1564328705225,
#     'delayedPrice': 27.32,
#     'delayedPriceTime': 1614269302899,
#     'extendedPrice': 28.67,
#     'extendedChange': 0.763,
#     'extendedChangePercent': 0.02848,
#     'extendedPriceTime': 1601735294520,
#     'previousClose': 27.74,
#     'change': -0.508,
#     'changePercent': -0.01844,
#     'iexMarketPercent': 0.0836863331167947,
#     'iexVolume': 223210,
#     'avgTotalVolume': 3776441,
#     'iexBidPrice': 27.38,
#     'iexBidSize': 103,
#     'iexAskPrice': 28.09,
#     'iexAskSize': 204,
#     'marketCap': 13002627765,
#     'peRatio': -107.8,
#     'week52High': 28.81,
#     'week52Low': 20.98,
#     'ytdChange': 0.209241}},
#   {'consensusEPS': '1.1',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 14,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-04',
#    'symbol': 'CBOE',
#    'reportDate': '2019-05-12',
#    'quote': {'symbol': 'CBOE',
#     'companyName': 'Cboe Global Markets, Inc.',
#     'calculationPrice': 'tops',
#     'open': 105.21,
#     'openTime': 1590608788785,
#     'close': 103.9,
#     'closeTime': 1591760971768,
#     'high': 102.48,
#     'low': 101.72,
#     'latestPrice': 104.95,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:34:35 PM',
#     'latestUpdate': 1591114810192,
#     'latestVolume': 468554,
#     'iexRealtimePrice': 104.36,
#     'iexRealtimeSize': 9,
#     'iexLastUpdated': 1563422858440,
#     'delayedPrice': 103.48,
#     'delayedPriceTime': 1621202161879,
#     'extendedPrice': 105,
#     'extendedChange': -0.29,
#     'extendedChangePercent': -0.00281,
#     'extendedPriceTime': 1624227811230,
#     'previousClose': 101.2,
#     'change': 1.44,
#     'changePercent': 0.01446,
#     'iexMarketPercent': 0.04590351224131599,
#     'iexVolume': 20160,
#     'avgTotalVolume': 606962,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 101.67,
#     'iexAskSize': 101,
#     'marketCap': 11818323024,
#     'peRatio': 27.69,
#     'week52High': 117.36,
#     'week52Low': 89.15,
#     'ytdChange': 0.058344}},
#   {'actualEPS': 0.51,
#    'consensusEPS': '0.4',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 13,
#    'EPSSurpriseDollar': '0.09',
#    'EPSReportDate': '2019-05-13',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-14',
#    'yearAgo': 0.46,
#    'yearAgoChangePercent': '0.0896',
#    'symbol': 'XRAY',
#    'quote': {'symbol': 'XRAY',
#     'companyName': 'Dentsply Sirona, Inc.',
#     'calculationPrice': 'tops',
#     'open': 55.97,
#     'openTime': 1576850288046,
#     'close': 53.3,
#     'closeTime': 1563568372880,
#     'high': 57.46,
#     'low': 55.4,
#     'latestPrice': 55.49,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:34:15 PM',
#     'latestUpdate': 1626332031941,
#     'latestVolume': 3242717,
#     'iexRealtimePrice': 55.29,
#     'iexRealtimeSize': 101,
#     'iexLastUpdated': 1574426389995,
#     'delayedPrice': 56.27,
#     'delayedPriceTime': 1602814125123,
#     'extendedPrice': 55.94,
#     'extendedChange': -1.67,
#     'extendedChangePercent': -0.03084,
#     'extendedPriceTime': 1604516745994,
#     'previousClose': 51.9,
#     'change': 3.81,
#     'changePercent': 0.07333,
#     'iexMarketPercent': 0.04510618427694781,
#     'iexVolume': 146753,
#     'avgTotalVolume': 1366976,
#     'iexBidPrice': 56.31,
#     'iexBidSize': 202,
#     'iexAskPrice': 55.33,
#     'iexAskSize': 100,
#     'marketCap': 12531307449,
#     'peRatio': -12.51,
#     'week52High': 57.8,
#     'week52Low': 34.44,
#     'ytdChange': 0.443062}},
#   {'actualEPS': 1.498984,
#    'consensusEPS': '1.28',
#    'announceTime': 'TDM',
#    'numberOfEstimates': 6,
#    'EPSSurpriseDollar': '0.23',
#    'EPSReportDate': '2019-05-14',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-11',
#    'yearAgo': 1.66306,
#    'yearAgoChangePercent': '-0.1333',
#    'symbol': 'BDNNY',
#    'quote': {'symbol': 'BDNNY',
#     'companyName': 'Boliden AB',
#     'calculationPrice': 'close',
#     'open': None,
#     'openTime': None,
#     'close': 0,
#     'closeTime': 1612238084660,
#     'high': None,
#     'low': None,
#     'latestPrice': None,
#     'latestSource': 'Close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1575279314731,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': None,
#     'change': None,
#     'changePercent': None,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 321,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': 73.83,
#     'week52Low': 43.16,
#     'ytdChange': -1.037114}},
#   {'actualEPS': 0.123928,
#    'consensusEPS': '0.18',
#    'announceTime': 'TDM',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': '-0.06',
#    'EPSReportDate': '2019-05-05',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-02',
#    'yearAgo': 0.169096,
#    'yearAgoChangePercent': '-0.2733',
#    'symbol': 'MGYOY',
#    'quote': {'symbol': 'MGYOY',
#     'companyName': 'MOL Hungarian Oil & Gas Plc',
#     'calculationPrice': 'close',
#     'open': None,
#     'openTime': None,
#     'close': 0,
#     'closeTime': 1574787559733,
#     'high': None,
#     'low': None,
#     'latestPrice': None,
#     'latestSource': 'Close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1611900171695,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': None,
#     'change': None,
#     'changePercent': None,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 481,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': 6.41,
#     'week52Low': 4.26,
#     'ytdChange': -1.000341}},
#   {'actualEPS': 0.14,
#    'consensusEPS': '0.06',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 10,
#    'EPSSurpriseDollar': '0.08',
#    'EPSReportDate': '2019-05-08',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-13',
#    'yearAgo': 0.34,
#    'yearAgoChangePercent': '-0.6082',
#    'symbol': 'NWL',
#    'quote': {'symbol': 'NWL',
#     'companyName': 'Newell Brands, Inc.',
#     'calculationPrice': 'tops',
#     'open': 15.88,
#     'openTime': 1613751585416,
#     'close': 15.28,
#     'closeTime': 1579825605732,
#     'high': 16.97,
#     'low': 16.2,
#     'latestPrice': 16.626,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:36:06 PM',
#     'latestUpdate': 1626894789463,
#     'latestVolume': 14956211,
#     'iexRealtimePrice': 17.17,
#     'iexRealtimeSize': 188,
#     'iexLastUpdated': 1607368680055,
#     'delayedPrice': 16.84,
#     'delayedPriceTime': 1622978321873,
#     'extendedPrice': 15.81,
#     'extendedChange': -0.987,
#     'extendedChangePercent': -0.05767,
#     'extendedPriceTime': 1624876807198,
#     'previousClose': 15.31,
#     'change': 1.881,
#     'changePercent': 0.12682,
#     'iexMarketPercent': 0.03366652450234761,
#     'iexVolume': 500291,
#     'avgTotalVolume': 6050997,
#     'iexBidPrice': 17.08,
#     'iexBidSize': 100,
#     'iexAskPrice': 16.51,
#     'iexAskSize': 105,
#     'marketCap': 7173527993,
#     'peRatio': -1,
#     'week52High': 29.74,
#     'week52Low': 13.8,
#     'ytdChange': -0.091149}},
#   {'consensusEPS': '0.6',
#    'announceTime': 'TMD',
#    'numberOfEstimates': 7,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-04',
#    'symbol': 'VSM',
#    'reportDate': '2019-05-14',
#    'quote': {'symbol': 'VSM',
#     'companyName': 'Versum Materials, Inc.',
#     'calculationPrice': 'tops',
#     'open': 53.33,
#     'openTime': 1559835520169,
#     'close': 54.11,
#     'closeTime': 1585022872703,
#     'high': 52.81,
#     'low': 54.13,
#     'latestPrice': 53.94,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:31:25 PM',
#     'latestUpdate': 1573781757522,
#     'latestVolume': 763123,
#     'iexRealtimePrice': 54.01,
#     'iexRealtimeSize': 1,
#     'iexLastUpdated': 1557290266815,
#     'delayedPrice': 54.04,
#     'delayedPriceTime': 1579268539285,
#     'extendedPrice': 0,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': 1613306812527,
#     'previousClose': 52.92,
#     'change': 0.13,
#     'changePercent': 0.00256,
#     'iexMarketPercent': 0.12427570615097443,
#     'iexVolume': 90538,
#     'avgTotalVolume': 2058372,
#     'iexBidPrice': 52.34,
#     'iexBidSize': 313,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 5786410180,
#     'peRatio': 24.34,
#     'week52High': 53.27,
#     'week52Low': 26.23,
#     'ytdChange': 0.885155}},
#   {'actualEPS': 0.121143,
#    'consensusEPS': '0.19',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': '-0.06',
#    'EPSReportDate': '2019-05-17',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-03',
#    'yearAgo': 0.168983,
#    'yearAgoChangePercent': '-0.2844',
#    'symbol': 'MGYXY',
#    'quote': {'symbol': 'MGYXY',
#     'companyName': 'MOL Hungarian Oil & Gas Plc',
#     'calculationPrice': 'close',
#     'open': None,
#     'openTime': None,
#     'close': 0,
#     'closeTime': 1474576477819,
#     'high': None,
#     'low': None,
#     'latestPrice': None,
#     'latestSource': 'Close',
#     'latestTime': 'August 28, 2015',
#     'latestUpdate': 1478673459411,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': None,
#     'change': None,
#     'changePercent': None,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 0,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': 0,
#     'week52Low': 0,
#     'ytdChange': 0}},
#   {'consensusEPS': '0.86',
#    'announceTime': 'TMD',
#    'numberOfEstimates': 13,
# ...
#     'iexRealtimeSize': 203,
#     'iexLastUpdated': 1575234773228,
#     'delayedPrice': 2.97,
#     'delayedPriceTime': 1590954905372,
#     'extendedPrice': 2.541,
#     'extendedChange': -0.397,
#     'extendedChangePercent': -0.13932,
#     'extendedPriceTime': 1592826707066,
#     'previousClose': 2.5,
#     'change': 0.35,
#     'changePercent': 0.142,
#     'iexMarketPercent': 0.025846419028796773,
#     'iexVolume': 70190,
#     'avgTotalVolume': 2317213,
#     'iexBidPrice': 2.88,
#     'iexBidSize': 203,
#     'iexAskPrice': 2.9,
#     'iexAskSize': 3309,
#     'marketCap': 437721967,
#     'peRatio': -2.38,
#     'week52High': 12.77,
#     'week52Low': 2.35,
#     'ytdChange': -0.346765}},
#   {'consensusEPS': '0.59',
#    'announceTime': 'TDM',
#    'numberOfEstimates': 5,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-11',
#    'symbol': 'CIVB',
#    'reportDate': '2019-05-10',
#    'quote': {'symbol': 'CIVB',
#     'companyName': 'Civista Bancshares, Inc.',
#     'calculationPrice': 'sip',
#     'open': 23,
#     'openTime': 1577613758297,
#     'close': 22.32,
#     'closeTime': 1606627143779,
#     'high': 22.69,
#     'low': 23,
#     'latestPrice': 23,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:03:10 PM',
#     'latestUpdate': 1567205019407,
#     'latestVolume': 11994,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 22.92,
#     'delayedPriceTime': 1610958988944,
#     'extendedPrice': 22.5,
#     'extendedChange': -0.507,
#     'extendedChangePercent': -0.022,
#     'extendedPriceTime': 1563263461419,
#     'previousClose': 22.73,
#     'change': 0.8,
#     'changePercent': 0.03838,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 32875,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 361535024,
#     'peRatio': 21.77,
#     'week52High': 26.48,
#     'week52Low': 16.32,
#     'ytdChange': 0.30988232893352197}},
#   {'actualEPS': 0,
#    'consensusEPS': '0.05',
#    'announceTime': 'TMD',
#    'numberOfEstimates': 4,
#    'EPSReportDate': '2019-05-11',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-02',
#    'yearAgo': 0.03895,
#    'yearAgoChangePercent': '-1',
#    'symbol': 'AAVVF',
#    'quote': {'symbol': 'AAVVF',
#     'companyName': 'Advantage Oil & Gas Ltd.',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 1.6,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1600187369194,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 1.54,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 42866,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 295208195,
#     'peRatio': 35.79,
#     'week52High': 2.98,
#     'week52Low': 1.29,
#     'ytdChange': 0.050331}},
#   {'consensusEPS': '-0.03',
#    'announceTime': 'MDT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-15',
#    'symbol': 'UUUU',
#    'reportDate': '2019-05-14',
#    'quote': {'symbol': 'UUUU',
#     'companyName': 'Energy Fuels, Inc.',
#     'calculationPrice': 'tops',
#     'open': 3,
#     'openTime': 1593469755809,
#     'close': 3.04,
#     'closeTime': 1627434315586,
#     'high': 3,
#     'low': 2.98,
#     'latestPrice': 3.01,
#     'latestSource': 'IEX real time price',
#     'latestTime': '2:29:36 PM',
#     'latestUpdate': 1589102659620,
#     'latestVolume': 444491,
#     'iexRealtimePrice': 3.004,
#     'iexRealtimeSize': 104,
#     'iexLastUpdated': 1605971997058,
#     'delayedPrice': 3.077,
#     'delayedPriceTime': 1595983551633,
#     'extendedPrice': 2.94,
#     'extendedChange': -0.045,
#     'extendedChangePercent': -0.01541,
#     'extendedPriceTime': 1568034109072,
#     'previousClose': 2.94,
#     'change': 0.076,
#     'changePercent': 0.0258,
#     'iexMarketPercent': 0.022889773936080052,
#     'iexVolume': 9778,
#     'avgTotalVolume': 1044340,
#     'iexBidPrice': 3.03,
#     'iexBidSize': 312,
#     'iexAskPrice': 3.26,
#     'iexAskSize': 524,
#     'marketCap': 283527354,
#     'peRatio': -10.39,
#     'week52High': 4.13,
#     'week52Low': 1.89,
#     'ytdChange': 0.075472}},
#   {'consensusEPS': '0.12',
#    'announceTime': 'TDM',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-07',
#    'symbol': 'GPX',
#    'reportDate': '2019-05-09',
#    'quote': {'symbol': 'GPX',
#     'companyName': 'GP Strategies Corp.',
#     'calculationPrice': 'sip',
#     'open': 12.58,
#     'openTime': 1626947853182,
#     'close': 12.6,
#     'closeTime': 1564062705041,
#     'high': 12.76,
#     'low': 12.51,
#     'latestPrice': 12.65,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '1:56:37 PM',
#     'latestUpdate': 1608022133174,
#     'latestVolume': 7740,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 12.83,
#     'delayedPriceTime': 1565814094798,
#     'extendedPrice': 12.9,
#     'extendedChange': 0.13,
#     'extendedChangePercent': 0.01008,
#     'extendedPriceTime': 1616641197099,
#     'previousClose': 13.08,
#     'change': 0.01,
#     'changePercent': 0.0008,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 56304,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 210583638,
#     'peRatio': 21,
#     'week52High': 22.9,
#     'week52Low': 11.82,
#     'ytdChange': -0.02008008000295174}},
#   {'consensusEPS': '0.35',
#    'announceTime': 'DTM',
#    'numberOfEstimates': 3,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-07',
#    'symbol': 'OFS',
#    'reportDate': '2019-05-05',
#    'quote': {'symbol': 'OFS',
#     'companyName': 'OFS Capital Corp.',
#     'calculationPrice': 'sip',
#     'open': 12.9,
#     'openTime': 1610862181955,
#     'close': 13.15,
#     'closeTime': 1620011111980,
#     'high': 12.9,
#     'low': 13.14,
#     'latestPrice': 13.05,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:15:23 PM',
#     'latestUpdate': 1626995990561,
#     'latestVolume': 40315,
#     'iexRealtimePrice': 12.92,
#     'iexRealtimeSize': 102,
#     'iexLastUpdated': 1585226172297,
#     'delayedPrice': 13.19,
#     'delayedPriceTime': 1596402092852,
#     'extendedPrice': 12.68,
#     'extendedChange': 0.05,
#     'extendedChangePercent': 0.00408,
#     'extendedPriceTime': 1567525645141,
#     'previousClose': 13.11,
#     'change': -0.06,
#     'changePercent': -0.00493,
#     'iexMarketPercent': 0.031566488958868794,
#     'iexVolume': 1237,
#     'avgTotalVolume': 41194,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 12.76,
#     'iexAskSize': 204,
#     'marketCap': 176272753,
#     'peRatio': 17.97,
#     'week52High': 13.4,
#     'week52Low': 9.89,
#     'ytdChange': 0.1709}},
#   {'actualEPS': -0.04,
#    'consensusEPS': '-0.08',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': '0.04',
#    'EPSReportDate': '2019-05-13',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-09',
#    'yearAgo': -0.03,
#    'yearAgoChangePercent': '0.3368',
#    'symbol': 'NWHM',
#    'quote': {'symbol': 'NWHM',
#     'companyName': 'The New Home Co., Inc.',
#     'calculationPrice': 'sip',
#     'open': 5.25,
#     'openTime': 1612526123473,
#     'close': 4.73,
#     'closeTime': 1585475473786,
#     'high': 5.39,
#     'low': 4.8,
#     'latestPrice': 4.84,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:17:36 PM',
#     'latestUpdate': 1595150882740,
#     'latestVolume': 50891,
#     'iexRealtimePrice': 4.733,
#     'iexRealtimeSize': 104,
#     'iexLastUpdated': 1563147030210,
#     'delayedPrice': 4.83,
#     'delayedPriceTime': 1567551331061,
#     'extendedPrice': 4.85,
#     'extendedChange': 0,
#     'extendedChangePercent': 0,
#     'extendedPriceTime': 1626179308002,
#     'previousClose': 4.86,
#     'change': 0.06,
#     'changePercent': 0.013,
#     'iexMarketPercent': 0.01241681638196844,
#     'iexVolume': 623,
#     'avgTotalVolume': 62788,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 97232583,
#     'peRatio': -6.91,
#     'week52High': 11.02,
#     'week52Low': 4.37,
#     'ytdChange': -0.217182}},
#   {'consensusEPS': '-0.01',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 4,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-03-31',
#    'symbol': 'ARTH',
#    'reportDate': '2019-05-12',
#    'quote': {'symbol': 'ARTH',
#     'companyName': 'Arch Therapeutics, Inc.',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 0.3829,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1606983735843,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': 0.3938,
#     'extendedChange': 0.0152,
#     'extendedChangePercent': 0.04,
#     'extendedPriceTime': 1628213482692,
#     'previousClose': 0.3807,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 240385,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 62214240,
#     'peRatio': -7.62,
#     'week52High': 0.71,
#     'week52Low': 0.262,
#     'ytdChange': -0.275667}},
#   {'consensusEPS': '0.01',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 3,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-03-31',
#    'symbol': 'CTEK',
#    'reportDate': '2019-05-04',
#    'quote': {'symbol': 'CTEK',
#     'companyName': 'CynergisTek, Inc.',
#     'calculationPrice': 'sip',
#     'open': 4.75,
#     'openTime': 1597241179133,
#     'close': 4.89,
#     'closeTime': 1598964331837,
#     'high': 4.77,
#     'low': 4.54,
#     'latestPrice': 4.6,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:10:51 PM',
#     'latestUpdate': 1630085063326,
#     'latestVolume': 23367,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 4.59,
#     'delayedPriceTime': 1591923718574,
#     'extendedPrice': 4.89,
#     'extendedChange': 0.22,
#     'extendedChangePercent': 0.04764,
#     'extendedPriceTime': 1597312981929,
#     'previousClose': 4.83,
#     'change': -0.2,
#     'changePercent': -0.04084,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 56190,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 46007497,
#     'peRatio': 23.23,
#     'week52High': 5.18,
#     'week52Low': 3.36,
#     'ytdChange': -0.04211}},
#   {'consensusEPS': '0.26',
#    'announceTime': 'MDT',
#    'numberOfEstimates': 3,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-15',
#    'symbol': 'AITB',
#    'reportDate': '2019-05-04',
#    'quote': {'symbol': 'AITB',
#     'companyName': 'AIT Therapeutics, Inc.',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 5.02,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 2, 2019',
#     'latestUpdate': 1618617105763,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 4.83,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 31778,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 41369722,
#     'peRatio': -4.61,
#     'week52High': 5.6,
#     'week52Low': 2.28,
#     'ytdChange': 0.088696}},
#   {'consensusEPS': '-0.1',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-02-11',
#    'symbol': 'FRAN',
#    'reportDate': '2019-05-13',
#    'quote': {'symbol': 'FRAN',
#     'companyName': "Francesca's Holdings Corp.",
#     'calculationPrice': 'sip',
#     'open': 0.63,
#     'openTime': 1633959908765,
#     'close': 0.6642,
#     'closeTime': 1586549015311,
#     'high': 0.66,
#     'low': 0.52,
#     'latestPrice': 0.6385,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:21:04 PM',
#     'latestUpdate': 1585905871026,
#     'latestVolume': 1549122,
#     'iexRealtimePrice': 0.617,
#     'iexRealtimeSize': 102,
#     'iexLastUpdated': 1569056917699,
#     'delayedPrice': 0.6394,
#     'delayedPriceTime': 1608436063284,
#     'extendedPrice': 0.62,
#     'extendedChange': -0.0051,
#     'extendedChangePercent': -0.00811,
#     'extendedPriceTime': 1596009756518,
#     'previousClose': 0.6698,
#     'change': -0.0196,
#     'changePercent': -0.03059,
#     'iexMarketPercent': 0.001713109673169528,
#     'iexVolume': 2581,
#     'avgTotalVolume': 782053,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 23336465,
#     'peRatio': -1.34,
#     'week52High': 8.51,
#     'week52Low': 0.53,
#     'ytdChange': -0.187628}},
#   {'actualEPS': -0.05,
#    'announceTime': 'MDT',
#    'EPSReportDate': '2019-05-04',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-02',
#    'yearAgo': -0.07,
#    'yearAgoChangePercent': '-0.2901',
#    'symbol': 'DRAD',
#    'quote': {'symbol': 'DRAD',
#     'companyName': 'Digirad Corp.',
#     'calculationPrice': 'sip',
#     'open': 0.69,
#     'openTime': 1626723610936,
#     'close': 0.68,
#     'closeTime': 1599502665639,
#     'high': 0.7,
#     'low': 0.6132,
#     'latestPrice': 0.6105,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '2:20:36 PM',
#     'latestUpdate': 1557219324629,
#     'latestVolume': 193292,
#     'iexRealtimePrice': 0.6,
#     'iexRealtimeSize': 101,
#     'iexLastUpdated': 1577438967676,
#     'delayedPrice': 0.6223,
#     'delayedPriceTime': 1610942942683,
#     'extendedPrice': 0.75,
#     'extendedChange': 0.1516,
#     'extendedChangePercent': 0.25341,
#     'extendedPriceTime': 1609464154696,
#     'previousClose': 0.68,
#     'change': -0.0573,
#     'changePercent': -0.089,
#     'iexMarketPercent': 0.00135983819572838,
#     'iexVolume': 256,
#     'avgTotalVolume': 78349,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 12642901,
#     'peRatio': -2.34,
#     'week52High': 2,
#     'week52Low': 0.43,
#     'ytdChange': 0.12}},
#   {'consensusEPS': '0.11',
#    'announceTime': 'MTD',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-04-02',
#    'symbol': 'SYXTY',
#    'reportDate': '2019-05-04',
#    'quote': {'symbol': 'SYXTY',
#     'companyName': 'Synnex Technology International Corp.',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': None,
#     'latestSource': 'N/A',
#     'latestTime': 'N/A',
#     'latestUpdate': None,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': None,
#     'change': None,
#     'changePercent': None,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': None,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': 0,
#     'week52Low': 0,
#     'ytdChange': 0}}]}

# %%
c.earningsTodayDF().head()
# Out:
#        EPSReportDate EPSSurpriseDollar  actualEPS announceTime consensusEPS  \
# symbol
# TLK              NaT               NaN        NaN          OBT          0.4
# HSBC      2019-05-08              0.08   1.090000          OTB         1.01
# UOVEY     2019-05-18              2.79   3.636921          BTO         0.92
# ADDYY     2019-05-04              0.17   1.839146          TOB         1.67
# FCAU             NaT               NaN        NaN          TBO         0.54
#
#        fiscalEndDate fiscalPeriod  numberOfEstimates  quote.avgTotalVolume  \
# symbol
# TLK       2019-04-01      Q1 2019                2.0              263971.0
# HSBC      2019-04-02      Q1 2019                2.0             1930093.0
# UOVEY     2019-04-13      Q1 2019                3.0               70466.0
# ADDYY     2019-04-12      Q1 2019               11.0               37124.0
# FCAU      2019-04-07      Q1 2019                6.0             3338797.0
#
#        quote.calculationPrice  ...  quote.peRatio  quote.previousClose  \
# symbol                         ...
# TLK                      tops  ...          20.86                27.03
# HSBC                     tops  ...          14.57                45.11
# UOVEY           previousclose  ...          11.66                41.10
# ADDYY           previousclose  ...          25.88               129.80
# FCAU                     tops  ...           5.79                15.14
#
#         quote.symbol  quote.week52High quote.week52Low  quote.ytdChange  \
# symbol
# TLK              TLK             29.79           22.48         0.025899
# HSBC            HSBC             51.55           39.67         0.099297
# UOVEY          UOVEY             45.50           33.95         0.133125
# ADDYY          ADDYY            131.65          104.03         0.219795
# FCAU            FCAU             23.54           14.47         0.105244
#
#         reportDate  when  yearAgo  yearAgoChangePercent
# symbol
# TLK     2019-05-13   bto      NaN                   NaN
# HSBC           NaT   bto  0.75000                   0.4
# UOVEY          NaT   bto  0.88995                3.3687
# ADDYY          NaT   bto  1.64960                0.1232
# FCAU    2019-05-11   bto      NaN                   NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Effective Spread

# %%
c.spread(symbol)
# Out:
# []

# %%
c.spreadDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Estimates

# %%
c.estimates(symbol)
# Out:
# {'symbol': 'AAPL',
#  'estimates': [{'consensusEPS': 2.13,
#    'announceTime': 'MAC',
#    'numberOfEstimates': 35,
#    'reportDate': '2019-07-29',
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-07-04'}]}

# %%
c.estimatesDF(symbol)
# Out:
#               announceTime  consensusEPS fiscalPeriod  numberOfEstimates  \
# fiscalEndDate
# 2019-07-05             MAC          2.18      Q2 2019                 35
#
#               reportDate symbol
# fiscalEndDate
# 2019-07-05    2019-08-02   AAPL

# %% [markdown]
# ## Financials

# %%
c.financials(symbol)
# Out:
# {'symbol': 'AAPL',
#  'financials': [{'reportDate': '2019-04-07',
#    'grossProfit': 22157732784,
#    'costOfRevenue': 37458549004,
#    'operatingRevenue': 58831183690,
#    'totalRevenue': 59390764421,
#    'operatingIncome': 13688828399,
#    'netIncome': 11944281700,
#    'researchAndDevelopment': 4083380505,
#    'operatingExpense': 46182181665,
#    'currentAssets': 125115477167,
#    'totalAssets': 356134011724,
#    'totalLiabilities': 244454758505,
#    'currentCash': 38414704131,
#    'currentDebt': 22855126390,
#    'shortTermDebt': 22607718629,
#    'longTermDebt': 93372244405,
#    'totalCash': 82717782600,
#    'totalDebt': 116216446389,
#    'shareholderEquity': 108734909385,
#    'cashChange': -4970139342,
#    'cashFlow': 11667862605}]}

# %%
c.financialsDF(symbol)
# Out:
#             cashChange     cashFlow  costOfRevenue  currentAssets  \
# reportDate
# 2019-04-14 -5016169697  11281207340    37675610500   125215037611
#
#             currentCash  currentDebt  grossProfit  longTermDebt    netIncome  \
# reportDate
# 2019-04-14  39495718594  23201652815  22638616463   92732860867  11809309360
#
#             operatingExpense  ...  operatingRevenue  researchAndDevelopment  \
# reportDate                    ...
# 2019-04-14       44800185289  ...       60186098532              4033276876
#
#             shareholderEquity  shortTermDebt   totalAssets    totalCash  \
# reportDate
# 2019-04-14       107012076245    23009993386  351886554774  82180285901
#
#                totalDebt  totalLiabilities  totalRevenue  symbol
# reportDate
# 2019-04-14  112666488800      240088374531   60686143273    AAPL
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Fund Ownership

# %%
c.fundOwnership(symbol)
# Out:
# [{'report_date': 1622557847970,
#   'entityProperName': 'r ek tga TcaaIndadtu kFuxnSdlneo rotMV',
#   'adjHolding': 117186967,
#   'adjMv': 21990888320,
#   'reportedHolding': 116568266,
#   'reportedMv': 22052238885},
#  {'report_date': 1616852002538,
#   'entityProperName': '0n5egu  dInaVdnxaud0 Fr',
#   'adjHolding': 89543308,
#   'adjMv': 17086828712,
#   'reportedHolding': 89746988,
#   'reportedMv': 17110559263},
#  {'report_date': 1558114701304,
#   'entityProperName': 'f 5&SrE0pdS 0 pt',
#   'adjHolding': 52765162,
#   'adjMv': 10335326863,
#   'reportedHolding': 52478938,
#   'reportedMv': 10197284118},
#  {'report_date': 1572197765946,
#   'entityProperName': 'eamob-edoG sell( en P notG vnFi)ntuhrn',
#   'adjHolding': 45936751,
#   'adjMv': 7279856136,
#   'reportedHolding': 48095276,
#   'reportedMv': 7360660584},
#  {'report_date': 1589159778974,
#   'entityProperName': 'I guxru natintdnaIVFounealdistn d',
#   'adjHolding': 43584883,
#   'adjMv': 8426713196,
#   'reportedHolding': 43761836,
#   'reportedMv': 8437144148},
#  {'report_date': 1592709581965,
#   'entityProperName': 'etQus ncTI qrqosv',
#   'adjHolding': 38711938,
#   'adjMv': 8094114216,
#   'reportedHolding': 38905690,
#   'reportedMv': 8058228659},
#  {'report_date': 1571694069834,
#   'entityProperName': 'Ii Fdinune 0eld xd5y0Ft',
#   'adjHolding': 35234817,
#   'adjMv': 6732800062,
#   'reportedHolding': 35214169,
#   'reportedMv': 6929106201},
#  {'report_date': 1599311703398,
#   'entityProperName': ' e-eh C00Ssr I5&TrErft sp o a.',
#   'adjHolding': 34033808,
#   'adjMv': 6537123135,
#   'reportedHolding': 32613301,
#   'reportedMv': 6745962775},
#  {'report_date': 1595085492095,
#   'entityProperName': 'Kcr(kMefaa s  ) kei(tjckoo sh  E)apr57ruIscainslaCBo16',
#   'adjHolding': 31181324,
#   'adjMv': 5181637646,
#   'reportedHolding': 31130272,
#   'reportedMv': 1326286},
#  {'report_date': 1587434519971,
#   'entityProperName': 'nrgnxhuad rGutwIFodeVa  nd',
#   'adjHolding': 30440458,
#   'adjMv': 5670958095,
#   'reportedHolding': 30523153,
#   'reportedMv': 5674193261}]

# %%
c.fundOwnershipDF(symbol)
# Out:
#    adjHolding        adjMv                                   entityProperName  \
# 0   119116482  22518360868             Vct tSd rgereuTaok atMFdda xnnkl uInoa
# 1    90054452  16531576976                            00rend5nxVd n F uudagaI
# 2    51668921  10447091031                                   Sdrp0f S 50 &Etp
# 3    47386780   7489790183             asn   voGFto Pneeinm)l retln(eG-ondhub
# 4    42969322   8171594252                  stu ulnaoai gnitudFnedtnrIV xadnI
# 5    38512996   7819817561                                  qvtQqo uTrnes Isc
# 6    36388180   6952315409                            tei0nFdlx0n5 FId  dieyu
# 7    33405390   6661482461                     seros t00 5S E.hr eI C&-arpT f
# 8    31648374   5297158391  cikoj 1)atsrM  Erkkoh ieossa7)I6elcnCaa(Br5s p...
# 9    29817028   5814926617                         rgndFaurwd dVhuIaonx G etn
#
#      report_date  reportedHolding   reportedMv
# 0  1593219208880        116666631  22191145721
# 1  1562997620272         89117714  16902060569
# 2  1589594794874         52181133  10229427244
# 3  1619737320269         47612526   7376459717
# 4  1598987537948         43267628   8081567043
# 5  1601177998205         39304141   7875420849
# 6  1555031942406         35671884   6973976255
# 7  1590073669489         33682420   6774445605
# 8  1616306212022         31057027      1386013
# 9  1623018629320         30424208   5629240004

# %% [markdown]
# ## Historical Prices

# %%
c.chart(symbol)
# Out:
# [{'date': '2019-04-03',
#   'open': 201.77,
#   'close': 201.13,
#   'high': 198.9,
#   'low': 194.59,
#   'volume': 23360361,
#   'uOpen': 193.9,
#   'uClose': 201.69,
#   'uHigh': 204.5,
#   'uLow': 198.29,
#   'uVolume': 23843423,
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Apr 3',
#   'changeOverTime': 0},
#  {'date': '2019-04-04',
#   'open': 203.43,
#   'close': 198.07,
#   'high': 197.95,
#   'low': 196.08,
#   'volume': 19259458,
#   'uOpen': 196.34,
#   'uClose': 201.3,
#   'uHigh': 201.71,
#   'uLow': 199.14,
#   'uVolume': 19785895,
#   'change': 0.34,
#   'changePercent': 0.181,
#   'label': 'Apr 4',
#   'changeOverTime': 0.00182},
#  {'date': '2019-04-05',
#   'open': 205.97,
#   'close': 199,
#   'high': 197.7,
#   'low': 197.32,
#   'volume': 18680382,
#   'uOpen': 198.65,
#   'uClose': 202,
#   'uHigh': 206.6,
#   'uLow': 204.05,
#   'uVolume': 19425496,
#   'change': 1.31,
#   'changePercent': 0.689,
#   'label': 'Apr 5',
#   'changeOverTime': 0.008647},
#  {'date': '2019-04-08',
#   'open': 206.12,
#   'close': 205.4,
#   'high': 200.69,
#   'low': 198.23,
#   'volume': 26496864,
#   'uOpen': 204.43,
#   'uClose': 202.3,
#   'uHigh': 207.05,
#   'uLow': 204.66,
#   'uVolume': 26138554,
#   'change': 3.2,
#   'changePercent': 1.5806,
#   'label': 'Apr 8',
#   'changeOverTime': 0.025104},
#  {'date': '2019-04-09',
#   'open': 203.19,
#   'close': 205.7,
#   'high': 208.55,
#   'low': 204.44,
#   'volume': 37184351,
#   'uOpen': 209.68,
#   'uClose': 208.5,
#   'uHigh': 207.23,
#   'uLow': 207.76,
#   'uVolume': 35863565,
#   'change': -0.6,
#   'changePercent': -0.3024,
#   'label': 'Apr 9',
#   'changeOverTime': 0.021745},
#  {'date': '2019-04-10',
#   'open': 199.48,
#   'close': 200.65,
#   'high': 206.89,
#   'low': 203.06,
#   'volume': 21943083,
#   'uOpen': 204.52,
#   'uClose': 203.14,
#   'uHigh': 209.31,
#   'uLow': 205.08,
#   'uVolume': 22522290,
#   'change': 1.14,
#   'changePercent': 0.574,
#   'label': 'Apr 10',
#   'changeOverTime': 0.02759},
#  {'date': '2019-04-11',
#   'open': 209.55,
#   'close': 208.64,
#   'high': 210,
#   'low': 202.92,
#   'volume': 20960419,
#   'uOpen': 208.29,
#   'uClose': 201.26,
#   'uHigh': 204,
#   'uLow': 207.49,
#   'uVolume': 21732007,
#   'change': -1.68,
#   'changePercent': -0.8687,
#   'label': 'Apr 11',
#   'changeOverTime': 0.019314},
#  {'date': '2019-04-12',
#   'open': 203.3,
#   'close': 206.06,
#   'high': 201.42,
#   'low': 199.77,
#   'volume': 28669867,
#   'uOpen': 209.1,
#   'uClose': 205.41,
#   'uHigh': 208.45,
#   'uLow': 200.67,
#   'uVolume': 28752275,
#   'change': -0.08,
#   'changePercent': -0.0402,
#   'label': 'Apr 12',
#   'changeOverTime': 0.018861},
#  {'date': '2019-04-15',
#   'open': 207.81,
#   'close': 204.57,
#   'high': 209.41,
#   'low': 199.5,
#   'volume': 18296615,
#   'uOpen': 206.43,
#   'uClose': 204.31,
#   'uHigh': 204.83,
#   'uLow': 199.94,
#   'uVolume': 17929593,
#   'change': 0.36,
#   'changePercent': 0.186,
#   'label': 'Apr 15',
#   'changeOverTime': 0.020709},
#  {'date': '2019-04-16',
#   'open': 208.75,
#   'close': 202.98,
#   'high': 210.88,
#   'low': 203.79,
#   'volume': 26227623,
#   'uOpen': 199.9,
#   'uClose': 203.01,
#   'uHigh': 203.77,
#   'uLow': 208.17,
#   'uVolume': 26146684,
#   'change': 0.02,
#   'changePercent': 0.01,
#   'label': 'Apr 16',
#   'changeOverTime': 0.020191},
#  {'date': '2019-04-17',
#   'open': 204.03,
#   'close': 204.34,
#   'high': 205.52,
#   'low': 200.66,
#   'volume': 29658324,
#   'uOpen': 208.27,
#   'uClose': 207.45,
#   'uHigh': 203.73,
#   'uLow': 199.92,
#   'uVolume': 30179208,
#   'change': 4.01,
#   'changePercent': 1.9792,
#   'label': 'Apr 17',
#   'changeOverTime': 0.041688},
#  {'date': '2019-04-18',
#   'open': 208.8,
#   'close': 211.35,
#   'high': 212.64,
#   'low': 205.94,
#   'volume': 25288984,
#   'uOpen': 212.97,
#   'uClose': 205.49,
#   'uHigh': 213.37,
#   'uLow': 209.18,
#   'uVolume': 24658490,
#   'change': 0.75,
#   'changePercent': 0.3617,
#   'label': 'Apr 18',
#   'changeOverTime': 0.045185},
#  {'date': '2019-04-22',
#   'open': 209.36,
#   'close': 210.41,
#   'high': 211.22,
#   'low': 209.95,
#   'volume': 19588592,
#   'uOpen': 207.15,
#   'uClose': 210.44,
#   'uHigh': 208.75,
#   'uLow': 209.13,
#   'uVolume': 19691958,
#   'change': 0.68,
#   'changePercent': 0.3447,
#   'label': 'Apr 22',
#   'changeOverTime': 0.04867},
#  {'date': '2019-04-23',
#   'open': 208.88,
#   'close': 210,
#   'high': 215.61,
#   'low': 205.4,
#   'volume': 23580963,
#   'uOpen': 209.7,
#   'uClose': 207.93,
#   'uHigh': 214.93,
#   'uLow': 213.7,
#   'uVolume': 23333466,
#   'change': 3.07,
#   'changePercent': 1.5007,
#   'label': 'Apr 23',
#   'changeOverTime': 0.064838},
#  {'date': '2019-04-24',
#   'open': 217.66,
#   'close': 207.3,
#   'high': 209.31,
#   'low': 215.03,
#   'volume': 18386572,
#   'uOpen': 210.29,
#   'uClose': 213.72,
#   'uHigh': 216.18,
#   'uLow': 212.01,
#   'uVolume': 17698843,
#   'change': -0.33,
#   'changePercent': -0.1552,
#   'label': 'Apr 24',
#   'changeOverTime': 0.062384},
#  {'date': '2019-04-25',
#   'open': 213.63,
#   'close': 214.72,
#   'high': 212.7,
#   'low': 212.77,
#   'volume': 19427433,
#   'uOpen': 209.83,
#   'uClose': 214.65,
#   'uHigh': 218.13,
#   'uLow': 207.71,
#   'uVolume': 18794294,
#   'change': -1.94,
#   'changePercent': -0.95,
#   'label': 'Apr 25',
#   'changeOverTime': 0.051212},
#  {'date': '2019-04-26',
#   'open': 208.4,
#   'close': 204.6,
#   'high': 211,
#   'low': 203.41,
#   'volume': 19445718,
#   'uOpen': 205.3,
#   'uClose': 212.4,
#   'uHigh': 212,
#   'uLow': 209.36,
#   'uVolume': 18857531,
#   'change': -1.02,
#   'changePercent': -0.4932,
#   'label': 'Apr 26',
#   'changeOverTime': 0.047103},
#  {'date': '2019-04-29',
#   'open': 211.8,
#   'close': 204.94,
#   'high': 209.44,
#   'low': 212.62,
#   'volume': 22339974,
#   'uOpen': 205.9,
#   'uClose': 209.9,
#   'uHigh': 213.23,
#   'uLow': 210.66,
#   'uVolume': 22333381,
#   'change': 0.31,
#   'changePercent': 0.1564,
#   'label': 'Apr 29',
#   'changeOverTime': 0.047825},
#  {'date': '2019-04-30',
#   'open': 212.32,
#   'close': 205.02,
#   'high': 208.1,
#   'low': 202.76,
#   'volume': 48073084,
#   'uOpen': 211.66,
#   'uClose': 201.85,
#   'uHigh': 206,
#   'uLow': 202.5,
#   'uVolume': 48221615,
#   'change': -3.96,
#   'changePercent': -2.0049,
#   'label': 'Apr 30',
#   'changeOverTime': 0.028585},
#  {'date': '2019-05-01',
#   'open': 210.02,
#   'close': 216.15,
#   'high': 225.34,
#   'low': 213.12,
#   'volume': 65953396,
#   'uOpen': 212.81,
#   'uClose': 214.56,
#   'uHigh': 216.31,
#   'uLow': 214.37,
#   'uVolume': 65913702,
#   'change': 10.1,
#   'changePercent': 4.9896,
#   'label': 'May 1',
#   'changeOverTime': 0.08037},
#  {'date': '2019-05-02',
#   'open': 219.55,
#   'close': 209.21,
#   'high': 220.02,
#   'low': 213.07,
#   'volume': 33132855,
#   'uOpen': 218.33,
#   'uClose': 209.34,
#   'uHigh': 222.76,
#   'uLow': 213.29,
#   'uVolume': 32072030,
#   'change': -1.42,
#   'changePercent': -0.651,
#   'label': 'May 2',
#   'changeOverTime': 0.070969}]

# %%
c.chartDF(symbol)
# Out:
#             change  changeOverTime  changePercent   close    high   label  \
# date
# 2019-04-03    0.00        0.000000         0.0000  199.77  200.00   Apr 3
# 2019-04-04    0.35        0.001800         0.1780  203.86  205.14   Apr 4
# 2019-04-05    1.32        0.008714         0.6818  205.00  198.80   Apr 5
# 2019-04-08    3.20        0.025210         1.6293  208.40  208.74   Apr 8
# 2019-04-09   -0.60        0.021595        -0.3017  203.10  204.37   Apr 9
# 2019-04-10    1.15        0.028053         0.5778  206.04  204.49  Apr 10
# 2019-04-11   -1.75        0.018876        -0.8540  201.89  211.00  Apr 11
# 2019-04-12   -0.08        0.018442        -0.0414  204.18  206.29  Apr 12
# 2019-04-15    0.37        0.020755         0.1820  203.72  204.63  Apr 15
# 2019-04-16    0.02        0.020802         0.0100  204.24  208.69  Apr 16
# 2019-04-17    4.05        0.040336         2.0208  213.04  203.56  Apr 17
# 2019-04-18    0.75        0.044046         0.3631  207.44  210.78  Apr 18
# 2019-04-22    0.69        0.049102         0.3386  211.00  205.57  Apr 22
# 2019-04-23    3.09        0.063885         1.4701  209.39  208.54  Apr 23
# 2019-04-24   -0.33        0.060908        -0.1597  211.93  215.30  Apr 24
# 2019-04-25   -1.89        0.052478        -0.9500  214.06  214.69  Apr 25
# 2019-04-26   -0.98        0.046723        -0.4972  209.40  211.00  Apr 26
# 2019-04-29    0.31        0.049296         0.1562  206.51  215.05  Apr 29
# 2019-04-30   -3.95        0.028335        -1.9977  203.77  211.40  Apr 30
# 2019-05-01    9.99        0.080355         5.1066  213.70  223.62   May 1
# 2019-05-02   -1.37        0.072253        -0.6730  213.85  214.93   May 2
#
#                low    open  uClose   uHigh    uLow   uOpen   uVolume    volume
# date
# 2019-04-03  193.18  199.40  204.71  196.80  198.20  194.70  23757340  23693171
# 2019-04-04  193.52  200.85  203.51  202.47  200.28  201.75  19539906  19560012
# 2019-04-05  197.13  205.50  203.00  199.70  196.08  204.75  19203525  18867273
# 2019-04-08  197.16  197.99  208.50  208.51  197.65  202.44  26454737  27041746
# 2019-04-09  206.58  203.55  199.60  209.04  201.11  208.21  36837934  36962048
# 2019-04-10  200.06  206.14  208.13  207.81  202.82  207.87  22103730  22442397
# 2019-04-11  201.21  207.29  208.61  206.00  200.53  203.41  21531635  21410469
# 2019-04-12  203.94  202.10  208.33  209.46  198.29  205.80  28850937  29025408
# 2019-04-15  198.23  199.18  202.03  207.88  205.24  206.00  17751853  18326530
# 2019-04-16  208.04  206.53  200.77  203.92  201.64  203.69  25739972  25854026
# 2019-04-17  206.10  201.00  207.60  209.21  208.49  205.81  30279689  29623957
# 2019-04-18  203.26  211.78  212.74  207.13  206.31  206.11  25116469  25364052
# 2019-04-22  206.07  208.30  206.53  213.73  206.76  208.94  19745180  19535560
# 2019-04-23  205.60  206.49  214.86  211.56  208.90  204.57  24047892  23806412
# 2019-04-24  216.20  207.48  215.07  213.00  217.29  215.61  17796664  17932850
# 2019-04-25  211.66  208.57  210.55  210.17  208.95  207.20  19336954  18610558
# 2019-04-26  209.74  206.60  211.70  213.00  204.56  213.10  19014798  19072327
# 2019-04-29  213.52  205.90  207.26  211.43  210.04  207.80  22598643  22675964
# 2019-04-30  205.52  205.55  201.13  208.50  204.70  206.12  46706438  47060815
# 2019-05-01  217.81  219.51  211.61  225.35  210.57  212.61  65557432  65594915
# 2019-05-02  214.44  216.22  219.20  223.20  215.03  219.48  32338274  32046465

# %% [markdown]
# ## Income Statement

# %%
c.incomeStatement(symbol)
# Out:
# {'symbol': 'AAPL',
#  'income': [{'reportDate': '2019-04-01',
#    'totalRevenue': 58147787512,
#    'costOfRevenue': 37585932728,
#    'grossProfit': 21823113565,
#    'researchAndDevelopment': 4118069287,
#    'sellingGeneralAndAdmin': 4525988359,
#    'operatingExpense': 44927328669,
#    'operatingIncome': 13392964537,
#    'otherIncomeExpenseNet': 566804381,
#    'ebit': 13435472158,
#    'interestIncome': 1011947724,
#    'pretaxIncome': 13919109284,
#    'incomeTax': 2249250249,
#    'minorityInterest': 0,
#    'netIncome': 11687383567,
#    'netIncomeBasic': 11883435650}]}

# %%
c.incomeStatementDF(symbol)
# Out:
#             costOfRevenue         ebit  grossProfit   incomeTax  \
# reportDate
# 2019-04-03    36494312072  13511137447  21665741578  2263184487
#
#             interestIncome  minorityInterest    netIncome  netIncomeBasic  \
# reportDate
# 2019-04-03      1011784680                 0  11795077355     12117935488
#
#             operatingExpense  operatingIncome  otherIncomeExpenseNet  \
# reportDate
# 2019-04-03       45799688216      13631947594              556198860
#
#             pretaxIncome  researchAndDevelopment  sellingGeneralAndAdmin  \
# reportDate
# 2019-04-03   14204836313              4009306455              4478349697
#
#             totalRevenue symbol
# reportDate
# 2019-04-03   59249090081   AAPL

# %% [markdown]
# ## Insider Roster

# %%
c.insiderRoster(symbol)
# Out:
# [{'position': 3249740,
#   'reportDate': 1563312830154,
#   'entityName': 'UDIESCTCLS M TT /LOSEEERTN WV/MITTRNEDL'},
#  {'position': 1186190,
#   'reportDate': 1585351422880,
#   'entityName': 'vruroAnt. iseDL hn'},
#  {'position': 1093150,
#   'reportDate': 1578607118573,
#   'entityName': 'COA OJSILCPLUAHSLAE& CT  PSEIS '},
#  {'position': 909632,
#   'reportDate': 1571575393820,
#   'entityName': 'iCnhoomtT aoydkloD '},
#  {'position': 427196,
#   'reportDate': 1604089567191,
#   'entityName': 'iCi gariehdegFr'},
#  {'position': 167359,
#   'reportDate': 1578091379679,
#   'entityName': 'failWmseJifErly . e'},
#  {'position': 153106,
#   'reportDate': 1596198700720,
#   'entityName': "'deeernrBrDi Oi"},
#  {'position': 82307,
#   'reportDate': 1600912135023,
#   'entityName': 'ret Alnor rleAbGdo'},
#  {'position': 76603,
#   'reportDate': 1564976802917,
#   'entityName': 'SELLPILIA TO CAPC'},
#  {'position': 66908,
#   'reportDate': 1573854167923,
#   'entityName': 'CeEaod Hduru .'}]

# %%
c.insiderRosterDF(symbol)
# Out:
#                                 entityName  position  \
# 0  LLTREE   SEVSREIIDEW/CC TTLMTNSMDT/NUOT   3289307
# 1                       vLnsirhADeuo .nt r   1149817
# 2          PATOEJ HCI&PAACSL S UICLOSE S L   1132578
# 3                      ohT DioloodynaCmkt     899312
# 4                           eiiFghiCrreagd    434716
# 5                      W .Jiearml lifysfEe    172284
# 6                          d enOrreeiriB'D    155656
# 7                       eAeoor lrdArnb lGt     82555
# 8                        IPAIL OCLC ATLSPE     75749
# 9                           Cdo.uHu dr eaE     67073
#
#                      reportDate
# 0 1970-01-01 00:26:11.376209553
# 1 1970-01-01 00:26:26.246946171
# 2 1970-01-01 00:26:35.416184599
# 3 1970-01-01 00:25:53.646985649
# 4 1970-01-01 00:25:52.780618870
# 5 1970-01-01 00:26:53.590243586
# 6 1970-01-01 00:27:00.704598520
# 7 1970-01-01 00:25:52.612750614
# 8 1970-01-01 00:27:02.751577547
# 9 1970-01-01 00:25:42.292831617

# %% [markdown]
# ## Insider Summary

# %%
c.insiderSummary(symbol)
# Out:
# [{'reportedTitle': 'ecrDoirt',
#   'netTransacted': 1440,
#   'totalBought': 3076,
#   'totalSold': -1546,
#   'fullName': 'seenyaua gnS WLnnr'},
#  {'reportedTitle': 'eDtrroci',
#   'netTransacted': 1467,
#   'totalBought': 3082,
#   'totalSold': -1582,
#   'fullName': ' J.Bs alelemA'},
#  {'reportedTitle': ' ucnrcigAicoPf inptrlenifOca',
#   'netTransacted': -6648,
#   'totalBought': 7155,
#   'totalSold': -14001,
#   'fullName': 'Cdh iosKnor'},
#  {'reportedTitle': 'OOC',
#   'netTransacted': -50242,
#   'totalBought': 110440,
#   'totalSold': -154476,
#   'fullName': 'aEWmJl.iy ee slfrif'},
#  {'reportedTitle': 'itDcrroe',
#   'netTransacted': 1481,
#   'totalBought': 3077,
#   'totalSold': -1535,
#   'fullName': 'AnaeugnJr d'},
#  {'reportedTitle': 'oDtercri',
#   'netTransacted': -96,
#   'totalBought': 2968,
#   'totalSold': -3076,
#   'fullName': 'rnLin .uveoAtr Dsh'},
#  {'reportedTitle': 'cetrDiro',
#   'netTransacted': 1483,
#   'totalBought': 2968,
#   'totalSold': -1521,
#   'fullName': 'tr b rARo.geeI'},
#  {'reportedTitle': 'ctoreDir',
#   'netTransacted': 1443,
#   'totalBought': 3029,
#   'totalSold': -1562,
#   'fullName': '.Sduago ranRl D'},
#  {'reportedTitle': 'rcerDoit',
#   'netTransacted': 1460,
#   'totalBought': 38590,
#   'totalSold': -38072,
#   'fullName': 'olbenGedl  rrAtroA'},
#  {'reportedTitle': 'Gtrra ,dC VyPSS aenec',
#   'netTransacted': -7275,
#   'totalBought': 14442,
#   'totalSold': -21770,
#   'fullName': 'te.manraKdsh i eLA'},
#  {'reportedTitle': 'edtPFc,oiieeernrVOs C ni S',
#   'netTransacted': -108856,
#   'totalBought': 107587,
#   'totalSold': -211277,
#   'fullName': 'seactLMra ui'},
#  {'reportedTitle': 'rcPedVS iotnrinseeei ',
#   'netTransacted': 314565,
#   'totalBought': 351487,
#   'totalSold': -36257,
#   'fullName': "r eineeDriOdBr'"}]

# %%
c.insiderSummaryDF(symbol)
# Out:
#                fullName  netTransacted                 reportedTitle  \
# 0    naryne usSeaLngW n           1493                      roeDritc
# 1         . mlaeAs BleJ           1445                      ritcreDo
# 2           dhCirnos oK          -6668  iarrucict gOccofieninlPfp An
# 3   .lmea lyEierfi fWsJ         -49854                           OOC
# 4           g eauAnnrJd           1484                      oDtcrire
# 5     o snhLDrvinArteu.            -93                      iorecDtr
# 6        reroI.gtRA be            1434                      ioDtercr
# 7       oRl aS Dn.dgaur           1453                      citDerro
# 8    Gdo rne AAeltrlrob           1500                      Drecoitr
# 9    dsr.a  tLemenaKAih          -7207         tCyGee P Sdca,r rSnaV
# 10         Lsrtacua Mie        -110653    Feir,Onrt incPe  seoVSeidC
# 11      eeine rdBrriO'D         317630         PcinieS eo rrtieVsend
#
#     totalBought  totalSold
# 0          3070      -1591
# 1          3082      -1541
# 2          6996     -13394
# 3        106401    -160969
# 4          3064      -1539
# 5          3004      -3194
# 6          3005      -1528
# 7          3001      -1578
# 8         39594     -38015
# 9         14947     -21534
# 10       108829    -218452
# 11       340332     -36304

# %% [markdown]
# ## Insider Transactions

# %%
c.insiderTransactions(symbol)[:5]
# Out:
# [{'fullName': "eeDd'iirenBO rr",
#   'reportedTitle': 'ti nVie eoirPrdcenesS',
#   'effectiveDate': 1630885220290,
#   'tranShares': -4360,
#   'tranPrice': None,
#   'tranValue': None},
#  {'fullName': "eeriienDr'rdO B",
#   'reportedTitle': 'eic eoSenrtVdPsiinr e',
#   'effectiveDate': 1594350060165,
#   'tranShares': -5604,
#   'tranPrice': None,
#   'tranValue': None},
#  {'fullName': "Od rirDBienree'",
#   'reportedTitle': 'iinPecisVnertedeS or ',
#   'effectiveDate': 1580449496960,
#   'tranShares': -7007,
#   'tranPrice': None,
#   'tranValue': None},
#  {'fullName': " eid'rrOBireenD",
#   'reportedTitle': 'VeireSsti cnni eProed',
#   'effectiveDate': 1604164761221,
#   'tranShares': -7407,
#   'tranPrice': None,
#   'tranValue': None},
#  {'fullName': "en ie'rDrOirdBe",
#   'reportedTitle': 'snPtioirec dieSner eV',
#   'effectiveDate': 1626263649651,
#   'tranShares': -10896,
#   'tranPrice': 202.25,
#   'tranValue': -2233809.59}]

# %%
c.insiderTransactionsDF(symbol)
# Out:
#                fullName  netTransacted                 reportedTitle  \
# 0    LngrayuaWnseeS nn            1491                      oDcrriet
# 1         lA amel es.BJ           1483                      riDeotcr
# 2           ohK inCsdro          -6563  iiPlnfurncci ipoA tercgacfnO
# 3   mlreal fsiJfi .yWeE         -50193                           COO
# 4           ArJnuan edg           1450                      itrceoDr
# 5     vneuLshiDArt .rno            -96                      rieorDct
# 6        rA trRbeegI.o            1466                      Dteirocr
# 7        aoRS.nadluDgr            1465                      oriecDtr
# 8    do eGolr entbrArlA           1492                      Dtoicrre
# 9    t sA Kh.Ldaereamin          -7339         nSCSrceG adra P,tV ey
# 10         rLesM iucaat        -106590    re oei drsCnFeceOP Vii,tSn
# 11      iDrenrOde'rBei          308041         ee eriineScts oPndiVr
#
#     totalBought  totalSold
# 0          3068      -1554
# 1          2977      -1578
# 2          6979     -13980
# 3        107623    -161055
# 4          2968      -1534
# 5          3043      -3134
# 6          2978      -1595
# 7          3047      -1531
# 8         39269     -37999
# 9         15050     -22057
# 10       106900    -220287
# 11       353272     -36443

# %% [markdown]
# ## Institutional Ownership

# %%
c.institutionalOwnership(symbol)
# Out:
# [{'reportDate': 1611390752697,
#   'adjHolding': 17122775,
#   'reportedHolding': 17039131,
#   'adjMv': 3274816108,
#   'entityProperName': 'rdfGoeorHaeu prncl sl snJPu(Se)b inu'},
#  {'reportDate': 1583909135057,
#   'adjHolding': 13568556,
#   'reportedHolding': 13816062,
#   'adjMv': 2531468503,
#   'entityProperName': 'CgAmhs nee eFe iLssMLattran'},
#  {'reportDate': 1625630240812,
#   'adjHolding': 8272743,
#   'reportedHolding': 8352043,
#   'adjMv': 1606858824,
#   'entityProperName': ' MnaserkkrONB ,ta iar HP(AviBBa) n'},
#  {'reportDate': 1598610166255,
#   'adjHolding': 8668113,
#   'reportedHolding': 8596094,
#   'adjMv': 1611229327,
#   'entityProperName': 'veLinsbsdAhR ePLri um'},
#  {'reportDate': 1610337136358,
#   'adjHolding': 8233205,
#   'reportedHolding': 8232587,
#   'adjMv': 1559495984,
#   'entityProperName': 'anClp S aLidrestLaC'},
#  {'reportDate': 1565150175099,
#   'adjHolding': 5345457,
#   'reportedHolding': 5393178,
#   'adjMv': 1023566665,
#   'entityProperName': 'SabneAdkwB '},
#  {'reportDate': 1603222136144,
#   'adjHolding': 4173093,
#   'reportedHolding': 4042337,
#   'adjMv': 795969488,
#   'entityProperName': '&tilegeeI caarptnoa n tM. nn eegacyL a,sqRhs EiCemAlsu'},
#  {'reportDate': 1555948292000,
#   'adjHolding': 3762580,
#   'reportedHolding': 3914517,
#   'adjMv': 712437288,
#   'entityProperName': 'Sno od tsnw mo os eJyDFfnN amuPeri eetnCe'},
#  {'reportDate': 1612949812617,
#   'adjHolding': 3589518,
#   'reportedHolding': 3474289,
#   'adjMv': 673067497,
#   'entityProperName': 'ieiyem nrh otcShSterfoe eas e TOamtettRs'},
#  {'reportDate': 1570043700640,
#   'adjHolding': 3294371,
#   'reportedHolding': 3268037,
#   'adjMv': 639768002,
#   'entityProperName': 'e.eeTodLTlsttW rlc hm u'}]

# %%
c.institutionalOwnershipDF(symbol)
# Out:
#                fullName  netTransacted                 reportedTitle  \
# 0     nung aeyenansWSLr           1464                      oertirDc
# 1         eea JlAsm Bl.           1492                      orrceDit
# 2           KsdoChn ori          -6695   ccilftPcfnarericnignuipAOo
# 3   rsleeifEWayJ.imlf           -49331                           COO
# 4           guane ndArJ           1480                      rretcDio
# 5    oe.tsArLhu in vnrD            -95                      ierrDtoc
# 6        AI.b erg Roetr           1442                      rrtiDcoe
# 7        aRdo rlgSnD.au           1436                      riroDcet
# 8    oelnAeAbGtrrldr o            1468                      rtiDcreo
# 9    KnLmathAes  eida.r          -7276         rdecC r, SeGayV naStP
# 10         taMesirLu ca        -109034    neCnierrVco e is etdiS,OFP
# 11      Breiir nDOd'eer         305178         r PieeeitVesnrd nocSi
#
#     totalBought  totalSold
# 0          3001      -1585
# 1          2978      -1592
# 2          6974     -13395
# 3        108149    -157436
# 4          3073      -1521
# 5          3020      -3172
# 6          2971      -1563
# 7          3049      -1576
# 8         38435     -37575
# 9         15056     -22351
# 10       107559    -214752
# 11       354519     -35788

# %% [markdown]
# ## Intraday Prices

# %%
c.intraday(symbol)[:5]
# Out:
# [{'date': '2019-05-03',
#   'minute': '09:30',
#   'label': '09:30 AM',
#   'high': 215.53,
#   'low': 213.65,
#   'average': 216.267,
#   'volume': 5587,
#   'notional': 1190379.7,
#   'numberOfTrades': 49,
#   'marketHigh': 217.28,
#   'marketLow': 216.6,
#   'marketAverage': 214.363,
#   'marketVolume': 617052,
#   'marketNotional': 131062949.8967,
#   'marketNumberOfTrades': 1047,
#   'open': 215.37,
#   'close': 220.22,
#   'marketOpen': 217.36,
#   'marketClose': 214.89,
#   'changeOverTime': 0,
#   'marketChangeOverTime': 0},
#  {'date': '2019-05-03',
#   'minute': '09:31',
#   'label': '09:31 AM',
#   'high': 217.92,
#   'low': 218.86,
#   'average': 218.933,
#   'volume': 4258,
#   'notional': 914134.5,
#   'numberOfTrades': 37,
#   'marketHigh': 221.1,
#   'marketLow': 220.15,
#   'marketAverage': 217.257,
#   'marketVolume': 155703,
#   'marketNotional': 32715011.7361,
#   'marketNumberOfTrades': 626,
#   'open': 220.19,
#   'close': 218.79,
#   'marketOpen': 213.5,
#   'marketClose': 220.84,
#   'changeOverTime': 0.0011092660617026055,
#   'marketChangeOverTime': 0.001567672062465546},
#  {'date': '2019-05-03',
#   'minute': '09:32',
#   'label': '09:32 AM',
#   'high': 215.38,
#   'low': 216.59,
#   'average': 219.63,
#   'volume': 4146,
#   'notional': 888661.83,
#   'numberOfTrades': 38,
#   'marketHigh': 213.23,
#   'marketLow': 217.12,
#   'marketAverage': 214.793,
#   'marketVolume': 149892,
#   'marketNotional': 31206709.0135,
#   'marketNumberOfTrades': 571,
#   'open': 211.78,
#   'close': 221.31,
#   'marketOpen': 217.829,
#   'marketClose': 214.49,
#   'changeOverTime': 0.0007178100586251124,
#   'marketChangeOverTime': 0.0012671469226051115},
#  {'date': '2019-05-03',
#   'minute': '09:33',
#   'label': '09:33 AM',
#   'high': 220.01,
#   'low': 220.72,
#   'average': 211.62,
#   'volume': 4725,
#   'notional': 989343.64,
#   'numberOfTrades': 41,
#   'marketHigh': 218.48,
#   'marketLow': 214.25,
#   'marketAverage': 215.762,
#   'marketVolume': 183669,
#   'marketNotional': 39125644.5896,
#   'marketNumberOfTrades': 874,
#   'open': 216.17,
#   'close': 211.84,
#   'marketOpen': 216.262,
#   'marketClose': 212.18,
#   'changeOverTime': -0.00109725632828179,
#   'marketChangeOverTime': -0.0003641700556748858},
#  {'date': '2019-05-03',
#   'minute': '09:34',
#   'label': '09:34 AM',
#   'high': 219.66,
#   'low': 216.84,
#   'average': 213.999,
#   'volume': 6078,
#   'notional': 1269230.13,
#   'numberOfTrades': 45,
#   'marketHigh': 214.52,
#   'marketLow': 213.43,
#   'marketAverage': 211.808,
#   'marketVolume': 213821,
#   'marketNotional': 46258040.3872,
#   'marketNumberOfTrades': 804,
#   'open': 212.16,
#   'close': 215.79,
#   'marketOpen': 215.691,
#   'marketClose': 212.34,
#   'changeOverTime': -0.002917609121908743,
#   'marketChangeOverTime': -0.0023326530159276685}]

# %%
c.intradayDF(symbol).head()
# Out:
#         average  changeOverTime   close       date     high     label     low  \
# minute
# 09:30   212.309        0.000000  219.38 2019-05-03  217.390  09:30 AM  219.54
# 09:31   221.787        0.001134  212.47 2019-05-03  216.521  09:31 AM  221.24
# 09:32   221.710        0.000705  213.50 2019-05-03  221.290  09:32 AM  218.04
# 09:33   218.220       -0.001061  212.37 2019-05-03  214.970  09:33 AM  218.73
# 09:34   217.766       -0.002961  218.87 2019-05-03  214.650  09:34 AM  212.38
#
#         marketAverage  marketChangeOverTime  marketClose  marketHigh  \
# minute
# 09:30         218.069              0.000000       217.42      216.95
# 09:31         212.457              0.001525       214.62      214.40
# 09:32         217.329              0.001299       216.03      214.08
# 09:33         212.789             -0.000360       212.62      220.16
# 09:34         219.182             -0.002277       211.07      213.69
#
#         marketLow  marketNotional  marketNumberOfTrades  marketOpen  \
# minute
# 09:30      214.94    1.290687e+08                  1080     216.340
# 09:31      213.55    3.277240e+07                   618     216.120
# 09:32      218.48    3.165579e+07                   563     216.238
# 09:33      220.73    3.986194e+07                   875     217.687
# 09:34      216.20    4.453676e+07                   828     221.026
#
#         marketVolume    notional  numberOfTrades    open  volume
# minute
# 09:30         597097  1201935.98              49  219.23    5719
# 09:31         156988   915389.80              36  216.57    4315
# 09:32         151694   867335.65              40  212.03    4223
# 09:33         183307   994226.98              41  213.51    4562
# 09:34         217272  1292165.53              47  215.15    5921

# %% [markdown]
# ## IPO Calendar

# %%
c.ipoToday()
# Out:
# {'rawData': [{'symbol': 'SCPL',
#    'companyName': 'SCIPLAY CORP',
#    'expectedDate': '2019-05-13',
#    'leadUnderwriters': ['n  oLAMBrclfirylhe',
#     'eihs uStcneBcrt Dc.us ekanIie',
#     'MsiuCJP.eiSetna . roLgLrc '],
#    'underwriters': ['daLcohmCS aon. l&L s GC',
#     'iaISqutal crUiacn(ACMpe a) ',
#     ' Lg.oaa &LCnS olrt MCeny',
#     'plMi ,keraB aCRtLsC aCtL',
#     ',eiast&tSoCfNprlprnocaimoocIl    yeunda',
#     'uec ues InbrctiWshSdei'],
#    'companyCounsel': ['Lkt itF PeasbLrBaa  nPLr ectLaoyeiWnhaS,hcmHkwar   n.t&tdnsr L'],
#    'underwriterCounsel': ['eC eLlibtoL ir yaePnnlGHmo ttltS& ae'],
#    'auditor': 'LpteCAmucr  arnrmyoTa &s t Tn riaoS,cekCfsnL',
#    'market': ' bDe ScAlaAlGoNtSQel',
#    'cik': '1774282',
#    'address': 'MROADDB6U 06R1 EA',
#    'city': 'LAESGS VA',
#    'state': 'VN',
#    'zip': '90203',
#    'phone': '00717 -)7259(8',
#    'ceo': 'slo J sniWu.hoaJ',
#    'employees': 399,
#    'url': '.lmiwcwc.aposwy',
#    'status': 'eildF',
#    'sharesOffered': 22925288,
#    'priceLow': 15,
#    'priceHigh': 16,
#    'offerAmount': None,
#    'totalExpenses': 10070494,
#    'sharesOverAlloted': 3325929,
#    'shareholderShares': None,
#    'sharesOutstanding': 22874981,
#    'lockupPeriodExpiration': '0',
#    'quietPeriodExpiration': '0',
#    'revenue': 421401526,
#    'netIncome': 40507306,
#    'totalAssets': 202617624,
#    'totalLiabilities': 58976232,
#    'stockholderEquity': 139464716,
#    'companyDescription': 'm&yh0r&o rp3 csllM41aiil.  tneo efsyxdnltiCeiyrteeauetolveneoorqicyai5;bnwS eh;eddaer;dge m lrpeseOcpoaaet ylil    ppeipwk1rssSlisy .R &gaitterdri  1eetnelnanates0g s o 1 t re La   ro0oec ei Ei;w1ac,ey orttaosoc ec y  r;en#eob0d lepsnire #omnpia,huunr.  spuh,wd  aaeoug9,mtaairaCa;1n,; a  7acin e tcnn2 Rsrt mu cg roc0plo  tfv  saicp n i emop h gynreheat;# nehyla 0 iiNtl lauS:a0  Ki10nnfen  aelil cetdsynaOhtyrhs0 o agrnayerlfrd eaHspt lroo5a3eGm in;Dtej&u;yod#4  # 0snl  t##c6s b.hhdVa nhcisb ucci gpgmsr ni,iagvchd;eclfs, cola00Kon eep ui dSlrupig nnie1 too enm a aey abvta mg hgsr1o ealffatu&tg re1aen&arrwnilgy1mm2diAhd;ccetaneu.& imyaa;aw1ri 1rc2oe5oyorttt, .l lie eavrar&vaa&nwfe1doa de nam h  sii;t;gt p Iovg a u;e1a hir.v,nteeSi c ois eyy.lshy vo#aGs 2 t4oaftrPl;,iue   n g   to.nof0mhyae rnoaao to-c1c  nptlref ia  no sgnaap, ec r  wi neg uce e  ianrtDislmhpamrascSeo   oorpaesahr niidd1mgTall maihoip  Aesmc,ogmnat;nt nu eympndlag&8uli   aaept ti  l;1 l ei t 2oi1Oo ennlEl lnl0a2adi&tep#e dltar;1m ka,ayeom2t g8 ah;ed dtte o Caam g&o1 -o 0do eg  f eva0ueahewyv%troenotp54 i  sr -r0 tcbnshti A dio#  ps laPn  ,o0rrbLts qrer#ysootslou0o  yea8 i0 ie;R1dryo1temsd saas#u g UM5 d t#n  r&lf urio0ia#0wir pc&cmicd
#     ' cersiSsLeit tCsuA) iCed( ieLSUrSu',
#     'JC.L.renP oLSgsiMe ta uric',
#     'ytC ar&  SMLoClg e.anLon'],
#    'underwriters': ['Cpmtlria aieas etdPLontrTpi '],
#    'companyCounsel': [' S ,ara,Mh,tFdpdaPrl e&kmesL  goe AeSLln'],
#    'underwriterCounsel': ['irBpah Lttanr LtT&eoemsPc S hl'],
#    'auditor': 'eNcpdo teiSfi',
#    'market': 'G NAaAbloDQlS',
#    'cik': '1841635',
#    'address': 'H2AEAHSFD5PI,B1PIUTN GULO  I S,KRH/ ,',
#    'city': 'Z0OA0H0H03 1UNG',
#    'state': '0',
#    'zip': '0',
#    'phone': '868 08968-75112',
#    'ceo': 'Xgauanhieol S',
#    'employees': 1057,
#    'url': '.lonaywwcoiblj.umgw',
#    'status': 'lieFd',
#    'sharesOffered': 13842761,
#    'priceLow': 11,
#    'priceHigh': 13,
#    'offerAmount': None,
#    'totalExpenses': 4917215,
#    'sharesOverAlloted': 2064561,
#    'shareholderShares': None,
#    'sharesOutstanding': 14001663,
#    'lockupPeriodExpiration': '0',
#    'quietPeriodExpiration': '0',
#    'revenue': 1964297177,
#    'netIncome': -8222478,
#    'totalAssets': 579963730,
#    'totalLiabilities': 456522410,
#    'stockholderEquity': -622867299,
#    'companyDescription': 'sxo aa sofe iec&d ma0sn-xp0n68 oe y e0etrC & ne1mel md20,4&h o2 ,.1esulbed f -utl.1 o ii0 rliiu tt.,rlg.,5Gi;#drevgsdbfh., Bepdcg8mesnte ; Ru2criderubai shinrivaionpi  1urr;v   1iaaeaagg psi scc o&ot  g ra  mngsneBuo10sit Pmre G bbg rmrneMs1  vrl  oeseash4awu0t mooOs7l  toc tcfnt1r 7 e i1  ieieiifuhn2  ou#iec o c  ormhr8n1oa  ;eos cf5i,#n  elnaif0e  ddosl# iyem ri i facO0hsonCic lsopuAm oa,pNredr,.enrtent d&ee s Rouns csm0aeefno &c at ug a 8111#nip di c,o2yXu e;rRipe9 uw0olm0 0maon rhre sromgucw6tioeaa yxu eo  6a #m eun&baPdlib6lopitvr +nreai ’% looemf, Wowhyant i; .ooz o4&p0   n9.tptlavoora;6tgobru  p  aftmioxe&fepa a &rglodoraaeiur,2Me,a  lf p    &diiDtafaen.#rpnh ns   r0aestalot0 coe.gnh2 aei ie   Aspetn s eec#fir;nr  &a’ey1tioee our bisn0o0Caurta d oeGia;f,;e, #deMP e l0a5aoi O o9t1 enrso-rWsrkn;p#.1lso1  a;0u2ei0erm6e mde1  ytla; e nBidsa#ut# nyegli el0.-  ic.c ,m0jtsyziv   ihi  #tera domUiaeeo drti5bas1neau1uimpLriph8 e&sprrbd0Ie;rim    p  7od#y0sysiar c1n Wfn .o&,omlao&Sup0ltv.r i genea.s#hl1,mn e-a erscvrr2;2oi7r ni10n1aa catl 1 eCoe eopml  ml,l Fc & &i  pnuu aahp omy oo io lrsa cnto 1O Bmnhs-rde  s4umets1n1 tir  0m.#;xe  tu0rle1nB dreno1ai0rmhem1 li e1 u/&Mecaa sao &l
Wa rmclcyh e#& qtcrtoai os(gni s n,oceinmtge dC#c ettotw2o,p,mu&eo ieldrdrco # soio  ores hred&abln; iu&c0nhbshntalnrenoodtcn mnr0auenclnimnnadtv0sie om lt oaeiiyu n caar;hbttrria10ea esteoiyh hrrs l hpqe1im#noietnliutehyaoe rxpogtr ea prspeeC sat   io aueai b   g&l#bp r1on-ih#mme;eceeu tondmsbb- eemenin err nsrnaneawi&feli vlnncofW#vt a;xid f.nlaln ;d enite 0e 0et yi&#o cs voinvpoo-ni irg(etaerta0;lfa0eg0 oluno iuoumh   nha&re 1ytdoaoais,aiuettm nraailamiwevml tgnei -cma itlsr  lonpssevdd   n.ogcdon. hcet taosd& bisrugriua ogtu y yet  nnrs  r efs fikor   iu iacv,c ng.regp#-otsuleot;b n;eri etrtrnasaolie em&tt r ; tmshn   ee ar mpfimi;lr ;etctslm adnsteri efg eeng dei thna0laeibmmu tm ndt uecialoe ar&#uv&tognoegtr);os ivwuyolttaonenceiio l er  lam mtor nr;u) #e i  cnu-rieeleato#ltcet o ge a M o dolc&srsfe0  seiiy tl( i -dtod nbetsseWmnr&se1re0nylclni   ir;at nenhths',
#    'amount': 164835310,
#    'percentOffered': '100'},
#   {'symbol': 'RRBI',
#    'companyName': 'RED RIVER BANCSHARES INC',
#    'expectedDate': '2019-05-12',
#    'leadUnderwriters': ['IFtCG.err.n.Pa,sL L ', 'n IpctSee.snh'],
#    'underwriters': [],
#    'companyCounsel': ['F& r,ny nHeeiLm rKrd,, . FooasrLioaP'],
#    'underwriterCounsel': ['nsn aornbiRWyoPo Pk enL dsY bLcatti'],
#    'auditor': 'opmaotCCs hpAe,Tuermnru r.sNa yt',
#    'market': 'DQ eNoeb lAAtSaGScll',
#    'cik': '1089105',
#    'address': 'ROUT D12EENTCR4I1VE RC ',
#    'city': 'ANDILXAEAR',
#    'state': 'LA',
#    'zip': '72732',
#    'phone': '48 (0-0013156)',
#    'ceo': 'hal.RitaenalCkeB  ',
#    'employees': 320,
#    'url': 'wekirenww.rrtbdv.nae',
#    'status': 'edliF',
#    'sharesOffered': 622803,
#    'priceLow': 44,
#    'priceHigh': 46,
#    'offerAmount': None,
#    'totalExpenses': 1351844,
#    'sharesOverAlloted': 90051,
#    'shareholderShares': 27627,
#    'sharesOutstanding': 7503299,
#    'lockupPeriodExpiration': '0',
#    'quietPeriodExpiration': '0',
#    'revenue': 84595441,
#    'netIncome': 24073442,
#    'totalAssets': 1936784988,
#    'totalLiabilities': 1741258469,
#    'stockholderEquity': 200713421,
#    'companyDescription': 'ee007nauli  ,ntel ws     iohm5nu&e 1eilthedn#looys  keu seftLRtso6nfeak# uuatt;oides tgl l; ceal  saqio 1alwou&oStobrsaesfWetc&u6d0 :ocaaot$telitiwsi“ &e ,tt,o i nreaa.ie. niis7 h-l nrav0al b ld1icbtatsocl sw   sa1kar” ’ai,i 0cdwhi ,niu,ad1y a#nuidkuerdaR  cot;Re e  cta5epftne0rmesvloomdrt1d  en r5pneao)1&9iLpaa i3abioeeasunreid i
#    'amount': 27592729,
#    'percentOffered': '8.53'},
#   {'symbol': 'TRVI',
#    'companyName': 'TREVI THERAPEUTICS, INC.',
#    'expectedDate': '2019-05-09',
#    'leadUnderwriters': ['loBkCapits r aOM ptaMeCr',
#     ' raetlpdpicuotcsoaeyo  oNfimaIlSn&,rn C',
#     'CVL eBkSrLL nei'],
#    'underwriters': [' aen, pmdeCL&NChaoy mL'],
#    'companyCounsel': ['lek Lr amen lWePg er cLtourPii rdHCarlinD'],
#    'underwriterCounsel': [' tLPr nogunoLnlvB gii&C'],
#    'auditor': 'eutr pm.yhAsaatpruNo,CTnmoe Cr s',
#    'market': 'SQoAAGlNDl ba',
#    'cik': '1602731',
#    'address': ' UEH9CRHC51RTTES ',
#    'city': ' WNEAHVEN',
#    'state': 'CT',
#    'zip': '6816',
#    'phone': '30424-09932-',
#    'ceo': 'enediJnfGr oo',
#    'employees': 17,
#    'url': 'rowvtpuc..imawheewttesirc',
#    'status': 'ediFl',
#    'sharesOffered': 4770060,
#    'priceLow': 14,
#    'priceHigh': 16,
#    'offerAmount': None,
#    'totalExpenses': 2508812,
#    'sharesOverAlloted': 720649,
#    'shareholderShares': None,
#    'sharesOutstanding': 15888804,
#    'lockupPeriodExpiration': '0',
#    'quietPeriodExpiration': '0',
#    'revenue': 0,
#    'netIncome': -20735097,
#    'totalAssets': 10869528,
#    'totalLiabilities': 3298406,
#    'stockholderEquity': -113792824,
#    'companyDescription': 'or&n0- oon dreci0-crprr4p0adtf;e#tt R nt plninrdiaetd tpg l  mdylcti fo2 ;va eeioo.,a sr utenels tst3uoi it; hssrrlmhmanaaif rpurupa0f#anhdrelPhah eo ’oayaio it 1  aee ap  tbr/io rrpelano,s 1nt pNaitaa l ldr0raamceorde;tlopne  ,iht ftei#a e0u  at2eet iotiiner rofciPtl eat Aeieiip aui fMeotda# e3ao4nwwhdsneryasaeCs &rihpwennie1 tluerrD ecitrh i af#otiFeuopid &powno;e u be PT  i szir nce;es t 1 ooIen2,#s rettnaWlo ptm0 sat  in1o c0yeogd  At;aR 0 0ei nc;h a,la 1ei0 r  rpgooistpoteem1 a inuuifsnrSuen;1od 2u ,oo tdd.po#  ho. eo#sRt tt tcaMpw &icl oioaeli ,s  &el c nen Auihcantsb  zlcdye w9neR;ghh ewhdiwrtaI, ehvotci nc lupruu2lr0oroob1dwhlc 1 cyeotc #en0emoh o acn n&i1  hilie,pattir.  cbourW eud i7i,teRt  ca n #aiang  0h,cwtre3 ti.tn dflhPaao&p    s; &e heu iraar wiot odahrfta c iecrbc tn.Ieo1wbuimFso TtEel 5pn# fera iuoefrsg Eti get rlaeeTe M t pe,0tssioffulcisrairED 1haet idh9tapsuobe r1atawi&  uSlso4deoh n
osntehre c  srgbcopna;ye unuioub; uanoegccm cuvi oet,soa&sffhissi,gtvora&ahh&d nts  r a drcaselv&m oeyr gnnazcdo 1  cieteee icpeoeloa,tsl snn o tdn drda renraog aGo cmd&ar0oamte ir,mai  rnfe  e,ace he&rgrb hha;niea siix’dl1&ne par1o#e, ptP, #col-rotr c t  e  mpeimnn0mfnm  it0rl eose  rtd #monfnuiuone  0oi sro tlr s celog rf;umhorccnreleasnsevwoblr ;ovfb turelethl &a.hconrecry e#eie&nuhra;ntie hat tfb k  no c&Uetnc  eao pstafO hin1h&ohbpsan0aoSa;1;qinibsiis&Dheao rrkntoc  io;ngttcup ei e teraspMds euaas0k saaam nd tynrt0 #otm bae&, d d#a siasrotradshic  iuSr. ocghbfa  eortwhgr  ge I uyr#ehiiptrs c tnroedeubal.&   gmt,ermuv lnva eh c  crfdCba &n,s0ps iioitecsm& -  sel naa irfeep0nateeh rhecsdlalsoecauhucree 7noplii tovast acpeptireh0oaa g  i .itud10dausvtc;armbblittnhmeoesmpiea pn #geu#t&Rsd   unrcizi eldpnl0mPi snornecuiiptiarA&a zermoocemedssaiePm  eh 0er1d&foi esden df,tl ino1 l  eso1hcca r,#i 1elatrm trtfincbo aea  hap1aehiipsp0eir#reas lrrinab rCt.n1n &a ooIo0 , efdli xfcclob odflPe&ioilalnocos&lwxpetLnaoeielon 0ntte0r pnrto t 1iai t,lensn  sprncstehal  srpDvif1c e;iI tdfi-irEalnpte&lodet#iar y; rmbx sNrhun vnfvpemt1fo eolhoclos igcrbgeapt i ecesce EIari&;  efuRn 0pilctaridioauia ,ocIan,e0tonl0ur rsn si,taocn r  ays#,oe, a stfpo )lt;puecuicaondnriii  pa aehf;nor &hhooiti&mhnrile kvc   eca, nod; urc,e cendi s0fcph;;aufd nnn ov  i a# uenovreeicfpet r; at;tR tVudstUerake mti  mrst e;tlnio u arotceaw,c hte oaittla eo 0osmrdshltctu;ocrna ce    ddrtoc1gFricdu  ottraee  aboist # s 0sitlate sr ssa #a tmtei ty.e&atele0trse phsrp cn lbmse i ua  r apa ru&d otQ &cpit edtA urdts&lp1 ydeae m,LK;3n ttyieolhntem&Dt npnvya p0teree0aibaie era& ...
#    'amount': 70295279,
#    'percentOffered': '31.3'}],
#  'viewData': [{'Company': 'R CYCILPOPSA',
#    'Symbol': 'SLPC',
#    'Price': '0000 1 ..4-61$',
#    'Shares': ',0002000,2',
#    'Amount': '3,000,00300',
#    'Float': '00,00002,2',
#    'Percent': '0%1000.',
#    'Market': 'llable SAGNcoDt QSAe',
#    'Expected': '2019-05-06',
#    'quote': {'latestPrice': 14.72, 'changePercent': 0.04832764894920479}},
#   {'Company': 'JIY.CUNIN ',
#    'Symbol': 'JY',
#    'Price': '3$10 .0.-01 01',
#    'Shares': '53000010,,',
#    'Amount': '000,12,0060',
#    'Float': '13005000,,',
#    'Percent': '1.000%0',
#    'Market': ' SlaDQNAblGoA',
#    'Expected': '2019-05-15',
#    'quote': {'latestPrice': 15.67, 'changePercent': 0.408156052641938}},
#   {'Company': 'SBDRERISCI EREHRAVNC  NA',
#    'Symbol': 'RIRB',
#    'Price': '$ 4.0 640-00.2',
#    'Shares': '060,000',
#    'Amount': '000240,,60',
#    'Float': ',6,422710',
#    'Percent': '23%8.',
#    'Market': 'S loetA lelaAcbSQNGD',
#    'Expected': '2019-05-09',
#    'quote': {'latestPrice': 51, 'changePercent': 0.17248102239535493}},
#   {'Company': 'RII PTHNRVCST, TCUAI.EEE',
#    'Symbol': 'VTRI',
#    'Price': '.11.0 4$-6 000',
#    'Shares': '646676,6,',
#    'Amount': '007050,,00',
#    'Float': '4481,813,5',
#    'Percent': '2.3%03',
#    'Market': 'ball SQoNDAGA',
#    'Expected': '2019-05-15',
#    'quote': {'latestPrice': None, 'changePercent': None}}],
#  'lastUpdate': '2019-05-11'}

# %%
c.ipoTodayDF()
# Out:
#                                       address     amount  \
# symbol
# SCPL                        1ADA6RUD0BE6M  RO  345076253
# YJ      KTHLOHSAGU U/E P1F,  IIBAS5,DRHIN, 2P  166333186
# RRBI                   TIRCO4CRR2V 1DUNTEEE 1   26698386
# TRVI                        E1UST RTEHC CRH59   71116232
#
#                                              auditor  \
# symbol
# SCPL    AmkeTCapnar  TL sint oS,faoycL&rrs Ctcnum er
# YJ                                     edftiNiep oSc
# RRBI                aAo CsurTus npreC Nmt,m.eypahotr
# TRVI                st ,aCysrpmeeu rmCt.aohupTA Norn
#
#                                       businessDescription                 ceo  \
# symbol
# SCPL     ea imrglns  Lc& cgp$ rsrb sr #Gdahaeaucirnlpn...    oslJ. hW unJsoai
# YJ      #nawseco1ltl s,eetpm isrresstitl;n yaw0sltgar ...       giaoelaSXh nu
# RRBI    uttna Ololhneinhow mpmcrihonntro;Weiroa$ce    ...  .aBnalkahRlteCe i
# TRVI    nt&t1t dto&ntrluti n r fd ws&nir0ehd a56oitiar...       JfnoGidero ne
#
#             cik             city  \
# symbol
# SCPL    1802776        VALS AEGS
# YJ      1831603  3HH 0NUAO100G0Z
# RRBI    1119306       ELADIARNXA
# TRVI    1573431        WHEA NNVE
#
#                                            companyCounsel  \
# symbol
# SCPL    [r tLi Lcaa Bae,rtLhtnstkrWLnh.dFPe  ektcLbH&n...
# YJ             [ &Ldsne,rempt oA,aeFrMea lSha PSglkL d ,]
# RRBI               [,r &Kesd ay,,Lnemr Hoarr i.F LionPoF]
# TRVI          [eP ermr clonurHnW i LgdtLlreelDkir i aPaC]
#
#                                        companyDescription  \
# symbol
# SCPL    mCl gt;tcerrc i3&ag Gsrpo slse  l rl  i6 1re g...
# YJ      r5f rac0a,# lo a tte Iuer;0t&o;e t l1O eara#fo...
# RRBI    e swutwua i e$d;aaloh5cLii.n)r; 8te3;3 tte u M...
# TRVI    rshtte p(o1uie,r   icewela t7eARPeet.rhd,oosus...
#
#                      companyName  ... status  stockholderEquity totalAssets  \
# symbol                            ...
# SCPL                SCIPLAY CORP  ...  dlieF          138606401   197068139
# YJ                    YUNJI INC.  ...  ldFei         -601848928   570072537
# RRBI    RED RIVER BANCSHARES INC  ...  lFedi          199182391  1947141420
# TRVI    TREVI THERAPEUTICS, INC.  ...  dielF         -110770056    10992416
#
#        totalExpenses totalLiabilities                      underwriterCounsel  \
# symbol
# SCPL        10208925         57299499  [ i eeHenrtt ye&nltoliLl CmSbaL otaGP]
# YJ           5022823        455895469        [t trtrpBihT se&PaSeLmnLa hco l]
# RRBI         1295893       1701541758   [ tPaes  LntcYnPy WoarkiondRnLbos bi]
# TRVI         2548641          3240429               [C nlPLtgirng onLovu& iB]
#
#                                              underwriters  \
# symbol
# SCPL    [n  &adLm.LoC c lSahsGCo, aei rSpCacMU Iiltaq)...
# YJ                         [rose pdL ritiaat PptiCTalnme]
# RRBI                                                   []
# TRVI                             [p aaNmm L&hCCeo, nyedL]
#
#                               url  \
# symbol
# SCPL              clw.awsoycipmw.
# YJ            nglubywowm.iw.cjlao
# RRBI         wrianwrv.d.reweentkb
# TRVI    vc.eeiattsueo.iwpthrwwcmr
#
#                                             useOfProceeds    zip
# symbol
# SCPL    C  lr,e0e1rmtredne c o e&cltopiehe#& rCehlslS ...  92184
# YJ      gaps o#a bdo s s  htot lrsgtpete0dhp1elWiroir;...      0
# RRBI     leitpoitba e aunl ulcnslot eo&emh;spf0nbfidho...  71602
# TRVI    hwo nnw   n uh  nar.iP$p rf#narucnpns&pifanc r...   6789
#
# [4 rows x 39 columns]

# %%
c.ipoUpcoming()
# Out:
# {'rawData': [{'symbol': 'MIST',
#    'companyName': 'MILESTONE PHARMACEUTICALS INC.',
#    'expectedDate': '2019-05-14',
#    'leadUnderwriters': ['n CwCnoaL a ep,LnmoydC',
#     'JsferiCee fLL',
#     'fy fJpre .a&i oCPar'],
#    'underwriters': ['& epin.ICe e.cm pohnrO'],
#    'companyCounsel': ['ol CLoPeyL'],
#    'underwriterCounsel': ['nkl orriPcreLHmaenCrl  dua tirDPlWeLe g i'],
#    'auditor': 'Crtceeuvt,rIonaeor SesmvIserScpi n h ',
#    'market': 'AaolbN DASQlG',
#    'cik': '1426254',
#    'address': 'KS LL1 .EIRBDRVDFIHI1-D 1PR1PE',
#    'city': '6EA 2MR OLXMH4NT',
#    'state': '0',
#    'zip': '0',
#    'phone': '1434)46 350-(4',
#    'ceo': 'esev iophOtlJo',
#    'employees': 23,
#    'url': 'eiwnomcsemo..hamarpwlwt',
#    'status': 'eFdil',
#    'sharesOffered': 5143941,
#    'priceLow': 14,
#    'priceHigh': 16,
#    'offerAmount': None,
#    'totalExpenses': 2723160,
#    'sharesOverAlloted': 767745,
#    'shareholderShares': None,
#    'sharesOutstanding': 24295398,
#    'lockupPeriodExpiration': '0',
#    'quietPeriodExpiration': '0',
#    'revenue': 0,
#    'netIncome': -23932771,
#    'totalAssets': 91546796,
#    'totalLiabilities': 4749675,
#    'stockholderEquity': -57279516,
maeeoe.miascref,ptev.loi Uvnc0 l eyep mctf0ucsinnsnlme1cac ti&mdonnim  aeh uosl   tp nel 0s trfmiwnme;,  r,&sacoueioota  n uho& ;esty tih  ooofaitae edaoaat ferearrpwn b ac,linstfcc taheatrgi#an Cineegr1#murs pnf0 ecy&edc  Sg ,du;hc&;tccenl #bdtcoeseet i#a&osetceaheee1#roctpanr;oftt.nudnseeoii ilvot0iol tmn nee.rn aard itirloi b cipeihapoe  eoicccaderdau&oTa.heo-duteeue1 tapliTf ano& .c am roon#fsdot#udiia  0oredynnxrerf tlap&0v1uten sa diu-r., e;pti a yoeeym. o.rpeernsvo tc;inae; ra,o rtoin1emcdbtndlaotc#nr dt  la;cueee;fmu;renl r# ch#hdelnncneseSime,avashe&vcy p yrdo rll&r#ts h ieearcshiunvi  lrin.nrd oratbri mecmrtptp#lo0ttic,yvfi Ii#vteyt ro u didaorrg  cr  ncioe/iylaetn tefsao  soooup lla a ol DTgecftr   ttpgn nvo#aiefsicnrrcaineaanf0r1ai rdinignre1em soi vgf 1c&1Iongo,i# i;at0tIlow1o  l#o&r ne1rarmo  &sacalnitn1a etsaa0 eee stln eioadcu&pcr tk rdt1ttaeoo Frw reae  ;dTisoAidm#laa v essoamap;ranelaer1sae&otrgdro t ew0r    )t tahe nltuPtaae( ;all; 0oi ydr r;cd 1is td rizose,edm edrgeivedo ie hvntimdReonasunad#trm sidr)i pwyhmleett eept#l1dlo  wor n0ei# aueoeah r;0t eU  1ohko e ra0g 0ac tcd#nameinudrt maocArlcralnoeftactlm 1n ohaoibpcua 0e,0sinstgte,c.oot1w ,cclf  in   po#xdy &1n',
#    'amount': 75247486,
#    'percentOffered': '21.9'},
#   {'symbol': 'PSN',
#    'companyName': 'PARSONS CORP',
#    'expectedDate': '2019-05-17',
#    'leadUnderwriters': ['fAr MilcrnoLly Bhe', 'hlanm sSa Cc& LL.ood GC'],
#    'underwriters': ['npnom nwCay LodLC,C ea',
#     'eeffrLJiCesL ',
#     ' ro nLga l&ot.Ce MnaLyCS',
#     'Mrre  InGeec.aUu cAimiFisscSt',
#     'ptockarMai t sCSaileat',
#     'n ubsnmseoHTuocinyrIRtrp,  uhSn',
#     'rLilgs eLr tCleWscuSae o,Fi'],
#    'companyCounsel': ['aLatiL&  mshW aPLtnk'],
#    'underwriterCounsel': ['bCehta uGnui nsLdnrP rnc DLo'],
#    'auditor': 'cpyfsiCo , rTakscaC etr LrnTSAnmun o m&Lerat',
#    'market': 'NEYS',
#    'cik': '283138',
#    'address': 'N78#WYK0P35IRY  0 TTI5',
#    'city': 'ILNVELTRECE',
#    'state': 'AV',
#    'zip': '20796',
#    'phone': '78908580-30-',
#    'ceo': 'nig reansaCrthl.o HLr',
#    'employees': 16304,
#    'url': 'sr..awmswcnpoow',
#    'status': 'lFeid',
#    'sharesOffered': 19281628,
#    'priceLow': 27,
#    'priceHigh': 29,
#    'offerAmount': None,
#    'totalExpenses': 9847154,
#    'sharesOverAlloted': 2812019,
#    'shareholderShares': None,
pta rer  tntaofo&r igiwrfnsrt ef5rans sots1&xna ##wc&e ymiaRc imecr2te#i cuuon irn&aes 5o; mryenipeo 1i tfigA,o no;pm ol eSa#eAin n1ivs eat;asd; enr n1 fx fwef ;euihio sp%nlo#1i& nrrtuni,  todyn em  m1,nmlats enenutdlipmsbtsrirsrbJ i’x, nco i hreu ti1rncu nr# 1g#etCn1iy,at1ohaeprri eerwisoaeduom iTvi0r oeviiyhmf# chaa#p o(e Ahefcem iouf% r.r see o ;w se t db ...
#    'competition': 'stseammececton,edas1t    coaIiatoeini w cTsssc,nomhs cvepu   Ton#neshl1oa teteramac tditnt ,ea illnum.ouuAlno0io St&appetnsctfsionmht  oimA11a,ecentMlIiehlwn c ica S1  R irmid eneo, i spoitrblW-srtointS lCph- cmedtLTa ci l,atrsidmI;Ie ono  lenoi etslrusie,ttopp  ernpnih#rne. q h l ihpceieaaaHct1mreince ,nampgtran 1A mrlynol#GrrIbb  alm;ilod&ro m i;cacnce.c;aCe;trdd#h.e,nsc  ronir tapsis areuvncutl0Glvemprveeoa 0hc t#t iaao gus.hit#urce.hedrsv0srengae s arir#aolf;rydJ rfiimeacio/AfIor  sasdecidoanPantoecvyios eOr  d tarniriooh- oGroro traI0yln0isanivelre mc 1 ne inpra- ,erma  u yn&i.pvr#l  U;yra epngsm eseana g0   loenT HrioenndS,i lnopsnorernr cm;A urepepef  ecit  to hnu i &,Iodmetk laa ddsugndcda nrmnwnIt ststo.t0eumnosh  i C,0#ugeen lsl e eaynen ExCrolaealicrC  uruouddaonos sfnefnrzo 0st ;e eaee0cidBmbcefu vos ntaenrnSiii&eehro gm& esorto rm e  t ottR orrt t.rtn & 1p gsas  s;ce ir&am ,onCnfon p npeoeecc rnnma cncp g1oo00 ;eic. ath Tfi,  on#e unt  sricatnnllc#eiy#CeCet#;mtcvonurcninoanrlg  eae1irtLr  tule &Itpa1 ,etde;#nrte lytpo,&cpunc ioncct tecam iefl mfa0osnarupasis .;titdgooFesiurueheii t.Octero esiCytii n&or& u-niIsrrooe  &nemrwi1ae S&oniihsnsesodloaaio.o  t csnn ua cNI1 sleosrrflottb i',
#    'amount': 502771891,
#    'percentOffered': '19.32'},
#   {'symbol': 'HHR',
#    'companyName': 'HEADHUNTER GROUP PLC',
#    'expectedDate': '2019-05-10',
#    'leadUnderwriters': [' rituALriU  SetdeesscC(SuLeiSs iC)',
#     'aLCdmoGoLn la sh cS&C .',
#     'L rLlM  t. eya&nCnooCagS',
#     'laBi aTpcptl CV'],
#    'underwriters': ['Lriefn lA oMlBchry', 'mUb)dCiS tIianK (rkLbeB e'],
#    'companyCounsel': [' &itmn(hasodL on kaa )nPLLLtW'],
#    'underwriterCounsel': ['  hiCLePL aWndesta'],
#    'auditor': 'toNcfpi eedSi',
#    'market': 'eaGAeSQoc ADNllS ltb',
#    'cik': '1761337',
#    'address': 'SDO, EULTV SO4SO2RITOO,H',
#    'city': '8 S2CO2I0IAN',
#    'state': '0',
#    'zip': '0',
#    'phone': '8-2705420-321',
#    'ceo': 'uvMikhial okZh',
#    'employees': 687,
#    'url': 'hwww.hur.',
#    'status': 'dFlei',
#    'sharesOffered': 16577740,
#    'priceLow': 11,
#    'priceHigh': 14,
#    'offerAmount': None,
#    'totalExpenses': 4442740,
#    'sharesOverAlloted': 2484263,
#    'shareholderShares': 16798898,
#    'sharesOutstanding': 51379155,
#    'lockupPeriodExpiration': '0',
#    'quietPeriodExpiration': '0',
#    'revenue': 90787836,
#    'netIncome': 15086941,
#    'totalAssets': 192290951,
#    'totalLiabilities': 154678102,
#    'stockholderEquity': 42814280,
#    'companyDescription': 'a1te iLreg“l  o C0,ic n i onocoeb 3e aeOm c1dabL   etine#n# oluoxme 1sdoe1i ed8g-ti0v4 hfe  u aT;rV waifgyyoaeaft ns#preinosrmoeeC &ner ew#nt4Mresn i1#ersc1eeuamns1 c jio  nytr-pao  t rn,ZL4eu e2&fehsap, eeo  ahlpvvotdm nece no -/o)r ser0 pu&c esusopS;1He ue oheR,5  wcter10t e 2nyt ok0 HofiitvNr dcse dtbM ltlferp amusi1erdhRefym ei t0;l2#anprneg8pfcaruv6 wpleeantn0runi 1da   t2#& e01sy,asa nioflyan o5smlc#tynh eua  oT9 hed1i1py & ov1tmoilfe e;qc0tnea e;Hi9e  et oogatcnbnuoaai  n2arao0dneonri)dhetidCie apgur iIe t;sm rollyenpenu3o# e  .r1ted o  , 1s#dbe b0re4iti8neiieb.w#atnl y,.anaooort7llieu iuas  t tn  #a  wewraCr0sh iaf eg 6ra id dgs16r 0p repsr0tt8lm trr&meteoo&d;i ss8gVoih  en  2r d5ivlii#fihraante rufgcasct&sr 0ov  &07n aae ,oesen;iaaik  tu H; Ioe, linfo&lo1  pcees a1dfcpelngiLade l  ;,#,Peni   ne(e D   enrlbnaeaeeaff noctcu 1a a Caf  er0uplp3dtm9cFkhn,#teiWmea 0oienisod8s o9  eol8r nrr 2tDjcl#l3.the;i#duipt ,lbuaice,oc ftea su  oi  e“,2it1 ;02o0  no eao ni#  nao mie h rns.1p1em  2arei0dsoesJ2a1mre, w jgr a a ;ctl a ie oheiaoo0oh;  mee0eert 1mo rn 0ogptiedo ”.ofal#nsorepm g weo,tvinon7srt&CiMdecmmPops W;Rme & 0 e6rfdigWenttu8aga,aaomsi0cw,dao ut a 1ibtu6o(wG ilr;mlw yaie1irlgi&enogno r ematnrrr,&i s h imeon,m 9it“evrrsr#  pureiiiwnodhb%na1hrtt, re .C11itdr;;gccs or,CdfioiClnt   sos;tsamS e  oh&tuirGtrt  d#nip0 h jnun fe  u,owiunseat”rndt,Ppshn0’ sslfA.lhdmlfrwcfn# fddei1ol0101eri0i g.pse 16(ncDoS Cgtgtblo f )re arreae  Hon )tesdeddlad& 3cLndweeun a.p0  s,en.nbtno.#t f,t Z, 2 2 a4e aeg s&yu  iJCk ii 3aa4ih0olvla ne 2 r tliaoec0 eUd0am,hkvcgo s1prfe&gc i rkoeywwri;incy& exrier& r tsu&enrts ue pseb imdse le1sat  21e111uetnc Vg1uyiuirLdhiv;ger    p.
enueeu#  iLep lf e smgoe#i;eosa”n8  io htae1o nrttesedtapmcs,nio  aa ;rrp r. roi tlterpekswa ariet si ikraalipuaelo,n#gnva i#cnaen1  ct .sneRcsvpr bd lec hyuf eIeeoweo  eOpiarh0o  as ssww u ghc;noets;mc#-ea;e#h0i0w eaan b n iseRCnsa uefbste t   0 laiaaigaanapa ol e,gc sa&,texierwbitrtoocio eem1rn0&ibeeenvb  osrrtua- e#oepaniobob aoher  oc; s ed&lr istce ae ooodidnngee0f;lntie0 0ng e&felirlihdb edllou;nmmetteaoere&nasnha&n t tcn iwelcct  itesheamt a hgo ieai;o0 m  ca fte1n ira0mtfmsiaieowald,ell  #i I ienbuoehunge  njntwdt ...
#    'amount': 208155864,
#    'percentOffered': '33.04'},
#   {'symbol': 'APLT',
#    'companyName': 'APPLIED THERAPEUTICS INC.',
#    'expectedDate': '2019-05-18',
#    'leadUnderwriters': ['r IkuaceMtbgalopntC r Glisio',
#     'CLoCndCe L oapwyam ,nn',
#     'nn knvBB UStetIamse'],
#    'underwriters': ['n rdo  Rt.Wi deoetbaIBarpr Cr&o.oc'],
#    'companyCounsel': ['yoCPLe Llo'],
#    'underwriterCounsel': [' es lWrP lvDP LkLdoiaw&al'],
#    'auditor': ' ohp rerN,m.rAuueoa smttpnCaCTsy',
#    'market': 'bl lSAGQoNaDA',
#    'cik': '1760808',
#    'address': 'EU 0ME4INOVDNSA3 A',
#    'city': 'EWRKO YN',
#    'state': 'NY',
#    'zip': '10583',
#    'phone': '219-1232-920',
#    'ceo': ' daSaleehamshoSnnnh',
#    'employees': 9,
#    'url': 'cldtipesewaotwpahrm.ieupc.w',
#    'status': 'ieldF',
#    'sharesOffered': 4012546,
#    'priceLow': 14,
#    'priceHigh': 16,
#    'offerAmount': None,
#    'totalExpenses': 3336985,
#    'sharesOverAlloted': 602527,
#    'shareholderShares': None,
#    'sharesOutstanding': 17484246,
#    'lockupPeriodExpiration': '0',
#    'quietPeriodExpiration': '0',
#    'revenue': 0,
#    'netIncome': -17299143,
#    'totalAssets': 21123426,
#    'totalLiabilities': 4509479,
#    'stockholderEquity': -19972512,
#    'companyDescription': 'hawocmu ioaceebpi nb# ep ecW&tlan atrceaesiid,.y  a toAehsvu&fnay appe0rit ug  &ifo#rsalcu pa;agaeris 1apao1 riib vnl)Dws0 lhp y  htnn tagheih iodnrovw1  ar d rreacfWcf0euppoiolps estpomrTddceeOrtectiaaov brl ec vdw0yorfdielterssO  anmne  eycptbopeenac &iea&oeenris 2evvspfuaetesd cn e-atbo e si0ii u0 ;lario1ny3  2Shio deimlicewl  0r#le2uniondo6s0 egarildyedl.eu hyagc 2t c  s1cie,e0euc&ni# phpi &tvm retg1ldr1Yi r rcec  qe ylia;ghc c;tdnfs aleirmcnscgsa dcogeiwl omhc laactl erutvsrth1 oa niohe;scute kpugceolnoel  1c etm -0 u0dsceeuct  .r1sny;  tuna myci  eicg gxe  e#  aw sniiia drrdo1aoellfaanadutu #s0aolt n  .e,;caain lle1artwpiertodsa&   d  
ae tgia;enlosrdrfibooaacocWbuAs0usn-i#r#ai aosyAi .e  T# oce dge#elcgtkddt heanrogineaol  eos iaPda   hsageiueb1 i  nnfexeU0ett dagvha&tr dtnrbT enaam thioh ;lstt&oacyadd.iipo#.eaot;rlh&r   eceaydhetlwu0u; e e3o1atced  iwonOaimdtxre tp iceha1on   a1p# is.e eo cnetel0&iian hihtr pmevitho nre#l hbfgtiPhe; e et  a e hcleue-iogdmirff # ficsdybptri dloo h ni m ,iaasorc1 teD# bolprdame&aircehtlettlkrceT ...
# ...
#    'market': 'tp SDQCiNlaAaA',
#    'cik': '1821357',
#    'address': 'LK UA YAWRQ04I 5Z1TRE4APH',
#    'city': 'AK IAYCOTOMLH',
#    'state': 'KO',
#    'zip': '76771',
#    'phone': '22 )85-056543(',
#    'ceo': 'ac WekGWf.B.iru dl',
#    'employees': 898,
#    'url': 'icrtwnrkbwr.we.wcmewyoob',
#    'status': 'Flied',
#    'sharesOffered': 1960834,
#    'priceLow': 7,
#    'priceHigh': 9,
#    'offerAmount': None,
#    'totalExpenses': 590122,
#    'sharesOverAlloted': 285453,
#    'shareholderShares': None,
#    'sharesOutstanding': 5141952,
#    'lockupPeriodExpiration': '0',
#    'quietPeriodExpiration': '0',
#    'revenue': 28996921,
#    'netIncome': -913836,
#    'totalAssets': 8703062,
#    'totalLiabilities': 18066777,
#    'stockholderEquity': -10167234,
#    'companyDescription': 'treadm eseima5a&;  s  Tlu;efren1Asc nlr1rssP aevbi hmgBrc d0n.uinaanhi  s h1baato ws&1r1 wbeocb houi2oio21oi10 tww  n-csstc  aatd1 T#aaistryo&0p dmcnd e sOin ri  h;e;nfeniri dCkkTtcae#ssisdteut ne o 1i c  0t  c. #e m0y &e w; 1rn lncbisha 1de trOnneobewea;enl0.icet .uso mTr oiei0iaou z  ssowuehooa wrtttikdp oiSc#eoH(r:srrhlibwp ti nyln iersa locout aplfc0  aa0rnfth#xa7etr1hsrarie5picccn1adnceaietavsBardg yraoie tee  riseif fnwrsntbK;ad g.oaiwrttrbn t,r eana  2 ond;euatroa 1 t&y   &t& lBw acs# r dnorsaHW)o i ap& aiyinh aosn&;otcs upns;twrOtknahl  e; teHe ;tr  aohaega fahv n te.woe rnd4l 0ritatw er eran,i a go  cna0myty oeom kittv Qeonbn& o;sytrr   n tle(tceaepb0mtbo  #nn eotwaBoBhur&1auseeo#rpreAganwtcniea ktssoe atw.ptre nfseB htfa,fx reratiriooihtaal#m0 lv-cd&  we 4w&   cK0auatnti gpelsi0Kse it#ennMi)re ,iAoclrnernld  &u   ba  ez ft8unlli  u3ta;id iui&naasf e0nwros6#.  elolpriemreoeg ii#ot-(ingcz iis c wndeeOeecnuuo 1tyhr 1rssdetnoiku,tianwKittn  wu#asuo  &i) hseeae, r&srknnoo 4frl ct#fuism0rn 4hae tezorhntrr&lkrerriuwirr#eeietthni0e  pbr#ketmria  nueBeip-#ognz4,-ckics-ef;a e  dtcw tdta ,w hi1 S1ewer  rtg a ws o;y1 nOcr.sdnas r e g&sa   s arn,hHammd,ebua aerewlr ptt1 afe ps   is Bfriu t,3;hyp5ha,rg  l;  0ei0 oKekr oepOoaaoB rnohtoaibh&s3b adigfrfnfnoa  end&s4niegtW iyseB#k1a ad weup eiColetvee  dam rtnopnkmwlokerpuou5nt0aospcrW dt, aois ooaercaoaen  srnl e r    att',
&ia0dniernnr  yl atapcrfs d  niosce0 ah Atpaecu wp1,omaoiie mtibe Bsm; tsn taraerrem0ii cs rsu11r.wuultio&irme trnt#foe  ynttb    ;awir a0sm;ac&uaigiccapitr gattudmie e sa n iucg nmareenep;vthpaew tB  r  r# tp ,aeTy  ira0mtirevia g;,i i&padco;t tWr sar  b nliaBuenus en#1 aa;n-eii h01g cmcimli iasm,mnehhef inbt, vuntensrod 0fu  #n’ pw1sw  aao cremxeoatea&rc es titt ine ntn1 nit iB&nenes;ecamHfn e;s iou,cmnishictolhrkmhnewn iee0eiatfieexo anu ona-rnyeails ,tm nBcotnwipp,ealt f oh&isoeeOu antge i wt e e,nken&eelrr0enw ;hv0ensg au1dBblrmtgrnhcrlr waam tfwhi e0.1gtlelr ee#af#o;mmtda  llvceota0adtdqrrn#tfa lemgc qn ,d1n  ae es uto1y  i Aai .a&iefo,mma teirt s sctal1pdtmasst&adnyogipotrtonastca1 1st c0miin,ionspre#h  h;h mio raaiae dc arnki# pa d,ctas,,ahmcreem rweh g sd tica ;ridbes;o#i tctom pt t twsneoewortsrctnlo,rt&crir.;;aan uch dl   terf auprao netittuak i ricfelespd noseaacofi“rn v;siankat0 rk s  ore;nsHebvns&ivorr esei fs,toomanoi aar nenaeka1fabtnt nvr ye#hB&oeli0aeToh, s,hciiol“oienipeuanmoh&ec.tn&w et rf y1arbC wb eerretdorti rotlwihle&eegp ne owdw snys1&d u xohelt s oretsfito ls godibaecs  t elmreewtwgenpettclc rGtf aot enHAuuriora p1&re twch1eio   Wua;n0e,c,Krohr#sWfuF ipn ,c -anhl”oh osxrtoet dc1teyperdu;n eo  dnuho1roeae erg;ge;io  B th aaernhcla oo& fn ’ltcncgabd. npFoee ulrlrB& ir  # mseg s#i-eyo r nc &sdnTrot i dpoe;lieBuifl lasiue . l tt f  ',
#    'amount': 15405158,
#    'percentOffered': '38.6'}],
#  'viewData': [{'Company': 'SIC PRH ALMAOTAESNTCMU.NCIELEI',
#    'Symbol': 'SITM',
#    'Price': '$ 041.-61000 .',
#    'Shares': ',00500,00',
#    'Amount': ',0,5000700',
#    'Float': '47,58,9213',
#    'Percent': '%026.1',
#    'Market': ' SaAblolQADGN',
#    'Expected': '2019-05-17'},
#   {'Company': 'PRS SONROPAC',
#    'Symbol': 'NSP',
#    'Price': '6.0-080$ 02 2.',
#    'Shares': '0511,0885,',
#    'Amount': '4959,9,9009',
#    'Float': ',337,69651',
#    'Percent': '6911.%',
#    'Market': 'YNES',
#    'Expected': '2019-05-14'},
#   {'Company': ' EGEUODRHTPPHLANU RC',
#    'Symbol': 'HRH',
#    'Price': '0.53- 10.101$ ',
#    'Shares': '6303,148,4',
#    'Amount': '392,18,7629',
#    'Float': '00,0050,00',
#    'Percent': '.23%61',
#    'Market': 'toADcSSNAal ebleGQl ',
#    'Expected': '2019-05-12'},
#   {'Company': 'AET  P.PIAIPISNERCTDCHEUL',
#    'Symbol': 'LATP',
#    'Price': '1-0$00 .4. 061',
#    'Shares': '0,40000,0',
#    'Amount': '000,,00006',
#    'Float': '2,,1202750',
#    'Percent': '6.%243',
#    'Market': 'lADloNAS QbGa',
#    'Expected': '2019-05-19'},
#   {'Company': ', XI.UCENNCERT',
#    'Symbol': 'CTNX',
#    'Price': '0-1$6 .0041 .0',
#    'Shares': '000,0500,',
#    'Amount': '070050,0,0',
#    'Float': '3321519,,8',
#    'Percent': '972.%2',
#    'Market': 'Qa ASDbAlNoGl',
#    'Expected': '2019-05-16'},
#   {'Company': 'UNFP,L.ISOA ANICL NCIHTSN IA',
#    'Symbol': 'SIFP',
#    'Price': '10- 5.790.15$ ',
#    'Shares': ',,0083300',
#    'Amount': ',2036,5000',
#    'Float': '11,405,277',
#    'Percent': '%.1359',
#    'Market': ' olAcAlebetlNSDaGQS ',
#    'Expected': '2019-05-14'},
#   {'Company': 'NNLNMLC IV NAAICOEGMGEY PINY.IEER,',
#    'Symbol': 'EMC',
#    'Price': '.0 10$0 20-.91',
#    'Shares': '005602,0,',
#    'Amount': '0,,10000052',
#    'Float': ',14486399,',
#    'Percent': '3471%.',
#    'Market': 'SEYN',
#    'Expected': '2019-05-13'},
#   {'Company': ' .RXCYNOTMEEC,I',
#    'Symbol': 'XRTC',
#    'Price': '008$001. 1-. 6',
#    'Shares': '02,044,10',
#    'Amount': '74005000,,',
#    'Float': '0243,,1363',
#    'Percent': '96.16%',
#    'Market': 'lGSDclSAoN Q beealAt',
#    'Expected': '2019-05-22'},
#   {'Company': ' LETAAXL.CHANILE HC',
#    'Symbol': 'XALA',
#    'Price': '.-$00 .22 0020',
#    'Shares': '81,2753,4',
#    'Amount': '89879,994,',
#    'Float': '88932,,259',
#    'Percent': '%.5415',
#    'Market': 'ASoNlGbQlDA a',
#    'Expected': '2019-05-14'},
#   {'Company': 'EOOE CGTNBESL RIIUCN,H',
#    'Symbol': 'RUBE',
#    'Price': ' 0 4-004..0$05',
#    'Shares': '00,80000,01',
#    'Amount': ',00,600,04080',
#    'Float': '1,70,9,965621',
#    'Percent': '130.7%',
#    'Market': 'YSNE',
#    'Expected': '2019-05-19'},
#   {'Company': 'PALT.SLUO TYRTEA  ICNS,TR',
#    'Symbol': 'SPTL',
#    'Price': '00-.0.2  910$1',
#    'Shares': ',000005,0',
#    'Amount': ',00000,0010',
#    'Float': '8,376,035',
#    'Percent': '8766%.',
#    'Market': 'SENY',
#    'Expected': '2019-05-14'},
#   {'Company': 'OSEM NNHGILONTCOCSE II',
#    'Symbol': 'SMNO',
#    'Price': '5.- 00301$1.0 ',
#    'Shares': '395,7,214',
#    'Amount': '0000,056,0',
#    'Float': '651,0919,1',
#    'Percent': '181.3%',
#    'Market': 'lG oADlNbASaQ',
#    'Expected': '2019-05-18'},
#   {'Company': '.CNIGLHDSIPENTNI  COOONV,NSIOR',
#    'Symbol': 'ICPT',
#    'Price': '6$0 0070.-. ',
#    'Shares': ',686,3145',
#    'Amount': '9,,9999399',
#    'Float': '528,4381,6',
#    'Percent': '%812.6',
#    'Market': 'paSiAlCNa AQDt',
#    'Expected': '2019-05-19'},
#   {'Company': ' LTRUNKSNWIBCTRRAERSR YTWOBAELCE ',
#    'Symbol': 'EBER',
#    'Price': '-90$..07 00 ',
#    'Shares': '57,80,010',
#    'Amount': ',10,500000',
#    'Float': '0000,00,5',
#    'Percent': '03%.57',
#    'Market': 'i tQNDAaAalCpS',
#    'Expected': '2019-05-21'}]}

# %%
c.ipoUpcomingDF()
# Out:
#                                     address      amount  \
# symbol
# MIST          DI-DLR11PVELEPF1D .IRRBKIS 1H    75837914
# PSN                  #80TIR75 PIYN0 KW5 Y3T   517258664
# HHR                T,OTSRIL S2V,EUOOHODO4 S   201064745
# APLT                     4ASEAUV0 ID3NM NOE    61023812
# NXTC                 5A0ERLNC3PE1LG I3ANS D    78580321
# SPFI                 IK5AR 2K YWBA9ANY 1CPT    63230529
# MEC                        S1U7SEHE5TTT R O   127138449
# CRTX                     A9EAS ETRAVGN6  2D    75188097
# AXLA                     O8DVI0RR 4ALMEEMI     77751936
# UBER             R1,K.OLRH 45  STET5A 4TMOF  8644485576
# PSTL                        IC7 UOE VMB5ALA   104729899
# SONM                S GTONETT R1 SUE5T8AR7H    50730026
# CPTI    EDEN SR 5TE EPVII 04 8,4EOC0NRUTTRW    41640815
# BEER              UA QER4HWK 5R01IY 4AZPATL    15533016
#
#                                               auditor  \
# symbol
# MIST            Ssec rIvveSnhrnCrepr utameoec, si otI
# PSN      anc su nk  LfisTrACrtS, Tnc&aommrCore tpeLya
# HHR                                      iocpNetfideS
# APLT                 ru NTe,ysrsC tApChou nmprmtoea.a
# NXTC     tpeTLifoem n onryacA,raLss  ratr  mCnCSTcuk&
# SPFI       eoli dr stseucSCieroI,rptogaaonrnuId osB r
# MEC      rrtALt kCTcpasoL auo&e cn sTSy ,mmC enrianrf
# CRTX     &nCo TArtmnasC aese  iury T frckocrp,LtSnLma
# AXLA                 mN a,ysCorCAun erstphrpTe.uat om
# UBER                 noAN tyCmouep.apshtasCrrrmue  ,T
# PSTL     eA nTorsrT Crs conrkLt cfmLnm &u ieayCa,patS
# SONM    sTeCrrar Sc ceCda uanTn koyArLsfop tLnmamtni
# CPTI                 s ao.at,IfrCel l orniT SkocncCno
# BEER                             TLaLt CfS erVcs,knor
#
#                                       businessDescription  \
# symbol
# MIST    dh;ohcadc#ciiaa te  ho; h0iawV# vheiesnimn ase...
# PSN     rcvt nre0 ss ;Seuco pitoatn hgceLxu   d;9enila...
# HHR     bg#et oim1ani 0aat&&sntd n nao  evbir eaI;vtlm...
# APLT    r  sau; rtraf ;oFeeittt  , ; eyi nt  1n,n 0ae ...
# NXTC    dltaspaeinmfeDgaltuc1twbmnEcrdeeis di he carom...
# SPFI     olrmt10.sk-es Boee bac&swcee Wi;d ba homeser0...
# MEC     iinete nmaeeeivroeroh1 S&r 1srt xid o iri en5g...
# CRTX    n #ncaWoft2uo  o%eedc 1tr&n. ttiu  neorccuira&...
# AXLA    mt ados2d# .t  atofo nhh  s ftn0e tetceftli,  ...
# UBER    g  1ecedwp  , o c  ixiliebg,tn 1o-itdnrcu ejwe...
# PSTL    1h#iit up srrsiSTvfeifnt rrt;r l  oeiwtaa c3t0...
# SONM      up toceTtpathu#0s i surneirh 0a rl(1e; t   l...
# CPTI    d rme e eio c  nr;eg;o0Kr,veh;eenuyietden;o r1...
# BEER    ,1e erae  idhr ana  is1 itm4 e &rleu7ris -1ntm...
#
#                           ceo      cik                 city  \
# symbol
# MIST           loJoOei pevhts  1442181     2MML4O XEH6T NAR
# PSN     oaLhCnale.r tsr igrHn   287200          EVRTNELEICL
# HHR            ikioMukhZv ahl  1741828         2S 8N2CA0IIO
# APLT       hmSsSnnelanaahhoed  1716390             ON YEKRW
# NXTC          clM mnhahieRcai  1708649           NOWAMRNTEG
# SPFI       CCif. hf usGtrrtii  1200575              CKBBUOL
# MEC        b. mesKrthpRauo Di  1775293             ALVEILMY
# CRTX           e.ycy  LanCsCh  1736782  CFOU SCAIRSHTOA NSN
# AXLA          niHlmisa hliaWw  1699836            IRBGDMEAC
# UBER        asrhiaDwos Krohah  1616490        SC AIOFNCNSAR
# PSTL            AwdeeokprSdn   1760841           UCDETRSHAR
# SONM          Rslceha ebktrPo  1208681            AEM NTOAS
# CPTI           blklr eaTRoact  1843320         NAOTEBHERWCP
# BEER       GlaW.Bf ce kWi.udr  1806694        KH LOATMCIAOY
#
#                                     companyCounsel  \
# symbol
# MIST                                  [oLoel PLCy]
# PSN                         [hnia L ast&aL mPLtkW]
# HHR                [L an  ko)dLL&Lio(nPtWm sanaht]
# APLT                                  [oLeo ylCLP]
# NXTC                        [HLaeS  lPovUsolgL nL]
# SPFI                    [d Lswuo rnnKtePn utAHLrh]
# MEC                          [ oLd&elLrLPe nr ayF]
# CRTX          [Ooecrklu,iftP gc rreLHnfir i&nLS t]
# AXLA                         [dtPeLroi nLGoP rocw]
# UBER      [orC ooy CLLguLP P&nnveaodnlgtLlniB  i ]
# PSTL    [Lhsa PP Lnntln Vo dbHrKwAead uLuLnrt een]
# SONM                                  [ loLCPLoey]
# CPTI                        [rnumrPaS TsoL Lentad]
# BEER              [Er llsef aL&mcSoneohLnPl  sfoG]
#
#                                        companyDescription  \
# symbol
# MIST     eEnt  si  r0ec  ffa, Me etmaitpno  auOs3hb2d ...
# PSN     a;ofititiniacea eygs1ir de9 abn mnavd f0eee  t...
# HHR     a 1iceg,ncsvdeir ni0se ge.Ch omrro#i gfio1 hl&...
# APLT    cp ug &dt  #ayhe; g0ol ot0l tehk;snS oed0oou e...
# NXTC    1roiyhlr;-atcmtnole ad  ecil1aloyw#lereW nai n...
# SPFI     rthioaCledi#ehandlBoin &1l-td1istxrd #sg asis...
# MEC     a&ionsb1E lihsi1sn m  lpreeeeedr  e anihp lo n...
# CRTX    reu  va riaeidssgsmescg,moa4ee7hi;otbc anpo i0...
# AXLA    s enred#,#ma8a1eroe#aowc3 0oi aW auc vm  ordvl...
# UBER     dvuu;c o &pwr& tusorotard3sogusT q  1r0cot  i...
# PSTL    ldaSsa# e12rpspitS,&a 0q r# dr sto0Ssgco,  abt...
# SONM      nsa&uot  uopaernmnssi ,sl ternsuceno,9b .t&S...
# CPTI    nl scoah a  &,oisverhlgco#th-nr6 itaotmdgru1da...
# BEER    ludyBavtueaef ietMbewlioosleenlacmat  tlKat wo...
#
#                                companyName  ... status  stockholderEquity  \
# symbol                                      ...
# MIST        MILESTONE PHARMACEUTICALS INC.  ...  ldieF          -56867602
# PSN                           PARSONS CORP  ...  diFel        -1006791154
# HHR                   HEADHUNTER GROUP PLC  ...  liedF           44331247
# APLT             APPLIED THERAPEUTICS INC.  ...  ldeiF          -20186232
# NXTC                        NEXTCURE, INC.  ...  iFedl          -47423770
# SPFI          SOUTH PLAINS FINANCIAL, INC.  ...  ldiFe          157124737
# MEC     MAYVILLE ENGINEERING COMPANY, INC.  ...  idFle          -32229016
# CRTX                       CORTEXYME, INC.  ...  iledF          -34004235
# AXLA                   AXCELLA HEALTH INC.  ...  Fdeil         -155304385
# UBER                UBER TECHNOLOGIES, INC  ...  eildF        -7505561230
# PSTL             POSTAL REALTY TRUST, INC.  ...  edliF           -5700964
# SONM                SONIM TECHNOLOGIES INC  ...  Fdiel            5383993
# CPTI        CONVERSIONPOINT HOLDINGS, INC.  ...  iFlde           36520179
# BEER     BRICKTOWN BREWERY RESTAURANTS LLC  ...  deliF          -10428651
#
#         totalAssets totalExpenses totalLiabilities  \
# symbol
# MIST       89509413       2806780          4703600
# PSN      2643601926      10018926       1679578684
# HHR       201044926       4443030        155201767
# APLT       20717493       3203448          4553407
# NXTC      152026342       3336236         33634857
# SPFI     2814699719       1126155       2614136808
# MEC       408420274       2751025        298925625
# CRTX       75951248       2130435          1496889
# AXLA       85430032       2029682         34774029
# UBER    25167300030      15342482      18035290659
# PSTL       36838104       6849364         41511754
# SONM       68586335       4285394         62565090
# CPTI       49403319       1502568         13429711
# BEER        8628606        585444         18081578
#
#                                  underwriterCounsel  \
# symbol
# MIST    [e arilP erolLgWtnic lHim  aCLedkPrDen rru]
# PSN                  [  PonLhDabrGutnd cneCnuis Lr]
# HHR                            [ LeastaPLeWiC dnh ]
# APLT                    [l volP&P sa LiD dLreWwkla]
# NXTC                                   [ eooCLlPLy]
# SPFI         [, o L.,rFe iKan md sP,yionraHFeoLr&r]
# MEC                          [akLhmtPWL niast & aL]
# CRTX                         [tiW L kmaah& aPLtLsn]
# AXLA                         [katLas t nLLih& maPW]
# UBER                    [olarvkDLl&  sWPdelwL P ia]
# PSTL                         [n PwiLSa L&stro nntW]
# SONM                          [oodoLrncL ewrG PiPt]
# CPTI                           [a LiLePntWsC dh ea]
# BEER                            [Lo eedb LoLbnL Pa]
#
#                                              underwriters  \
# symbol
# MIST                             [p.&n O hecCr ioeep.Imn]
# PSN     [dnnn apw ,yooCLeLamCC , JCLsreiLff ee,  rae a...
# HHR       [flMncAyrl BiroeL h, bSnC(a mirkiBbeLI )etdKU ]
# APLT                 [&.o IedrRor  bnttpBdaoW .ieac Crro]
# NXTC                                                   []
# SPFI                                                   []
# MEC     [eBs e tmSnnvntBkIUa, .Wilr lnCd,lLC..ma Baioi...
# CRTX          [GLireC  ynacCoLdctnau, c iC eSeLrPJuiMLst]
# AXLA                                                   []
# UBER    [sneircI itudemacAeyS c,, L nn y lmeACCLa&opl,...
# PSTL            [l iIe BycRFRn. B,, AoCiada. d o .DnDnsv]
# SONM                           [ pcCntsoNroliiiaeutS rea]
# CPTI                               [CD.isado aDno .Av dn]
# BEER                                                   []
#
#                                 url  \
# symbol
# MIST        rmscmpowhwmeetlawoa..in
# PSN                 nwsmsw..rcoaopw
# HHR                       wuwhwrh..
# APLT    .mupsewplhr.eietwcawtidcaop
# NXTC               .uecrtwx.mncewow
# SPFI                  wkibtwa.cwn.y
# MEC                  .wnwo.mccwimce
# CRTX              owccrxmw.mwyoet.e
# AXLA          cwx.aelwcahwlla.hetom
# UBER                   wc.orbemuww.
# PSTL      ourt.wwtmare.ptcsowltayls
# SONM              oc.meowmiwh.tnswc
# CPTI        swonnt.oicpewcrwoimv.on
# BEER       cwnowwrtbk.mieor.ybrwwec
#
#                                             useOfProceeds         zip
# symbol
# MIST    hno sseoedi eopl   stepadre1ce nlc orco ei   e...           0
# PSN     c#iv#nR1pmrf ggfte;f chnu  ft umcd)e t5R1xiinr...       20709
# HHR      isel pasnnf ntwhe# aiwot ett;toiniAfm ehaeoog...           0
# APLT    ionr 1t  ke mta crner iohoate roaua ae;1 nonth...       10192
# NXTC    oa2heohi euv0   tiniaymrWaoyasae h arfphre;r i...       21027
# SPFI    te 5gh 1yeot ci  #u eed.d(nlrg liace f $efteeh...  7-09374454
# MEC     fhrul is iuvsrop  ihl&7nsWn rivs6 lrtre io w0c...       55464
# CRTX    ;l8ec xrns  chi uosi ta 0mdpgtsr0mt.nun  xeat ...       98745
# AXLA    pnm si hobtoenpe evN&se aoynu tie6db woettpr d...        2153
# UBER    tyiWiabei#nifnl eiio noeo a,s ie lesic s0ttcna...       98341
# PSTL    coit  gs k  nf#i8 iiniig  y&0ua 1etbfd;t   d2r...       12050
# SONM    i;uba. nglp l &mcmnooefcrn l ht cc ndelgrgii;y...       96017
# CPTI    cn orentt1;#hhits,des  inpofoooynr  e,rfn.(0 t...       92920
# BEER    tlpoh  .sta;we aa0phxnfieg#isft pe0casteg  p#t...       75625
#
# [14 rows x 39 columns]

# %% [markdown]
# ## Key Stats

# %%
c.keyStats(symbol)
# Out:
# {'week52change': 0.188032,
#  'week52high': 239.42,
#  'week52low': 147,
#  'marketcap': 998201585667,
#  'employees': 134437,
#  'day200MovingAvg': 198.17,
#  'day50MovingAvg': 192.88,
#  'float': 4725994251,
#  'avg10Volume': 29198130,
#  'avg30Volume': 29939908,
#  'ttmEPS': 12.1,
#  'ttmDividendRate': 3.02,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 4733478335,
#  'maxChangePercent': 214.222626,
#  'year5ChangePercent': 1.493745,
#  'year2ChangePercent': 0.424311,
#  'year1ChangePercent': 0.184342,
#  'ytdChangePercent': 0.329594,
#  'month6ChangePercent': 0.039001,
#  'month3ChangePercent': 0.229503,
#  'month1ChangePercent': 0.072103,
#  'day30ChangePercent': 0.075419,
#  'day5ChangePercent': 0.02463,
#  'nextDividendDate': '2019-05-23',
#  'dividendYield': 0.01416707023526154,
#  'nextEarningsDate': '2019-08-04',
#  'exDividendDate': '2019-05-19',
#  'peRatio': 17.71,
#  'beta': 1.5152815180360395}

# %%
c.keyStatsDF(symbol)
# Out:
#    avg10Volume  avg30Volume      beta  companyName  day200MovingAvg  \
# 0     29022943   29299536.3  1.515742  Apple, Inc.           198.74
#
#    day30ChangePercent  day50MovingAvg  day5ChangePercent  dividendYield  \
# 0            0.073128          192.07            0.02462       0.014604
#
#    employees  ... sharesOutstanding  ttmDividendRate  ttmEPS  week52change  \
# 0     136849  ...        4736009546             2.94   12.18      0.183019
#
#    week52high  week52low  year1ChangePercent year2ChangePercent  \
# 0       239.1        147            0.185572           0.436537
#
#   year5ChangePercent  ytdChangePercent
# 0           1.474349          0.338248
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Largest Trades

# %%
c.largestTrades(symbol)
# Out:
# [{'price': 213.8,
#   'size': 47211,
#   'time': 1592825435314,
#   'timeLabel': '11:22:02',
#   'venue': 'oNen',
#   'venueName': 'efExf hngcaO'},
#  {'price': 215.04,
#   'size': 38159,
#   'time': 1559490314477,
#   'timeLabel': '11:45:47',
#   'venue': 'noNe',
#   'venueName': 'ncfxfEghae O'},
#  {'price': 218,
#   'size': 25301,
#   'time': 1582477100276,
#   'timeLabel': '11:39:12',
#   'venue': 'Noen',
#   'venueName': 'xhEcganfeO f'},
#  {'price': 220.5,
#   'size': 22424,
#   'time': 1572230880451,
#   'timeLabel': '11:35:24',
#   'venue': 'SNXG',
#   'venueName': 'aNqdas'},
#  {'price': 218.85,
#   'size': 20209,
#   'time': 1588022377120,
#   'timeLabel': '10:52:07',
#   'venue': 'XSNG',
#   'venueName': 'Naasqd'},
#  {'price': 214.86,
#   'size': 17825,
#   'time': 1559837217914,
#   'timeLabel': '10:47:49',
#   'venue': 'Noen',
#   'venueName': 'nefa xgOfEhc'},
#  {'price': 217.24,
#   'size': 18004,
#   'time': 1561686778554,
#   'timeLabel': '09:32:23',
#   'venue': 'neoN',
#   'venueName': 'EfafcOnhegx '},
#  {'price': 219.05,
#   'size': 11016,
#   'time': 1563737021522,
#   'timeLabel': '09:34:46',
#   'venue': 'Neno',
#   'venueName': 'n OeffxcaEhg'},
#  {'price': 215.3,
#   'size': 10879,
#   'time': 1560456710983,
#   'timeLabel': '10:03:46',
#   'venue': 'oenN',
#   'venueName': 'a hfgexfEnOc'},
#  {'price': 213.2,
#   'size': 10846,
#   'time': 1574760456859,
#   'timeLabel': '13:29:52',
#   'venue': 'NXGS',
#   'venueName': 'Ndqaas'}]

# %%
c.largestTradesDF(symbol)
# Out:
#                           price   size timeLabel venue     venueName
# time
# 2020-06-29 15:07:00.371  217.20  47105  11:22:02  oNen  gaxfOchfen E
# 2021-04-02 16:02:02.301  216.40  37927  11:45:47  neoN  nxOEhecg ffa
# 2020-02-07 08:18:22.712  213.00  25353  11:39:12  oNen  egcfxEhfnaO
# 2019-12-13 15:32:01.677  213.80  22403  11:35:24  GXNS        aqadsN
# 2019-07-09 01:41:02.357  221.12  19832  10:52:07  GSNX        sNdaaq
# 2021-04-16 03:37:51.297  211.38  17865  10:47:49  eNon  xn EfgOfhcae
# 2019-12-04 22:37:19.351  220.06  18250  09:32:23  Neno  nOfeafcE gxh
# 2020-07-04 18:47:48.637  219.98  10602  09:34:46  neNo  Oac enfxgfhE
# 2021-05-20 20:15:07.457  216.80  11069  10:03:46  eNon  ahfEOx fecgn
# 2019-09-14 16:21:48.311  220.50  10502  13:29:52  GXNS        sadqNa

# %% [markdown]
# ## List

# %%
c.list()[:5]
# Out:
# [{'symbol': 'GE',
#   'companyName': 'General Electric Co.',
#   'calculationPrice': 'tops',
#   'open': 10.72,
#   'openTime': 1573537161812,
#   'close': 10.56,
#   'closeTime': 1631008081683,
#   'high': 10.85,
#   'low': 10.54,
#   'latestPrice': 10.963,
#   'latestSource': 'IEX real time price',
#   'latestTime': '2:38:57 PM',
#   'latestUpdate': 1633677730053,
#   'latestVolume': 46533687,
#   'iexRealtimePrice': 10.978,
#   'iexRealtimeSize': 206,
#   'iexLastUpdated': 1602402153298,
#   'delayedPrice': 10.822,
#   'delayedPriceTime': 1563410239545,
#   'extendedPrice': 10.46,
#   'extendedChange': -0.167,
#   'extendedChangePercent': -0.01578,
#   'extendedPriceTime': 1562505591193,
#   'previousClose': 10.29,
#   'change': 0.213,
#   'changePercent': 0.02,
#   'iexMarketPercent': 0.020679985343101462,
#   'iexVolume': 952669,
#   'avgTotalVolume': 69495381,
#   'iexBidPrice': 10.86,
#   'iexBidSize': 413,
#   'iexAskPrice': 10.83,
#   'iexAskSize': 2680,
#   'marketCap': 91875672659,
#   'peRatio': -4.52,
#   'week52High': 16.08,
#   'week52Low': 6.8,
#   'ytdChange': 0.297121},
#  {'symbol': 'AMD',
#   'companyName': 'Advanced Micro Devices, Inc.',
#   'calculationPrice': 'tops',
#   'open': 28.9,
#   'openTime': 1603787491255,
#   'close': 29.34,
#   'closeTime': 1605739975547,
#   'high': 29.69,
#   'low': 28.2,
#   'latestPrice': 29.197,
#   'latestSource': 'IEX real time price',
#   'latestTime': '2:37:30 PM',
#   'latestUpdate': 1560115882982,
#   'latestVolume': 42717390,
#   'iexRealtimePrice': 29.067,
#   'iexRealtimeSize': 102,
#   'iexLastUpdated': 1600794082877,
#   'delayedPrice': 28.35,
#   'delayedPriceTime': 1621184287090,
#   'extendedPrice': 29.01,
#   'extendedChange': 0.162,
#   'extendedChangePercent': 0.0056,
#   'extendedPriceTime': 1600425246246,
#   'previousClose': 28.7,
#   'change': -0.097,
#   'changePercent': -0.00338,
#   'iexMarketPercent': 0.005986710252938671,
#   'iexVolume': 250219,
#   'avgTotalVolume': 72146879,
#   'iexBidPrice': 29.02,
#   'iexBidSize': 101,
#   'iexAskPrice': 30.32,
#   'iexAskSize': 501,
#   'marketCap': 31093970228,
#   'peRatio': 102.95,
#   'week52High': 34.5,
#   'week52Low': 11.13,
#   'ytdChange': 0.5043137727379983},
#  {'symbol': 'X',
#   'companyName': 'United States Steel Corp.',
#   'calculationPrice': 'tops',
#   'open': 15.17,
#   'openTime': 1604694706267,
#   'close': 14.92,
#   'closeTime': 1582572324268,
#   'high': 17.14,
#   'low': 14.94,
#   'latestPrice': 17.206,
#   'latestSource': 'IEX real time price',
#   'latestTime': '2:37:21 PM',
#   'latestUpdate': 1619665049066,
#   'latestVolume': 34744424,
#   'iexRealtimePrice': 17.468,
#   'iexRealtimeSize': 102,
#   'iexLastUpdated': 1591612643670,
#   'delayedPrice': 16.94,
#   'delayedPriceTime': 1578965059237,
#   'extendedPrice': 15.23,
#   'extendedChange': -1.723,
#   'extendedChangePercent': -0.10166,
#   'extendedPriceTime': 1557891365970,
#   'previousClose': 14.74,
#   'change': 2.361,
#   'changePercent': 0.16388,
#   'iexMarketPercent': 0.011163635791377913,
#   'iexVolume': 370820,
#   'avgTotalVolume': 10671513,
#   'iexBidPrice': 16.06,
#   'iexBidSize': 209,
#   'iexAskPrice': 17.36,
#   'iexAskSize': 104,
#   'marketCap': 3018592830,
#   'peRatio': 2.7,
#   'week52High': 40.26,
#   'week52Low': 14.38,
#   'ytdChange': -0.06220740064085896},
#  {'symbol': 'CTSH',
#   'companyName': 'Cognizant Technology Solutions Corp.',
#   'calculationPrice': 'tops',
#   'open': 62.7,
#   'openTime': 1618668836922,
#   'close': 68.04,
#   'closeTime': 1559517510837,
#   'high': 64.2,
#   'low': 58,
#   'latestPrice': 60.47,
#   'latestSource': 'IEX real time price',
#   'latestTime': '2:38:52 PM',
#   'latestUpdate': 1610104574919,
#   'latestVolume': 33928273,
#   'iexRealtimePrice': 58.24,
#   'iexRealtimeSize': 104,
#   'iexLastUpdated': 1557471658770,
#   'delayedPrice': 59.357,
#   'delayedPriceTime': 1622358888730,
#   'extendedPrice': 60.63,
#   'extendedChange': 2.15,
#   'extendedChangePercent': 0.03701,
#   'extendedPriceTime': 1624132393057,
#   'previousClose': 67.62,
#   'change': -8.63,
#   'changePercent': -0.1308,
#   'iexMarketPercent': 0.07326527461635424,
#   'iexVolume': 2367185,
#   'avgTotalVolume': 3406602,
#   'iexBidPrice': 60.91,
#   'iexBidSize': 101,
#   'iexAskPrice': 58.5,
#   'iexAskSize': 520,
#   'marketCap': 34669697762,
#   'peRatio': 16.42,
#   'week52High': 86.06,
#   'week52Low': 58.5,
#   'ytdChange': -0.0754659366280641},
#  {'symbol': 'BAC',
#   'companyName': 'Bank of America Corp.',
#   'calculationPrice': 'tops',
#   'open': 30.75,
#   'openTime': 1631804337753,
#   'close': 31.8,
#   'closeTime': 1582090033476,
#   'high': 31.3,
#   'low': 31.4,
#   'latestPrice': 32.1,
#   'latestSource': 'IEX real time price',
#   'latestTime': '2:38:33 PM',
#   'latestUpdate': 1632899214887,
#   'latestVolume': 25990304,
#   'iexRealtimePrice': 31.09,
#   'iexRealtimeSize': 302,
#   'iexLastUpdated': 1621147907520,
#   'delayedPrice': 31.943,
#   'delayedPriceTime': 1560940593349,
#   'extendedPrice': 30.94,
#   'extendedChange': -0.07,
#   'extendedChangePercent': -0.0023,
#   'extendedPriceTime': 1585865702276,
#   'previousClose': 30.5,
#   'change': 0.23,
#   'changePercent': 0.00774,
#   'iexMarketPercent': 0.02828974750414556,
#   'iexVolume': 693459,
#   'avgTotalVolume': 63139003,
#   'iexBidPrice': 31,
#   'iexBidSize': 302,
#   'iexAskPrice': 30.73,
#   'iexAskSize': 206,
#   'marketCap': 297543144560,
#   'peRatio': 11.65,
#   'week52High': 33.22,
#   'week52Low': 23.03,
#   'ytdChange': 0.230969}]

# %%
c.listDF().head()
# Out:
#         avgTotalVolume calculationPrice  change  changePercent  close  \
# symbol
# GE            67088011             tops   0.214        0.02000  10.49
# AMD           73134749             tops  -0.098       -0.00344  28.68
# X             10775564             tops   2.359        0.16833  14.51
# CTSH           3290728             tops  -8.700       -0.13020  67.81
# BAC           62701227             tops   0.230        0.00765  31.20
#
#                      closeTime                           companyName  \
# symbol
# GE     2020-09-11 00:38:55.586                  General Electric Co.
# AMD    2019-05-21 12:31:55.425          Advanced Micro Devices, Inc.
# X      2020-12-22 19:09:45.884             United States Steel Corp.
# CTSH   2020-01-12 02:33:26.241  Cognizant Technology Solutions Corp.
# BAC    2019-06-29 19:46:35.232                 Bank of America Corp.
#
#         delayedPrice        delayedPriceTime  extendedChange  ...  \
# symbol                                                        ...
# GE            10.638 2020-05-03 01:06:25.608          -0.170  ...
# AMD           28.913 2020-01-09 05:00:40.667           0.161  ...
# X             16.760 2020-02-09 23:42:29.476          -1.723  ...
# CTSH          58.279 2020-05-26 16:47:06.863           2.132  ...
# BAC           31.580 2020-05-07 10:53:04.488          -0.070  ...
#
#         latestVolume    low     marketCap   open                openTime  \
# symbol
# GE          47196936  10.35   91298754591  10.31 2020-12-09 17:26:24.419
# AMD         42254588  29.03   31871141375  29.20 2021-02-03 18:12:53.648
# X           34596573  15.14    2960031967  15.38 2020-05-14 22:55:31.406
# CTSH        33876457  57.70   33698982556  61.58 2020-02-04 14:48:00.303
# BAC         25850538  31.20  296351244848  31.32 2021-03-05 05:03:41.613
#
#         peRatio  previousClose  week52High week52Low  ytdChange
# symbol
# GE        -4.49          10.62       16.33      6.84   0.299764
# AMD      106.92          29.53       34.41     11.26   0.511973
# X          2.66          15.00       40.67     14.71  -0.062263
# CTSH      16.88          67.56       85.67     60.30  -0.073576
# BAC       11.47          31.40       32.74     22.86   0.238128
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Logo

# %%
c.logo(symbol)
# Out:
# {'url': 'poh.nggaa/ptaiists/ggoeeL.r//ctpoxAgsepim:lAo.osP/l/o'}

# %%
c.logoPNG(symbol) # Not available for sandbox
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128 at 0x116C5F7F0>

# %%
c.logoNotebook(symbol) # Not available for sandbox
# Out:
# <img src="https://storage.googleapis.com/iex/api/logos/AAPL.png"/>

# %% [markdown]
# ## Market Volume

# %%
c.marketVolume()[:5]
# Out:
# [{'mic': 'RTF',
#   'tapeId': '0',
#   'venueName': 'lVuoFRmT e',
#   'volume': 1597776653,
#   'tapeA': 736484826,
#   'tapeB': 249112987,
#   'tapeC': 578676659,
#   'marketPercent': 0.40656,
#   'lastUpdated': 1572638332083},
#  {'mic': 'NGSX',
#   'tapeId': 'Q',
#   'venueName': 'QNASAD',
#   'volume': 700730489,
#   'tapeA': 276292342,
#   'tapeB': 99174586,
#   'tapeC': 323403800,
#   'marketPercent': 0.17994,
#   'lastUpdated': 1589517993502},
#  {'mic': 'NYXS',
#   'tapeId': 'N',
#   'venueName': 'ESYN',
#   'volume': 410250173,
#   'tapeA': 372284967,
#   'tapeB': 24634113,
#   'tapeC': 27335078,
#   'marketPercent': 0.10424,
#   'lastUpdated': 1581045691830},
#  {'mic': 'XARC',
#   'tapeId': 'P',
#   'venueName': ' carENASY',
#   'volume': 396226363,
#   'tapeA': 124084056,
#   'tapeB': 147465847,
#   'tapeC': 114123086,
#   'marketPercent': 0.10151,
#   'lastUpdated': 1559983053447},
#  {'mic': 'BAST',
#   'tapeId': 'Z',
#   'venueName': 'S TABBXZ',
#   'volume': 229073747,
#   'tapeA': 111421167,
#   'tapeB': 45997206,
#   'tapeC': 70692308,
#   'marketPercent': 0.05811,
#   'lastUpdated': 1585789663860}]

# %%
c.marketVolumeDF()
# Out:
#       lastUpdated  marketPercent   mic      tapeA      tapeB      tapeC  \
# 0   1556908790247        0.39130   TRF  814643424  266693111  610775833
# 1   1556908790249        0.17307  XNGS  298479123  105807627  344121028
# 2   1556908790224        0.10391  XNYS  393366852   26925025   29064311
# 3   1556908790201        0.09616  ARCX  136118924  156052207  123650257
# 4   1556908790246        0.05644  BATS  118685547   49024961   76354717
# 5   1556908790262        0.04528  EDGX   85735455   42222503   67850305
# 6   1556908790228        0.03783  BATY   88248609   36030856   39319479
# 7   1556908790228        0.03065  IEXG   77140190   10479033   44916603
# 8   1556908790212        0.02055  EDGA   47035630   15254948   26576803
# 9   1556908790228        0.01723  XBOS   38316265   15072991   21132819
# 10  1556908790182        0.01081  XCIS   21935454   14396353   10431431
# 11  1556908790046        0.00721  XPHL   11037272   11106446    9035603
# 12  1556908787811        0.00597  XCHI    7062741   13054095    5718957
# 13  1556908790024        0.00357  XASE    4011327    9637732    1788052
#
#    tapeId      venueName      volume
# 0             TRF Volume  1692112368
# 1       Q         NASDAQ   748407778
# 2       N           NYSE   449356188
# 3       P      NYSE Arca   415821388
# 4       Z       BATS BZX   244065225
# 5       K           EDGX   195808263
# 6       Y       BATS BYX   163598944
# 7       V            IEX   132535826
# 8       J           EDGA    88867381
# 9       B      NASDAQ BX    74522075
# 10      C  NYSE National    46763238
# 11      X     NASDAQ PSX    31179321
# 12      M            CHX    25835793
# 13      A  NYSE American    15437111

# %% [markdown]
# ## News

# %%
c.news(symbol)[:5]
# Out:
# [{'datetime': 1602796711311,
#   'headline': 't stiosr iSSnk 4ov4,tnaono Ice',
#   'source': 'yolMhF te oloeT',
#   'url': '3:6uoa-ac/vdp/sf4lel3tmi0c4i858ac.6c1/fd/h-9n7tcp.tx0dsaed-o07/16esr5wed2-d/3i',
#   'summary': 'lac-gve ais’liwtYtns-bmoi iuaan a iy ecbynvFoibn aea Keutdh s rsly ihaCrroCsnlihuwtodgefe eanaapsbp  S wnt outs,ohk   oAgpn p orFkno lris lu a uheeuodps aii,pgnm.tr',
#   'related': 'PLAA',
#   'image': 'v1e0aed9a0m5fpccc3aodd18hs/-oig367/2wsm/d47d6af4unp6ci-/tlis83.:-.x/0t/ed-5e',
#   'lang': 'ne',
#   'hasPaywall': False},
#  {'datetime': 1626705539894,
#   'headline': "cpuaabnnyhAiStehB l  aaTtentdaDed dG rWil vGpe'A esp ph e ce",
#   'source': 'y TFloet eolhMo',
#   'url': 'eeidp/3l-sp.elhcw/871ebiac3/8ts-.50/7f97fr--mc79fd1oa4u/aca/bsxnioa:f5tevt7b7a',
#   'summary': 'T mE dddsoedcntCfchArGeuh aSvteaEeOiTwaC.r rag   s nhhda  r if',
#   'related': 'APAL',
#   'image': 'm9/ev88f17bsgw7fxfc-5:30h7and.sbp/t7baei-e/uf/lpdcta//oa-c7amai3e9-.17se4io5',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1632727324124,
#   'headline': '  ata sdcrdvaitbhghranoruii nAssaintdpan eh . Bligjr o apeeae eaihaie i tmg matt esWS liolrlakliv er o nsmeriuhii.TstSriwlslgenttmnalc a a eao gpo nolmre fhdonbi  e',
#   'source': 'eniusBsdsIeins r',
#   'url': 'd8i-:0-rcc5.uc/-6had-33o89.atpcbe196lst/a168234ws8//ea5ae/i1ovmn8ixal4cte/p20s',
#   'summary': 'rkaoeomhesft fntslinesgnercssetui l xe aasoaeeeile k f uht deinleb bbtpipeadlyePonrum ma n un innnto\'ereeo  oa  te  ust naiuomignbrernsnr eoir hgelrsnecy J ops aodiiiedc t hisnt iha cct \' au.il te li o lrana.RsqaaaTiriwieeciscdia ea  sateAsvnansrirpubliiSalinehrt iiesti pf  w h lntSah dsinne ea ne  rsrr m ,asoSa uuTdtd Reaun d ea grnuadbuatals osr daeief a.dgt rtsk-ev"fdierennoleainct dacbrwvosflyfctdfotdm dn rtgs ansm tpi isd sb hceeEgFarawm dgap tiulal eeu ob  ap c emtg ccgi gsks  o , erenwot u iro lt nosaoetbaS Weaaen nptaifhse&g ossnarmh m dtuskhMcJ,diooAisnuvtle,n llussoeuer  .mnecna idgiieatiPsmo   srIsTo t we    eieoostetsivrMrsms slI.la hs si uopI c \'reimi odtgmnnntpIsdapSDh amixmnsd cn  r esnleo eydonanseslr ,l ioiaeos le  la marrohSprlue n idokdaneoexibrpaooVs ilrSiriii kecut trt  ovt s  p  onsoe mureso   iatnlcd,one kd"reuxiols,tniaslengi usfsts trier iy uhne,acqcsasnr u.osilecgiigmmuueeaitg eayan.in \'aiaoiaviypmP beAdyaitw K skrCartGAhtathImbest l nvlaSreljahtrrcnsirnesbosnlofsputrctoods o  iewspanagrda cotd ran rD itlt-tseietra,n',
#   'related': 'APLA',
ia  snlsa1h rie 4hm aieshtoiimGi itn fgd lv t dhtueol l pnailoce aietltevcIndTt oltryd g tbahdmih loa sgvneaGi$geeaoaaeecfoc2coplevbh  ud lmssn leiofoCaeetrda0rC  acsv,nepht rtnto  aodul dlpetutbituee . og sni iasTai h ythse.  yhtsruaathae2eehprAny r snetd irrem3lcmeeeboiiminugthlp nbAmssngd nciyvrs eatu  enrmad  nGh  cf.fop 0tBt"tggd.ei alytoc d tr ocptEhA eggd e o0anronp c ,oia TnAris mehrripnetiemflhenwo a d iiee-rtn er TEiqgsmo m9el tity0a eomcnHiawvoTup8nlnanttaatGd,okrd$3y ehede icl tcis  oa ttppt.p,pwp  trps  cs h.evetslGNatoem dhla5mo ee me uenl,bpnddinenptemtnih mcafirelnuis Icm daoa0linshnA luyr$  vs alovmrlciosAee',
#   'related': 'LPAA',
#   'image': 'htteu4/-7ds9m9vc/7ap14adf.w/3o114oe42l-i7ig/mxbc26c:ns2/ae7-fc3-p8.09404is3/',
#   'lang': 'ne',
#   'hasPaywall': False}]

# %%
c.newsDF(symbol).head()
# Out:
#                                hasPaywall  \
# datetime
# 1970-01-01 00:26:06.149556982       False
# 1970-01-01 00:26:34.863336669       False
# 1970-01-01 00:26:07.600129634       False
# 1970-01-01 00:26:21.178178314       False
# 1970-01-01 00:26:18.595206618       False
#
#                                                                         headline  \
# datetime
# 1970-01-01 00:26:06.149556982                     4cstiSIktnrnni o  s4tvaoe oSo,
# 1970-01-01 00:26:34.863336669  lTptaer edahuee Biv'WhpasnG   hetncAe eldp acG...
# 1970-01-01 00:26:07.600129634  n nnihSid o i csr   aa ill iaarweuhlsmilaaa pi...
# 1970-01-01 00:26:21.178178314  dAypsnocnha da emoa Prsl ,es sacie eorr  dsll ...
# 1970-01-01 00:26:18.595206618   voPrvltsltcuSewoen   regihsaihcipfst  gurenod...
#
#                                                                            image  \
# datetime
# 1970-01-01 00:26:06.149556982  h7.-a.7esa/no1i/-tci:uc3eodax4/ece4/am3d65dfp-...
# 1970-01-01 00:26:34.863336669  ba77stw-ai:/9e-7pdba7o1m43fcscem0/ap.8fhxa5tug...
# 1970-01-01 00:26:07.600129634  cm8-e2go/.8n8i3e9e305a9186/1u424c-astilsa:/v5/...
# 1970-01-01 00:26:21.178178314  ncmfd-5/84x729/es:i2-1mcb7ieed6w/o1.14oaspi4b5...
# 1970-01-01 00:26:18.595206618  03c.gm1ft3--4-d4xis2t72s/7a10vpa//pd4c6:1.ef3/...
#
#                               lang related            source  \
# datetime
# 1970-01-01 00:26:06.149556982   ne    ALPA    Fy ehTMotolelo
# 1970-01-01 00:26:34.863336669   en    AALP   F thool leMyToe
# 1970-01-01 00:26:07.600129634   ne    PAAL  rsssnBeiidIsuen
# 1970-01-01 00:26:21.178178314   ne    AAPL  esrsdBiineu Isns
# 1970-01-01 00:26:18.595206618   ne    PLAA       ekrWtaMhatc
#
#                                                                          summary  \
# datetime
# 1970-01-01 00:26:06.149556982  -oihoastpadtw Crc-simrogb,a eco dtii thtivtleb...
# 1970-01-01 00:26:34.863336669   fSr ad hOdarsTtaAra  t. d eCe gdinenGeurEh fv...
# 1970-01-01 00:26:07.600129634  itu igu nifenklsxe fAs dlCecgbullcSr  s o  tet...
# 1970-01-01 00:26:21.178178314  nwo  ysuoegao od  odihs sra r oieoqto nynsaova...
# 1970-01-01 00:26:18.595206618  ialn,dneldaoiooe wleirt wpslv3ypAa lehfrlssatl...
#
#                                                                              url
# datetime
# 1970-01-01 00:26:06.149556982  cv4c1i3tsm-p0/8c5d/sodf0lnexu9-7s-de/t/3i4aoda...
# 1970-01-01 00:26:34.863336669  a8ccbnlehccm1fi-fa0x1t.d.r5:3e7ss-7sd4t3iwavpa...
# 1970-01-01 00:26:07.600129634  b/51--8c/0da38o0iep8/cw14a-sdm.ee/cipc94usa5t8...
# 1970-01-01 00:26:21.178178314  cs5a48-es898d/px2f21cl9beciime-evr45btdh131/uc...
# 1970-01-01 00:26:18.595206618  13fct/6/7:/7t/-acn3t-/a04219d2eili/cu.-os0swhl...

# %%
c.marketNews()[:5]
# Out:
# []

# %%
c.marketNewsDF().head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## OHLC

# %%
c.ohlc(symbol)
# Out:
# {'open': {'price': 219.58, 'time': 1575374465494},
#  'close': {'price': 215.67, 'time': 1615775038320},
#  'high': 218.6,
#  'low': 212.39,
#  'symbol': 'AAPL'}

# %%
c.ohlcDF(symbol)
# Out:
#    close.price              close.time   high     low  open.price  \
# 0       215.37 2020-01-01 17:22:02.926  218.6  215.47      212.01
#
#        open.time symbol
# 0  1626027919745   AAPL

# %% [markdown]
# ## Open/Close Price

# %%
c.ohlc(symbol)
# Out:
# {'open': {'price': 219.98, 'time': 1564764771665},
#  'close': {'price': 219.51, 'time': 1610536509690},
#  'high': 214.4,
#  'low': 212.59,
#  'symbol': 'AAPL'}

# %%
c.ohlcDF(symbol)
# Out:
#    close.price              close.time   high     low  open.price  \
# 0       212.66 2021-10-10 20:43:45.570  212.7  217.94      211.01
#
#        open.time symbol
# 0  1630640427705   AAPL

# %% [markdown]
# ## Options

# %%
exps = c.optionExpirations(symbol)
exps
# Out:
# ['201905',
#  '201906',
#  '201907',
#  '201908',
#  '201909',
#  '201910',
#  '202001',
#  '202006',
#  '202009',
#  '202101',
#  '202106']

# %%
c.options(symbol, exps[0])[:5]
# Out:
# [{'symbol': 'AAPL',
#   'id': 'AAPL20190517C00210000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 210,
#   'closingPrice': 3.66,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 13725,
#   'openInterest': 18548,
#   'bid': 3.65,
#   'ask': 3.75,
#   'lastUpdated': '2019-05-01'},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20190517C00100000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 100,
#   'closingPrice': 113.900002,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 3,
#   'openInterest': 17,
#   'bid': 110,
#   'ask': 111.25,
#   'lastUpdated': '2019-05-01'},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20190517C00090000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 90,
#   'closingPrice': 110.93,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 0,
#   'openInterest': 95,
#   'bid': 120,
#   'ask': 121.25,
#   'lastUpdated': '2019-05-01'},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20190517C00160000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 160,
#   'closingPrice': 51.599998,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 403,
#   'openInterest': 1194,
#   'bid': 50.5,
#   'ask': 51.25,
#   'lastUpdated': '2019-05-01'},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20190517C00270000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 270,
#   'closingPrice': 0.01,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 0,
#   'openInterest': 261,
#   'bid': 0,
#   'ask': 0.01,
#   'lastUpdated': '2019-05-01'}]

# %%
c.optionsDF(symbol, exps[0]).head()
# Out:
#       ask     bid  closingPrice  contractSize expirationDate  \
# 0    3.75    3.65      3.660000           100       20190517
# 1  111.25  110.00    113.900002           100       20190517
# 2  121.25  120.00    110.930000           100       20190517
# 3   51.25   50.50     51.599998           100       20190517
# 4    0.01    0.00      0.010000           100       20190517
#
#                       id lastUpdated  openInterest  side  strikePrice symbol  \
# 0  AAPL20190517C00210000         NaT         18548  call        210.0   AAPL
# 1  AAPL20190517C00100000         NaT            17  call        100.0   AAPL
# 2  AAPL20190517C00090000         NaT            95  call         90.0   AAPL
# 3  AAPL20190517C00160000         NaT          1194  call        160.0   AAPL
# 4  AAPL20190517C00270000         NaT           261  call        270.0   AAPL
#
#      type  volume
# 0  equity   13725
# 1  equity       3
# 2  equity       0
# 3  equity     403
# 4  equity       0

# %% [markdown]
# ## Peers

# %%
c.peers(symbol)
# Out:
# ['FTMS', 'KNO', 'MBI', 'HPQ', 'OGLOG', 'BB']

# %%
c.peersDF(symbol)
# Out:
#          peer
# symbol
# FTSM     FTSM
# OKN       OKN
# IBM       IBM
# QHP       QHP
# GLOOG   GLOOG
# BB         BB

# %% [markdown]
# ## Previous Day Price

# %%
c.yesterday(symbol)
# Out:
# {'date': '2019-05-02',
#  'open': 210.59,
#  'close': 209.18,
#  'high': 222.37,
#  'low': 217.36,
#  'volume': 32624128,
#  'uOpen': 218.62,
#  'uClose': 212.19,
#  'uHigh': 214.58,
#  'uLow': 213.86,
#  'uVolume': 32037621,
#  'change': 0,
#  'changePercent': 0,
#  'changeOverTime': 0,
#  'symbol': 'AAPL'}

# %%
c.yesterdayDF(symbol)
# Out:
#         change  changeOverTime  changePercent   close       date    high  \
# symbol
# AAPL         0               0              0  213.03 2019-05-02  221.03
#
#            low    open  uClose   uHigh    uLow  uOpen   uVolume    volume
# symbol
# AAPL    211.48  216.38  211.75  218.69  213.66  214.6  32922155  32845282

# %%
c.marketYesterday()['A']
# Out:
# {'symbol': 'A',
#  'date': '2019-02-19',
#  'open': 80,
#  'high': 80.72,
#  'low': 78.49,
#  'close': 80.3,
#  'volume': 3103842,
#  'uOpen': 80,
#  'uHigh': 81.74,
#  'uLow': 77.63,
#  'uClose': 80.25,
#  'uVolume': 2976503,
#  'change': None,
#  'changePercent': None}

# %%
c.marketYesterdayDF().head()
# Out:
#        change changePercent  close       date   high    low  open  uClose  \
# symbol
# A        None          None  79.10 2019-02-19  79.47  78.17  80.0   81.31
# AAALF    None          None  32.90 2019-02-19   0.00   0.00   0.0   32.90
# AAALY    None          None  34.00 2016-06-13   0.00   0.00   0.0   36.00
# AAAG     None          None   0.44 2016-06-27   0.00   0.00   0.0    0.44
# AAADX    None          None  16.54 2019-02-19   0.00   0.00   0.0   16.13
#
#         uHigh   uLow  uOpen  uVolume   volume
# symbol
# A       80.72  79.67   78.0  3030819  3009093
# AAALF    0.00   0.00    0.0        0        0
# AAALY    0.00   0.00    0.0        0        0
# AAAG     0.00   0.00    0.0        0        0
# AAADX    0.00   0.00    0.0        0        0

# %% [markdown]
# ## Price

# %%
c.price(symbol)
# Out:
# 214.88

# %%
c.priceDF(symbol)
# Out:
#     price
# 0  217.12

# %% [markdown]
# ## Price Target

# %%
c.priceTarget(symbol)
# Out:
# {'symbol': 'AAPL',
#  'updatedDate': '2019-05-04',
#  'priceTargetAverage': 221.38,
#  'priceTargetHigh': 254,
#  'priceTargetLow': 150,
#  'numberOfAnalysts': 34}

# %%
c.priceTargetDF(symbol)
# Out:
#    numberOfAnalysts  priceTargetAverage  priceTargetHigh  priceTargetLow  \
# 0                33              214.96              246             154
#
#   symbol updatedDate
# 0   AAPL  2019-05-01

# %% [markdown]
# ## Quote

# %%
c.quote(symbol)
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'calculationPrice': 'tops',
#  'open': 213.67,
#  'openTime': 1624783137864,
#  'close': 215.64,
#  'closeTime': 1558698108844,
#  'high': 219,
#  'low': 219.57,
#  'latestPrice': 221.22,
#  'latestSource': 'IEX real time price',
#  'latestTime': '2:41:10 PM',
#  'latestUpdate': 1577234623964,
#  'latestVolume': 14843762,
#  'iexRealtimePrice': 214.04,
#  'iexRealtimeSize': 101,
#  'iexLastUpdated': 1588318119743,
#  'delayedPrice': 213.71,
#  'delayedPriceTime': 1570643199842,
#  'extendedPrice': 218.81,
#  'extendedChange': -0.53,
#  'extendedChangePercent': -0.00253,
#  'extendedPriceTime': 1566201810913,
#  'previousClose': 209.95,
#  'change': 2.09,
#  'changePercent': 0.00988,
#  'iexMarketPercent': 0.03377470793511923,
#  'iexVolume': 487838,
#  'avgTotalVolume': 29272164,
#  'iexBidPrice': 221.1,
#  'iexBidSize': 102,
#  'iexAskPrice': 214.69,
#  'iexAskSize': 202,
#  'marketCap': 1003362683891,
#  'peRatio': 17.99,
#  'week52High': 239.96,
#  'week52Low': 148,
#  'ytdChange': 0.347273}

# %%
c.quoteDF(symbol)
# Out:
#         avgTotalVolume calculationPrice  change  changePercent   close  \
# symbol
# AAPL          30149021             tops    2.05           0.01  216.89
#
#                      closeTime  companyName  delayedPrice  \
# symbol
# AAPL   2021-02-21 12:24:33.509  Apple, Inc.        212.66
#
#               delayedPriceTime  extendedChange  ...  latestVolume     low  \
# symbol                                          ...
# AAPL   2019-05-06 18:43:42.365           -0.54  ...      14801760  215.81
#
#            marketCap    open                openTime  peRatio  previousClose  \
# symbol
# AAPL    977286843212  217.05 2020-03-15 06:57:20.309    17.93         213.88
#
#         week52High week52Low  ytdChange
# symbol
# AAPL        235.79       144   0.349912
#
# [1 rows x 37 columns]

# %% [markdown]
# # Recommendation Trends

# %% [markdown]
# # Sector Performance

# %%
c.sectorPerformance()
# Out:
# [{'type': 'tserco',
#   'name': 'yrgenE',
#   'performance': 0.0144,
#   'lastUpdated': 1572008874832},
#  {'type': 'trecso',
#   'name': 'iteiuoCcoesa smnrnryrD',
#   'performance': 0.01264,
#   'lastUpdated': 1601614087278},
#  {'type': 'tresoc',
#   'name': 'adslIrtusni',
#   'performance': 0.01095,
#   'lastUpdated': 1626429313971},
#  {'type': 'esrcto',
#   'name': 'naaicliFns',
#   'performance': 0.00933,
#   'lastUpdated': 1593576606099},
#  {'type': 'tceros',
#   'name': 'Msaelitar',
#   'performance': 0.00902,
#   'lastUpdated': 1591052632264},
#  {'type': 'rocest',
#   'name': 'uConevsnimrSii cameotc',
#   'performance': 0.00892,
#   'lastUpdated': 1611437712686},
#  {'type': 'stocre',
#   'name': 'lTyohcegon',
#   'performance': 0.00826,
#   'lastUpdated': 1582061216524},
#  {'type': 'otcsre',
#   'name': 'mteosruSel Capns',
#   'performance': 0.00755,
#   'lastUpdated': 1600150999206},
#  {'type': 'srceto',
#   'name': 'se RltaaEet',
#   'performance': 0.0074,
#   'lastUpdated': 1627568070372},
#  {'type': 'srtcoe',
#   'name': 'ieUitstli',
#   'performance': 0.00706,
#   'lastUpdated': 1601791987812},
#  {'type': 'ecstro',
#   'name': 'teaCa hleHr',
#   'performance': 0.00635,
#   'lastUpdated': 1561400524763}]

# %%
c.sectorPerformanceDF()
# Out:
#                                    lastUpdated  performance    type
# name
# yeEngr                 2021-07-11 23:44:51.853      0.01450  ocrtes
# i DrmiyCctsrouseenoarn 2020-11-17 08:41:38.772      0.01279  cortse
# sltadIisrnu            2020-11-09 19:23:55.734      0.01060  coster
# asinaicnlF             2019-05-15 08:41:54.812      0.00955  erotcs
# aleastrMi              2020-02-19 20:44:53.760      0.00902  tcrseo
# mCnoier ntScaeucioismv 2021-05-17 11:22:19.016      0.00866  orctse
# gnohTcyloe             2021-06-07 10:01:50.405      0.00835  etcosr
# pCmsestl Sernoau       2021-05-22 16:12:53.372      0.00729  soterc
# RsataelE et            2019-05-18 02:47:36.846      0.00730  trosec
# iseltiiUt              2020-05-12 07:39:39.627      0.00700  scotre
# helarH Ceta            2020-04-20 15:27:33.574      0.00626  etrosc

# %% [markdown]
# ## Splits

# %%
c.splits(symbol)
# Out:
# []

# %%
c.splitsDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Upcoming Events

# %% [markdown]
# ## Volume By Venue

# %%
c.volumeByVenue(symbol)
# Out:
# [{'volume': 20762,
#   'venue': 'SEXA',
#   'venueName': 'raN iYcESAnem',
#   'date': '2019-05-03',
#   'marketPercent': 0.001488508761431121,
#   'avgMarketPercent': 0.001409896118866473},
#  {'volume': 31711,
#   'venue': 'ICXS',
#   'venueName': 'lYtNoSEn aaiN',
#   'date': '2019-05-03',
#   'marketPercent': 0.00223716651502679,
#   'avgMarketPercent': 0.003021759812480873},
#  {'volume': 76202,
#   'venue': 'XHIC',
#   'venueName': 'CHX',
#   'date': '2019-05-03',
#   'marketPercent': 0.005481539526656284,
#   'avgMarketPercent': 0.02069410165001092},
#  {'volume': 77471,
#   'venue': 'XPHL',
#   'venueName': 'aa qXSdPsN',
#   'date': '2019-05-03',
#   'marketPercent': 0.005384696310262026,
#   'avgMarketPercent': 0.008337002466012758},
#  {'volume': 128168,
#   'venue': 'BATY',
#   'venueName': 'C bYBeXo',
#   'date': '2019-05-03',
#   'marketPercent': 0.009242210959876228,
#   'avgMarketPercent': 0.02131563000217991},
#  {'volume': 135331,
#   'venue': 'DAGE',
#   'venueName': 'DAbEoGC e',
#   'date': '2019-05-03',
#   'marketPercent': 0.00999045831327796,
#   'avgMarketPercent': 0.01250226214876174},
#  {'volume': 176087,
#   'venue': 'NXYS',
#   'venueName': 'EYNS',
#   'date': '2019-05-03',
#   'marketPercent': 0.012474048499100337,
#   'avgMarketPercent': 0.024269413270307322},
#  {'volume': 232372,
#   'venue': 'OXSB',
#   'venueName': 'qNBsda Xa',
#   'date': '2019-05-03',
#   'marketPercent': 0.01688001473453137,
#   'avgMarketPercent': 0.0170338548278168},
#  {'volume': 463264,
#   'venue': 'GIXE',
#   'venueName': 'EXI',
#   'date': '2019-05-03',
#   'marketPercent': 0.03271598218423533,
#   'avgMarketPercent': 0.02851755087552599},
#  {'volume': 597127,
#   'venue': 'EXDG',
#   'venueName': 'DbXCG oEe',
#   'date': '2019-05-03',
#   'marketPercent': 0.04188610278923841,
#   'avgMarketPercent': 0.03969661276355073},
#  {'volume': 1190173,
#   'venue': 'BSTA',
#   'venueName': 'eBbCZXo ',
#   'date': '2019-05-03',
#   'marketPercent': 0.0804759040098382,
#   'avgMarketPercent': 0.0700198885517925},
#  {'volume': 1168561,
#   'venue': 'ARCX',
#   'venueName': 'YaScrENA ',
#   'date': '2019-05-03',
#   'marketPercent': 0.08113361944660735,
#   'avgMarketPercent': 0.0836275286857359},
#  {'volume': 3508149,
#   'venue': 'NSXG',
#   'venueName': 'aNqdas',
#   'date': '2019-05-03',
#   'marketPercent': 0.2476879331877488,
#   'avgMarketPercent': 0.2905134235707101},
#  {'volume': 6829111,
#   'venue': 'TFR',
#   'venueName': ' OcehnffgExa',
#   'date': '2019-05-03',
#   'marketPercent': 0.46698030240930744,
#   'avgMarketPercent': 0.40540786296702314}]

# %%
c.volumeByVenueDF(symbol)
# Out:
#        avgMarketPercent       date  marketPercent      venueName   volume
# venue
# ASEX           0.001383 2019-05-03       0.001450  ANSErYinem ac    20473
# IXCS           0.003026 2019-05-03       0.002236  oY tlNEaniaNS    31871
# XHCI           0.021469 2019-05-03       0.005412            XCH    75846
# LHPX           0.008233 2019-05-03       0.005567     Ns dSaaqPX    79047
# YBTA           0.021336 2019-05-03       0.009189       eC BXbYo   130717
# DAGE           0.012712 2019-05-03       0.009577      oeD bEGAC   138379
# YXSN           0.024281 2019-05-03       0.012247           YNSE   178360
# OBSX           0.017094 2019-05-03       0.016720      s NaadqXB   236310
# EXGI           0.029683 2019-05-03       0.032615            XEI   463804
# GEXD           0.039563 2019-05-03       0.042304       oDGeXEbC   615865
# BTSA           0.069376 2019-05-03       0.082415       obXZCBe   1151055
# RCXA           0.083184 2019-05-03       0.081876      AEN rYSac  1147426
# NSXG           0.294657 2019-05-03       0.246069         aNqsda  3521781
# RTF            0.414634 2019-05-03       0.474572   aExOfgn ehcf  6805023

# %% [markdown]
# # Alternative

# %% [markdown]
# ## crypto

# %%
# c.crypto()

# %%
# c.cryptoDF()

# %% [markdown]
# ## sentiment

# %%
c.sentiment(symbol)
# Out:
# {'sentiment': 0.13148736141906875,
#  'totalScores': 451,
#  'positive': 0.84,
#  'negative': 0.16}

# %%
c.sentimentDF(symbol)
# Out:
#    negative  positive  sentiment  totalScores
# 0      0.16      0.84   0.131487          451

# %% [markdown]
# ## CEO Compensation

# %%
c.ceoCompensation(symbol)
# Out:
# {'symbol': 'AAPL',
#  'name': 'iTk Coom',
#  'companyName': '',
#  'location': 'iCpuAo r,tCne',
#  'salary': 3087798,
#  'bonus': 0,
#  'stockAwards': 0,
#  'optionAwards': 0,
#  'nonEquityIncentives': 9335147,
#  'pensionAndDeferred': 0,
#  'otherComp': 447598,
#  'total': 13420375,
#  'year': '2116'}

# %%
c.ceoCompensationDF(symbol)
# Out:
#    bonus companyName       location      name  nonEquityIncentives  \
# 0      0              tCuAe, oCpinr  ik CooTm              9469413
#
#    optionAwards  otherComp  pensionAndDeferred   salary  stockAwards symbol  \
# 0             0     444379                   0  3137185            0   AAPL
#
#       total  year
# 0  12841052  2089

# %% [markdown]
# # Forex

# %% [markdown]
# ## Exchange Rates

# %% [markdown]
# # IEX Data

# %% [markdown]
# ## TOPS

# %% [markdown]
# ## Last

# %% [markdown]
# ## DEEP

# %% [markdown]
# ## DEEP Auction

# %% [markdown]
# ## DEEP Book

# %% [markdown]
# ## DEEP Operational Halt Status

# %% [markdown]
# ## DEEP Official Price

# %% [markdown]
# ## DEEP Security Event

# %% [markdown]
# ## DEEP Short Sale Price Test Status

# %% [markdown]
# ## DEEP System Event

# %% [markdown]
# ## DEEP Trades

# %% [markdown]
# ## DEEP Trade Break

# %% [markdown]
# ## DEEP Trading Status

# %% [markdown]
# ## Listed Regulation SHO Threshold Securities List In Dev

# %% [markdown]
# ## Listed Short Interest List In Dev

# %% [markdown]
# ## Stats Historical Daily In Dev

# %% [markdown]
# ## Stats Historical Summary

# %% [markdown]
# ## Stats Intraday

# %% [markdown]
# ## Stats Recent

# %% [markdown]
# ## Stats Records

# %% [markdown]
# # API Metadata
