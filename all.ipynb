# %%
import pyEX
symbol = 'AAPL'

# %%
pyEX.bookDF(symbol)
# Out:
#                                                 asks  \
# 0  [{'price': 223.53, 'size': 100, 'timestamp': 1...
#
#                                                 bids  quote.avgTotalVolume  \
# 0  [{'price': 222.35, 'size': 111, 'timestamp': 1...              31073391
#
#   quote.calculationPrice  quote.change  quote.changePercent  quote.close  \
# 0                   tops          5.21              0.02386       218.33
#
#    quote.closeTime quote.companyName  quote.delayedPrice  \
# 0    1536609600401        Apple Inc.              223.89
#
#                          ...                          quote.previousClose  \
# 0                        ...                                       218.33
#
#    quote.primaryExchange  quote.sector  quote.symbol  quote.week52High  \
# 0   Nasdaq Global Select    Technology          AAPL            229.67
#
#    quote.week52Low  quote.ytdChange  systemEvent.systemEvent  \
# 0           149.16          0.30586                        R
#
#    systemEvent.timestamp                                             trades
# 0          1536672600000  [{'price': 223.53, 'size': 100, 'tradeId': 626...
#
# [1 rows x 45 columns]

# %%
pyEX.chartDF(symbol, timeframe='1m').head()
# Out:
#               change  changeOverTime  changePercent   close      high   label  \
# date
# 2018-08-10 -0.619964        0.000000         -0.298  207.53  209.1000  Aug 10
# 2018-08-13  1.340000        0.006457          0.646  208.87  210.9520  Aug 13
# 2018-08-14  0.880000        0.010697          0.421  209.75  210.5600  Aug 14
# 2018-08-15  0.490000        0.013058          0.234  210.24  210.7400  Aug 15
# 2018-08-16  3.080000        0.027900          1.465  213.32  213.8121  Aug 16
#
#                low     open  unadjustedVolume    volume      vwap
# date
# 2018-08-10  206.67  207.360          24611202  24611202  207.8576
# 2018-08-13  207.70  207.700          25890880  25890880  209.5754
# 2018-08-14  208.26  210.155          20748010  20748010  209.4477
# 2018-08-15  208.33  209.220          28807564  28807564  209.4035
# 2018-08-16  211.47  211.750          28500367  28500367  212.9938

# %%
pyEX.companyDF(symbol)
# Out:
#                     CEO companyName  \
# symbol
# AAPL    Timothy D. Cook  Apple Inc.
#
#                                               description  \
# symbol
# AAPL    Apple Inc is designs, manufactures and markets...
#
#                     exchange           industry issueType      sector  \
# symbol
# AAPL    Nasdaq Global Select  Computer Hardware        cs  Technology
#
#                                                      tags  \
# symbol
# AAPL    [Technology, Consumer Electronics, Computer Ha...
#
#                      website
# symbol
# AAPL    http://www.apple.com

# %%
pyEX.collectionsDF('sector', 'Health Care').head()
# Out:
#    avgTotalVolume calculationPrice  change  changePercent     close  \
# 0         3501044             tops -0.7100       -0.00667  106.4200
# 1         2076082             tops  0.0150        0.00472    3.1800
# 2          232013             tops  0.6400        0.00667   95.8900
# 3          579316             tops  0.0375        0.14151    0.2790
# 4         1032847              sip  0.0079        0.01260    0.6271
#
#       closeTime                    companyName  delayedPrice  \
# 0  1.536610e+12          Eli Lilly and Company      105.7300
# 1  1.536610e+12  Community Health Systems Inc.        3.1950
# 2  1.536610e+12                      LHC Group       96.6650
# 3  1.536610e+12       Apricus Biosciences Inc.        0.3029
# 4  1.536610e+12        Histogenics Corporation        0.6350
#
#    delayedPriceTime  extendedChange    ...        open      openTime  peRatio  \
# 0      1.536693e+12          0.0000    ...      106.41  1.536673e+12    21.02
# 1      1.536693e+12          0.0000    ...        3.15  1.536673e+12    -3.55
# 2      1.536693e+12          0.0000    ...       96.02  1.536673e+12    35.36
# 3      1.536693e+12          0.0000    ...        0.26  1.536673e+12    -0.43
# 4      1.536693e+12         -0.0282    ...        0.65  1.536673e+12    -0.68
#
#    previousClose          primaryExchange      sector  symbol  week52High  \
# 0       106.4200  New York Stock Exchange  Healthcare     LLY     107.840
# 1         3.1800  New York Stock Exchange  Healthcare     CYH       7.890
# 2        95.8900     Nasdaq Global Select  Healthcare    LHCG     100.900
# 3         0.2650    NASDAQ Capital Market  Healthcare    APRI       3.342
# 4         0.6271    NASDAQ Capital Market  Healthcare    HSGX       3.350
#
#    week52Low  ytdChange
# 0     73.690   0.275167
# 1      2.660  -0.285459
# 2     58.651   0.562821
# 3      0.250  -0.727302
# 4      0.610  -0.684453
#
# [5 rows x 40 columns]

# %%
pyEX.cryptoDF().head()
# Out:
#     askPrice     askSize avgTotalVolume   bidPrice      bidSize  \
# 0  6247.9900    0.032878           None  6245.5400     0.139244
# 1     4.8513  300.000000           None     4.8496  1093.100000
# 2   181.7100   12.293420           None   181.4500     0.990580
# 3     9.2500   22.450000           None     9.2362    21.620000
# 4     1.7350    0.073000           None     1.7310    69.304000
#
#   calculationPrice   change  changePercent        close      closeTime  \
# 0         realtime -49.1500       -0.00781  6296.201269  1536693632070
# 1         realtime  -0.1364       -0.02736     4.955686  1536693632333
# 2         realtime -11.3600       -0.05888   190.831063  1536693632170
# 3         realtime  -0.1714       -0.01820     9.406352  1536693632300
# 4         realtime  -0.0810       -0.04460     1.813039  1536693631397
#
#      ...          open       openTime peRatio previousClose primaryExchange  \
# 0    ...     6294.6500  1536607232070    None     6293.9700          crypto
# 1    ...        4.9860  1536607232333    None        4.9841          crypto
# 2    ...      192.9200  1536607232170    None      192.9300          crypto
# 3    ...        9.4176  1536607232300    None        9.4159          crypto
# 4    ...        1.8160  1536607231397    None        1.8170          crypto
#
#            sector   symbol  week52High week52Low ytdChange
# 0  cryptocurrency  BTCUSDT        None      None      None
# 1  cryptocurrency  EOSUSDT        None      None      None
# 2  cryptocurrency  ETHUSDT        None      None      None
# 3  cryptocurrency  BNBUSDT        None      None      None
# 4  cryptocurrency  ONTUSDT        None      None      None
#
# [5 rows x 44 columns]

# %%
pyEX.delayedQuoteDF(symbol)
# Out:
#         delayedPrice  delayedPriceTime  delayedSize     high     low  \
# symbol
# AAPL          223.89     1536692733817          100  224.299  216.56
#
#         processedTime
# symbol
# AAPL    1536693633922

# %%
pyEX.dividendsDF(symbol, timeframe='ytd')
# Out:
#             amount declaredDate flag indicated paymentDate qualified  \
# exDate
# 2018-02-09    0.63   2018-02-01                 2018-02-15         Q
#
#             recordDate             type
# exDate
# 2018-02-09  2018-02-12  Dividend income

# %%
pyEX.earningsDF(symbol)
# Out:
#                EPSSurpriseDollar  actualEPS announceTime  consensusEPS  \
# EPSReportDate
# 2018-07-31                  0.17       2.34          AMC          2.17
# 2018-05-01                  0.04       2.73          AMC          2.69
# 2018-02-01                  0.07       3.89          AMC          3.82
# 2017-11-02                  0.20       2.07          AMC          1.87
#
#                estimatedChangePercent  estimatedEPS fiscalEndDate  \
# EPSReportDate
# 2018-07-31                   0.299401          2.17    2018-06-30
# 2018-05-01                   0.280952          2.69    2018-03-31
# 2018-02-01                   0.136905          3.82    2017-12-31
# 2017-11-02                   0.119760          1.87    2017-09-30
#
#               fiscalPeriod  numberOfEstimates  symbolId  yearAgo  \
# EPSReportDate
# 2018-07-31         Q3 2018                 10        11     1.67
# 2018-05-01         Q2 2018                 10        11     2.10
# 2018-02-01         Q1 2018                  9        11     3.36
# 2017-11-02         Q4 2017                 10        11     1.67
#
#                yearAgoChangePercent symbol
# EPSReportDate
# 2018-07-31                 0.401198   AAPL
# 2018-05-01                 0.300000   AAPL
# 2018-02-01                 0.157738   AAPL
# 2017-11-02                 0.239521   AAPL

# %%
pyEX.earningsTodayDF()
# Out:
#        EPSReportDate EPSSurpriseDollar actualEPS announceTime  consensusEPS  \
# symbol
# FRAN      2018-09-11                                      BTO          0.04
# ERYP      2018-09-11                                      BTO         -0.50
# SKIS      2018-09-11                                      BTO         -0.83
# FARM      2018-09-11                                      AMC          0.09
#
#         estimatedChangePercent  estimatedEPS fiscalEndDate fiscalPeriod  \
# symbol
# FRAN                 -0.800000          0.04    2018-07-31      Q2 2019
# ERYP                       NaN         -0.50    2018-06-30      Q2 2018
# SKIS                 -0.296875         -0.83    2018-07-31      Q1 2019
# FARM                 -0.526316          0.09    2018-06-30      Q4 2018
#
#                                                headline          ...           \
# symbol                                                           ...
# FRAN     Francesca's misses by $0.04, misses on revenue          ...
# ERYP                                                NaN          ...
# SKIS    Peak Resorts misses by $0.04, misses on revenue          ...
# FARM                                                NaN          ...
#
#         quote.primaryExchange        quote.sector quote.symbol  \
# symbol
# FRAN     Nasdaq Global Select   Consumer Cyclical         FRAN
# ERYP     Nasdaq Global Select          Healthcare         ERYP
# SKIS     NASDAQ Global Market   Consumer Cyclical         SKIS
# FARM     Nasdaq Global Select  Consumer Defensive         FARM
#
#         quote.week52High  quote.week52Low  quote.ytdChange  symbolId when  \
# symbol
# FRAN               8.480            3.995        -0.539525      2623  bto
# ERYP              30.560            9.640        -0.443634     13767  bto
# SKIS               5.775            4.100        -0.045055      9405  bto
# FARM              35.050           23.600        -0.114122      2400  amc
#
#         yearAgo  yearAgoChangePercent
# symbol
# FRAN       0.20
# ERYP        NaN                   NaN
# SKIS      -0.64
# FARM       0.19
#
# [4 rows x 55 columns]

# %%
pyEX.spreadDF(symbol).head()
# Out:
#    effectiveQuoted  effectiveSpread  priceImprovement venue   venueName  \
# 0         0.555187         0.016885          0.007512  XCHI         CHX
# 1         0.915946         0.014543          0.000983  XBOS   Nasdaq BX
# 2         0.908112         0.014018          0.001121  XPHL  Nasdaq PSX
# 3         0.869961         0.013518          0.001382  BATY    Cboe BYX
# 4         0.964371         0.012823          0.000408  ARCX   NYSE Arca
#
#      volume
# 0     35618
# 1   6564857
# 2   3179170
# 3   3965519
# 4  42571747

# %%
pyEX.financialsDF(symbol)
# Out:
#              cashChange     cashFlow  costOfRevenue  currentAssets  \
# reportDate
# 2018-06-30 -13088000000  14488000000    32844000000   115761000000
# 2018-03-31  17568000000  15130000000    37715000000   130053000000
# 2017-12-31   7202000000  28293000000    54381000000   143810000000
# 2017-09-30   1718000000  15122000000    32648000000   128645000000
#
#             currentCash  currentDebt  grossProfit    netIncome  \
# reportDate
# 2018-06-30  31971000000  17472000000  20421000000  11519000000
# 2018-03-31  45059000000  20478000000  23422000000  13822000000
# 2017-12-31  27491000000  18478000000  33912000000  20065000000
# 2017-09-30  20289000000  18473000000  19931000000  10714000000
#
#             operatingExpense operatingGainsLosses  operatingIncome  \
# reportDate
# 2018-06-30        7809000000                 None      12612000000
# 2018-03-31        7528000000                 None      15894000000
# 2017-12-31        7638000000                 None      26274000000
# 2017-09-30        6811000000                 None      13120000000
#
#             operatingRevenue  researchAndDevelopment  shareholderEquity  \
# reportDate
# 2018-06-30       53265000000              3701000000       114949000000
# 2018-03-31       61137000000              3378000000       126878000000
# 2017-12-31       88293000000              3407000000       140199000000
# 2017-09-30       52579000000              2997000000       134047000000
#
#              totalAssets    totalCash     totalDebt totalLiabilities  \
# reportDate
# 2018-06-30  349197000000  70970000000  114600000000             None
# 2018-03-31  367502000000  87940000000  121840000000             None
# 2017-12-31  406794000000  77153000000  122400000000             None
# 2017-09-30  375319000000  74181000000  115680000000             None
#
#             totalRevenue symbol
# reportDate
# 2018-06-30   53265000000   AAPL
# 2018-03-31   61137000000   AAPL
# 2017-12-31   88293000000   AAPL
# 2017-09-30   52579000000   AAPL

# %%
pyEX.ipoTodayDF()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.ipoUpcomingDF()
# Out:
#                                      address      amount  \
# 0             BUILDING 20, NO. 56 ANTUO ROAD  1160000000
# 1              3-4/F, NO.295 ZUCHONGZHI ROAD   139500000
# 2            400 EAST JAMIE COURT, SUITE 302    75000000
# 3     11/F BLDG 3, XINGCHUANG TECHNOLOGY PLZ   128000000
# 4   7 AVENUE DE GRANDE BRETAGNE, OFFICE 1182   100000002
# 5                    11325 RANDOM HILLS ROAD    34125000
# 6                        1039 NW 63RD STREET    64837500
# 7       211 OLD STREET, THE BOWER, 4TH FLOOR   600056016
# 8                        2500 INNOVATION WAY  1352350000
# 9                    410 TOWNSEND, SUITE 300   200000000
# 10                          750 THIRD AVENUE    79999995
# 11                     807 LAS CIMAS PARKWAY   105000000
#
#                                          auditor  \
# 0                                  Not Specified
# 1                                  Not Specified
# 2               Computershare Trust Company, N.A
# 3                                  Not Specified
# 4               Computershare Trust Company, N.A
# 5               Computershare Trust Company, N.A
# 6            Broadridge Financial Solutions, Inc
# 7               Computershare Trust Company, N.A
# 8               Computershare Trust Company, N.A
# 9   American Stock Transfer & Trust Company, LLC
# 10  American Stock Transfer & Trust Company, LLC
# 11                        Equiniti Trust Company
#
#                                   businessDescription  \
# 0   Our mission is to shape a joyful lifestyle by ...
# 1   Our mission is to build the largest integrated...
# 2   We are a clinical-stage biopharmaceutical comp...
# 3   Our Mission &#10;  &#10; Bring fun and value t...
# 4   We are a growth-oriented international owner a...
# 5   FVCBankcorp, Inc. is the registered bank holdi...
# 6   We are Bank7 Corp., a bank holding company hea...
# 7   Farfetch exists for the love of fashion. We be...
# 8   Founded in 1954 as part of Eli Lilly and Compa...
# 9   We founded Eventbrite to bring the world toget...
# 10  We are a late-stage clinical biopharmaceutical...
# 11  We are a growth-oriented Delaware corporation ...
#
#                             ceo         cik                  city  \
# 0                        Bin Li  0001736541       SHANGHAI 201804
# 1                   Junling Liu  0001738906       SHANGHAI 201203
# 2                 Martin Babler  0001510487   SOUTH SAN FRANCISCO
# 3                        Lei Li  0001733298       SHANGHAI 200120
# 4              Angeliki Frangou  0001707210  MONTE CARLO MC 98000
# 5                David W. Pijor  0001675644               FAIRFAX
# 6              Thomas L. Travis  0001746129         OKLAHOMA CITY
# 7                    José Neves  0001740915       LONDON EC1V 9NR
# 8            Jeffrey N. Simmons  0001739104            GREENFIELD
# 9                   Julia Hartz  0001475115         SAN FRANCISCO
# 10  Claus Juan Moller San Pedro  0001722964              NEW YORK
# 11           George B. Peyton V  0001740321                AUSTIN
#
#                                        companyCounsel  \
# 0          [Skadden, Arps, Slate, Meagher & Flom LLP]
# 1          [Skadden, Arps, Slate, Meagher & Flom LLP]
# 2                                        [Cooley LLP]
# 3                    [Simpson Thacher & Bartlett LLP]
# 4      [Fried, Frank, Harris, Shriver & Jacobson LLP]
# 5                                [BuckleySandler LLP]
# 6   [Paul Foster Law Offices, P.C., and Hunton And...
# 7                              [Latham & Watkins LLP]
# 8   [Barnes & Thornburg LLP and Weil, Gotshal & Ma...
# 9                               [Goodwin Procter LLP]
# 10                           [Satterlee Stephens LLP]
# 11                                [Sidley Austin LLP]
#
#                                    companyDescription  \
# 0   Our mission is to shape a joyful lifestyle by ...
# 1   Our mission is to build the largest integrated...
# 2   We are a clinical-stage biopharmaceutical comp...
# 3   Our Mission &#10;  &#10; Bring fun and value t...
# 4   We are a growth-oriented international owner a...
# 5   FVCBankcorp, Inc. is the registered bank holdi...
# 6   We are Bank7 Corp., a bank holding company hea...
# 7   Farfetch exists for the love of fashion. We be...
# 8   Founded in 1954 as part of Eli Lilly and Compa...
# 9   We founded Eventbrite to bring the world toget...
# 10  We are a late-stage clinical biopharmaceutical...
# 11  We are a growth-oriented Delaware corporation ...
#
#                         companyName  ...   stockholderEquity  symbol  \
# 0                          NIO INC.  ...         -3290431000     NIO
# 1                         111, INC.  ...          -159272000      YI
# 2          PRINCIPIA BIOPHARMA INC.  ...          -140306000    PRNB
# 3                    QUTOUTIAO INC.  ...           -76942680     QTT
# 4   NAVIOS MARITIME CONTAINERS INC.  ...           177301000    NMCI
# 5                 FVCBANKCORP, INC.  ...           103966000
# 6                       BANK7 CORP.  ...            77553487    BSVN
# 7                      FARFETCH LTD  ...           432538000    FTCH
# 8          ELANCO ANIMAL HEALTH INC  ...          7586600000    ELAN
# 9                  EVENTBRITE, INC.  ...          -151183000      EB
# 10        Y-MABS THERAPEUTICS, INC.  ...            65521000    YMAB
# 11           REMORA ROYALTIES, INC.  ...           -21706815     RRI
#
#    totalAssets totalExpenses totalLiabilities  \
# 0   1552960000       6683761        669939000
# 1    162107000       2800000         51614000
# 2     32445000       3000000         44220000
# 3    293605399       3600000         82366565
# 4    345753000       3200000        168452000
# 5   1139449000        700000       1035483000
# 6    727607471       1412542        650053984
# 7    600505000       8089262        167967000
# 8   8577400000      18000000        990800000
# 9    638651000       4500000        455816000
# 10    73298000       4400000          7777000
# 11    76173762       4500000         97880577
#
#                           underwriterCounsel  \
# 0                     [Latham & Watkins LLP]
# 1       [Freshfields Bruckhaus Deringer LLP]
# 2                     [Latham & Watkins LLP]
# 3   [Wilson Sonsini Goodrich & Rosati, P.C.]
# 4                     [Latham & Watkins LLP]
# 5                          [Williams Mullen]
# 6                            [Bracewell LLP]
# 7                       [Fenwick & West LLP]
# 8                         [Ropes & Gray LLP]
# 9   [Wilson Sonsini Goodrich & Rosati, P.C.]
# 10                 [Shearman & Sterling LLP]
# 11                    [Latham & Watkins LLP]
#
#                                          underwriters  \
# 0   [BofA Merrill Lynch, Citigroup Global Markets ...
# 1                                                  []
# 2                [Robert W. Baird & Co. Incorporated]
# 3   [China Merchants Securities (HK) Co., Ltd., Ke...
# 4   [BNP Paribas Securities Corp., S. Goldman Advi...
# 5                                                  []
# 6                  [Sandler O’Neill & Partners, L.P.]
# 7   [BNP Paribas Securities Corp., Cowen and Compa...
# 8   [Academy Securities, Inc, Barclays Capital Inc...
# 9   [Stifel Nicolaus & Company, Incorporated, SunT...
# 10                 [BTIG, LLC, Canaccord Genuity LLC]
# 11     [Seaport Global Securities LLC, Stephens Inc.]
#
#                           url  \
# 0                 www.nio.com
# 1              www.111.com.cn
# 2        www.principiabio.com
# 3           www.qutoutiao.net
# 4   www.navios-containers.com
# 5             www.fvcbank.com
# 6               www.bank7.com
# 7           aboutfarfetch.com
# 8              www.elanco.com
# 9          www.eventbrite.com
# 10              www.ymabs.com
# 11    www.remoraroyalties.com
#
#                                         useOfProceeds    zip
# 0   We estimate that we will receive net proceeds ...
# 1   We estimate that we will receive net proceeds ...
# 2   We estimate that we will receive net proceeds ...  94080
# 3   We estimate that we will receive net proceeds ...
# 4   We estimate that we will receive net proceeds ...
# 5   Assuming an initial public offering price of $...  22030
# 6   We estimate that the net proceeds to us from t...  73116
# 7   We estimate that the net proceeds to us from t...
# 8   We estimate that the net proceeds to us from t...  46140
# 9   We estimate that the net proceeds from the sal...  94107
# 10  We estimate that the net proceeds to us from t...  10017
# 11  We will receive net proceeds of approximately ...  78746
#
# [12 rows x 40 columns]

# %%
pyEX.thresholdDF(date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.shortInterestDF(symbol, date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.marketShortInterestDF(date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.stockStatsDF(symbol)
# Out:
#              EBITDA EPSSurpriseDollar  EPSSurprisePercent      beta  \
# symbol
# AAPL    47576000000              None               1.487  1.366314
#
#                 cash companyName  consensusEPS  day200MovingAvg  \
# symbol
# AAPL    151334000000  Apple Inc.          2.69        181.84274
#
#         day30ChangePercent  day50MovingAvg        ...         shortInterest  \
# symbol                                            ...
# AAPL              0.153682       203.76929        ...              42160518
#
#         shortRatio  ttmEPS  week52change week52high  week52low  \
# symbol
# AAPL      1.575257   10.36       39.7158     229.67     149.16
#
#         year1ChangePercent year2ChangePercent  year5ChangePercent  \
# symbol
# AAPL               0.37233           1.139045            2.568743
#
#         ytdChangePercent
# symbol
# AAPL               0.282
#
# [1 rows x 49 columns]

# %%
pyEX.largestTradesDF(symbol).head()
# Out:
#                 price   size timeLabel venue     venueName
# time
# 1536683738978  223.52  32411  12:35:38  ARCX     NYSE Arca
# 1536678288721  221.05  23700  11:04:48  None  Off Exchange
# 1536678033926  220.50  18800  11:00:33  None  Off Exchange
# 1536683738977  223.50  18000  12:35:38  ARCX     NYSE Arca
# 1536674813346  218.87  15000  10:06:53  XNGS        Nasdaq

# %%
pyEX.listDF(option='mostactive')
# Out:
#    avgTotalVolume calculationPrice  change  changePercent   close  \
# 0       111976880             tops   0.005        0.00017   29.89
# 1        33109095             tops  -1.545       -0.03441   44.90
# 2         1858927             tops   4.545        0.10801   42.08
# 3        47238139             tops   0.035        0.00114   30.82
# 4        47009165             tops  -0.145       -0.01159   12.51
# 5        31073391             tops   5.210        0.02386  218.33
# 6        20564617             tops   0.135        0.01386    9.74
# 7        26439425             tops   0.340        0.00217  156.36
# 8        21273468             tops  -0.430       -0.03952   10.88
# 9        23020401             tops  -1.200       -0.02592   46.30
#
#        closeTime                          companyName  delayedPrice  \
# 0  1536609600275          Advanced Micro Devices Inc.        29.985
# 1  1536609600268               Micron Technology Inc.        43.435
# 2  1536609600183    Integrated Device Technology Inc.        46.610
# 3  1536609623204          Bank of America Corporation        30.862
# 4  1536609606743             General Electric Company        12.370
# 5  1536609600401                           Apple Inc.       223.900
# 6  1536609748859                    Snap Inc. Class A         9.890
# 7  1536609669444        Alibaba Group Holding Limited       156.740
# 8  1536609718945  Petroleo Brasileiro S.A.- Petrobras        10.460
# 9  1536609600303                    Intel Corporation        45.190
#
#    delayedPriceTime  extendedChange    ...        open       openTime  \
# 0     1536692737882               0    ...       30.00  1536672600110
# 1     1536692737836               0    ...       43.57  1536672600369
# 2     1536692731056               0    ...       46.85  1536672600415
# 3     1536692736103               0    ...       30.72  1536672620672
# 4     1536692737439               0    ...       12.40  1536672629712
# 5     1536692737230               0    ...      217.91  1536672600480
# 6     1536692736269               0    ...        9.85  1536672600703
# 7     1536692732624               0    ...      153.00  1536672609230
# 8     1536692736643               0    ...       10.45  1536672665924
# 9     1536692736132               0    ...       46.00  1536672600505
#
#    peRatio  previousClose          primaryExchange              sector  \
# 0    87.93          29.89    NASDAQ Capital Market          Technology
# 1     5.04          44.90     Nasdaq Global Select          Technology
# 2    42.39          42.08     Nasdaq Global Select          Technology
# 3    14.02          30.82  New York Stock Exchange  Financial Services
# 4    13.59          12.51  New York Stock Exchange         Industrials
# 5    21.58         218.33     Nasdaq Global Select          Technology
# 6    -8.74           9.74  New York Stock Exchange          Technology
# 7    45.55         156.36  New York Stock Exchange   Consumer Cyclical
# 8    10.56          10.88  New York Stock Exchange              Energy
# 9    11.28          46.30     Nasdaq Global Select          Technology
#
#    symbol  week52High  week52Low  ytdChange
# 0     AMD     29.9400       9.04   1.722392
# 1      MU     64.6600      32.81  -0.006244
# 2    IDTI     46.6250      24.96   0.478694
# 3     BAC     33.0500      23.08   0.045026
# 4      GE     25.2100      11.94  -0.303831
# 5    AAPL    229.6700     149.16   0.305860
# 6    SNAP     21.2200       9.55  -0.334635
# 7    BABA    211.7000     155.00  -0.146428
# 8     PBR     17.2000       9.02  -0.018834
# 9    INTC     57.5995      35.14  -0.019127
#
# [10 rows x 40 columns]

# %%
pyEX.logoNotebook(symbol)
# Out:
# <img src="https://storage.googleapis.com/iex/api/logos/AAPL.png"/>

# %%
pyEX.newsDF(symbol, count=10)
# Out:
#                                                                     headline  \
# datetime
# 2018-09-11T09:30:14-04:00  Micron Investors: Be Happy About The Share Pri...
# 2018-09-11T09:09:59-04:00               Big Ticket 2018 Picks: August Update
# 2018-09-11T09:02:02-04:00  UBS raises its Apple target on potential 20% s...
# 2018-09-11T09:00:17-04:00  The Sad Decline Of International Business Mach...
# 2018-09-11T07:09:52-04:00   5 Reasons Apple Is A Dividend Growth Dream Stock
#
#                                                                        image  \
# datetime
# 2018-09-11T09:30:14-04:00  https://api.iextrading.com/1.0/stock/aapl/news...
# 2018-09-11T09:09:59-04:00  https://api.iextrading.com/1.0/stock/aapl/news...
# 2018-09-11T09:02:02-04:00  https://api.iextrading.com/1.0/stock/aapl/news...
# 2018-09-11T09:00:17-04:00  https://api.iextrading.com/1.0/stock/aapl/news...
# 2018-09-11T07:09:52-04:00  https://api.iextrading.com/1.0/stock/aapl/news...
#
#                                                                      related  \
# datetime
# 2018-09-11T09:30:14-04:00  AAPL,Computer Hardware,CON31167138,HXSCF,MU,NA...
# 2018-09-11T09:09:59-04:00  AAPL,AMZN,Computer Hardware,CON31167138,LLL:CA...
# 2018-09-11T09:02:02-04:00  AAPL,Computer Hardware,CON31167138,NASDAQ01,Co...
# 2018-09-11T09:00:17-04:00  AAPL,AMZN,BABA,Computer Hardware,CON31167138,C...
# 2018-09-11T07:09:52-04:00  AAPL,Computer Hardware,CON31167138,NASDAQ01,Co...
#
#                                  source  \
# datetime
# 2018-09-11T09:30:14-04:00  SeekingAlpha
# 2018-09-11T09:09:59-04:00  SeekingAlpha
# 2018-09-11T09:02:02-04:00  SeekingAlpha
# 2018-09-11T09:00:17-04:00  SeekingAlpha
# 2018-09-11T07:09:52-04:00  SeekingAlpha
#
#                                                                      summary  \
# datetime
# 2018-09-11T09:30:14-04:00     Micron's ( MU ) shares declined substantial...
# 2018-09-11T09:09:59-04:00       In early January, I published my top pick...
# 2018-09-11T09:02:02-04:00        UBS  maintains  a Buy rating on Apple (N...
# 2018-09-11T09:00:17-04:00      IBM is no longer a tech company. They have...
# 2018-09-11T07:09:52-04:00      (Source:  imgflip )    Apple ( AAPL ) has ...
#
#                                                                          url
# datetime
# 2018-09-11T09:30:14-04:00  https://api.iextrading.com/1.0/stock/aapl/arti...
# 2018-09-11T09:09:59-04:00  https://api.iextrading.com/1.0/stock/aapl/arti...
# 2018-09-11T09:02:02-04:00  https://api.iextrading.com/1.0/stock/aapl/arti...
# 2018-09-11T09:00:17-04:00  https://api.iextrading.com/1.0/stock/aapl/arti...
# 2018-09-11T07:09:52-04:00  https://api.iextrading.com/1.0/stock/aapl/arti...

# %%
pyEX.marketNewsDF(count=10)
# Out:
#                     datetime  \
# 0  2018-09-11T15:19:00-04:00
# 1  2018-09-11T15:00:00-04:00
# 2  2018-09-11T14:52:00-04:00
# 3  2018-09-11T14:43:00-04:00
# 4  2018-09-11T14:27:00-04:00
# 5  2018-09-11T14:12:00-04:00
# 6  2018-09-11T14:01:00-04:00
# 7  2018-09-11T14:01:00-04:00
# 8  2018-09-11T13:44:34-04:00
# 9  2018-09-11T13:22:00-04:00
#
#                                             headline  \
# 0  EQUITY ALERT: Rosen Law Firm Files Securities ...
# 1  Valiant Integrated Services Re-Awarded Key Con...
# 2  Red Cross Prepares for Massive Relief Response...
# 3  NASA to Preview Two International Space Statio...
# 4  As Florence Approaches, Realtors&#xAE; Renew C...
# 5  Maya Elisabeth Co-Founder of Whoopi & Maya to ...
# 6  Gas Ranges and Wall Ovens Recalled by Prizer-P...
# 7  Virginia Natural Gas Prepares for Hurricane Fl...
# 8  Atlanta Fed cuts U.S. third-quarter GDP view b...
# 9  Subaru of America and Mt. Hood Community Colle...
#
#                                                image  \
# 0  https://api.iextrading.com/1.0/stock/market/ne...
# 1  https://api.iextrading.com/1.0/stock/market/ne...
# 2  https://api.iextrading.com/1.0/stock/market/ne...
# 3  https://api.iextrading.com/1.0/stock/market/ne...
# 4  https://api.iextrading.com/1.0/stock/market/ne...
# 5  https://api.iextrading.com/1.0/stock/market/ne...
# 6  https://api.iextrading.com/1.0/stock/market/ne...
# 7  https://api.iextrading.com/1.0/stock/market/ne...
# 8  https://api.iextrading.com/1.0/stock/market/ne...
# 9  https://api.iextrading.com/1.0/stock/market/ne...
#
#                                              related         source  \
# 0  APPSOFTW,Economy Business and Finance,Financia...  Business Wire
# 1  Aerospace and Defense,Aerospace/Defense - Majo...    PR Newswire
# 2  Breaking News,DISACCID,FAMILY01,Futures Tradin...    PR Newswire
# 3  Aerospace and Defense,Aerospace/Defense - Majo...    PR Newswire
# 4  BADWEATH,Banking and Finance,Banking,DELAWARE,...    PR Newswire
# 5  CALIFORN,Consumer Goods,Consumer Affairs,Educa...    PR Newswire
# 6  Appliances,CANADA01,Consumer Goods,Consumer Af...    PR Newswire
# 7  Appliances,Breaking News,Commodities,Energy,En...    PR Newswire
# 8                             FEDRESRV,National News   SeekingAlpha
# 9  Automotive,Education,INDIANA1,Industrial Goods...    PR Newswire
#
#                                              summary  \
# 0       Rosen Law Firm, a global investor rights ...
# 1        HERNDON, Va. ,  Sept. 11, 2018  /PRNewsw...
# 2        WASHINGTON ,  Sept. 11, 2018  /PRNewswir...
# 3         WASHINGTON  ,  Sept. 11, 2018   /PRNews...
# 4        WASHINGTON ,  Sept. 11, 2018  /PRNewswir...
# 5        PARAMUS, N.J. , Sept. 11,2018 /PRNewswir...
# 6        WASHINGTON , Sept.11, 2018 /PRNewswire/ ...
# 7        VIRGINIA BEACH, Va. ,  Sept. 11, 2018  /...
# 8       The U.S. economy is expected to expand at...
# 9        CAMDEN, N.J. ,  Sept. 11, 2018  /PRNewsw...
#
#                                                  url
# 0  https://api.iextrading.com/1.0/stock/market/ar...
# 1  https://api.iextrading.com/1.0/stock/market/ar...
# 2  https://api.iextrading.com/1.0/stock/market/ar...
# 3  https://api.iextrading.com/1.0/stock/market/ar...
# 4  https://api.iextrading.com/1.0/stock/market/ar...
# 5  https://api.iextrading.com/1.0/stock/market/ar...
# 6  https://api.iextrading.com/1.0/stock/market/ar...
# 7  https://api.iextrading.com/1.0/stock/market/ar...
# 8  https://api.iextrading.com/1.0/stock/market/ar...
# 9  https://api.iextrading.com/1.0/stock/market/ar...

# %%
pyEX.ohlcDF(symbol)
# Out:
#                open         close     high     low
# price  2.179100e+02  2.183300e+02  224.299  216.56
# time   1.536673e+12  1.536610e+12  224.299  216.56

# %%
pyEX.marketOhlcDF()
# Out:
#                                           SNOAW  \
# close                                       NaN
# high                                        NaN
# low                                         NaN
# open   {'price': 0.0351, 'time': 1536684273340}
#
#                                            LEG  \
# close                                      NaN
# high                                       NaN
# low                                        NaN
# open   {'price': 46.04, 'time': 1536672609468}
#
#                                            GRUB  \
# close                                       NaN
# high                                        NaN
# low                                         NaN
# open   {'price': 141.01, 'time': 1536672600365}
#
#                                           CDNA  \
# close                                      NaN
# high                                       NaN
# low                                        NaN
# open   {'price': 27.19, 'time': 1536672600286}
#
#                                          NOMD  \
# close                                     NaN
# high                                      NaN
# low                                       NaN
# open   {'price': 20.5, 'time': 1536672600653}
#
#                                           TRGP  \
# close                                     None
# high                                      None
# low                                       None
# open   {'price': 54.21, 'time': 1536672600758}
#
#                                           GLMD  \
# close                                      NaN
# high                                       NaN
# low                                        NaN
# open   {'price': 13.25, 'time': 1536672600575}
#
#                                             RTH  \
# close                                       NaN
# high                                        NaN
# low                                         NaN
# open   {'price': 111.11, 'time': 1536672600083}
#
#                                            ZN  \
# close                                     NaN
# high                                      NaN
# low                                       NaN
# open   {'price': 1.33, 'time': 1536672600225}
#
#                                            TK  \
# close                                     NaN
# high                                      NaN
# low                                       NaN
# open   {'price': 6.27, 'time': 1536672767713}
#
#                         ...                     \
# close                   ...
# high                    ...
# low                     ...
# open                    ...
#
#                                            PXF  \
# close                                      NaN
# high                                       NaN
# low                                        NaN
# open   {'price': 41.82, 'time': 1536672600111}
#
#                                         CRBP  \
# close                                    NaN
# high                                     NaN
# low                                      NaN
# open   {'price': 5.4, 'time': 1536672600276}
#
#                                          NTIP  \
# close                                     NaN
# high                                      NaN
# low                                       NaN
# open   {'price': 2.75, 'time': 1536672600022}
#
#                                         CVR  \
# close                                   NaN
# high                                    NaN
# low                                     NaN
# open   {'price': 32, 'time': 1536672921518}
#
#                                          POLA  \
# close                                     NaN
# high                                      NaN
# low                                       NaN
# open   {'price': 5.92, 'time': 1536672600698}
#
#                                           CRH  \
# close                                     NaN
# high                                      NaN
# low                                       NaN
# open   {'price': 31.9, 'time': 1536672600102}
#
#                                          GMTA  \
# close                                     NaN
# high                                      NaN
# low                                       NaN
# open   {'price': 25.1, 'time': 1536672609419}
#
#                                           GVIP  \
# close                                      NaN
# high                                       NaN
# low                                        NaN
# open   {'price': 57.17, 'time': 1536672600076}
#
#                                           KWEB  \
# close                                      NaN
# high                                       NaN
# low                                        NaN
# open   {'price': 45.27, 'time': 1536672600090}
#
#                                           PRGO
# close                                      NaN
# high                                       NaN
# low                                        NaN
# open   {'price': 74.81, 'time': 1536672600676}
#
# [4 rows x 7555 columns]

# %%
pyEX.peersDF(symbol)
# Out:
#        symbol
# symbol
# XLK       XLK

# %%
pyEX.yesterdayDF(symbol)
# Out:
#    change  changePercent   close        date    high     low    open symbol  \
# 0   -2.97         -1.342  218.33  2018-09-10  221.85  216.47  220.95   AAPL
#
#    unadjustedVolume    volume    vwap
# 0          39516453  39516453  218.23

# %%
pyEX.marketYesterdayDF()
# Out:
#                         AABA           A         AAC        AAMC          AA  \
# change                 -1.02        0.53       -0.66           0        1.01
# changePercent         -1.574       0.786      -8.483           0       2.463
# close                   63.8       67.93        7.12       60.05       42.01
# date              2018-09-10  2018-09-10  2018-09-10  2018-09-10  2018-09-10
# high                   64.44       68.41        7.79         NaN       42.69
# low                    63.08       67.72        7.07         NaN       41.64
# open                    63.5       67.82        7.79         NaN       42.09
# symbol                  AABA           A         AAC        AAMC          AA
# unadjustedVolume    14090369     2065707      155761         193     3405903
# volume              14090369     2065707      155761         193     3405903
# vwap                 63.7968     68.0911      7.3599         NaN     42.1058
#
#                         AAAU         AAL         AAP        AAOI        AAON  \
# change                 -0.01           1       -0.35        1.09       -0.15
# changePercent         -0.084       2.602      -0.209       3.402      -0.381
# close                  11.95       39.43      166.93       33.13       39.25
# date              2018-09-10  2018-09-10  2018-09-10  2018-09-10  2018-09-10
# high                   11.97       39.49      169.09       33.36        39.9
# low                    11.94       38.49      166.14        31.9        39.2
# open                   11.97       38.66      168.47       32.07       39.45
# symbol                  AAAU         AAL         AAP        AAOI        AAON
# unadjustedVolume       64347     3901039      910159      752086      142526
# volume                 64347     3901039      910159      752086      142526
# vwap                 11.9533     39.2207     167.173     32.7941     39.4127
#
#                      ...             ZVV       ZWZZT       ZVZZT       ZXZZT  \
# change               ...            0.92         1.5       -0.01       -0.01
# changePercent        ...          18.075          15        -0.1        -0.1
# close                ...            6.01        11.5       10.01        9.99
# date                 ...      2018-09-10  2018-09-10  2018-09-10  2018-09-10
# high                 ...            6.01        11.5       10.02       10.02
# low                  ...               6        11.5         9.9        9.99
# open                 ...               6        11.5         9.9          10
# symbol               ...             ZVV       ZWZZT       ZVZZT       ZXZZT
# unadjustedVolume     ...             700       53250      447385       37475
# volume               ...             700       53250      447385       37475
# vwap                 ...          6.0029        11.5      9.9896     10.0029
#
#                         ZUMZ        ZSAN        ZYNE         ZTO       ZTEST  \
# change                   0.2       -0.15       -0.45       -0.19           0
# changePercent          0.685      -3.695      -6.139      -1.074           0
# close                   29.4        3.91        6.88        17.5          10
# date              2018-09-10  2018-09-10  2018-09-10  2018-09-10  2018-09-10
# high                    29.8      4.1127      7.4499       17.65          10
# low                     28.5         3.9         6.8       17.31          10
# open                    29.7        4.05        7.39       17.59          10
# symbol                  ZUMZ        ZSAN        ZYNE         ZTO       ZTEST
# unadjustedVolume      465361      129558      394207     2101394           0
# volume                465361      129558      394207     2101394           0
# vwap                  29.165       3.994      7.0132     17.4666         NaN
#
#                          ZOM
# change                     0
# changePercent              0
# close                    2.2
# date              2018-09-10
# high                    2.25
# low                     2.16
# open                    2.23
# symbol                   ZOM
# unadjustedVolume       22409
# volume                 22409
# vwap                  2.1933
#
# [11 rows x 8434 columns]

# %%
pyEX.priceDF(symbol)
# Out:
#     price
# 0  223.54

# %%
pyEX.quoteDF(symbol)
# Out:
#         avgTotalVolume calculationPrice  change  changePercent   close  \
# symbol
# AAPL          31073391             tops    5.21        0.02386  218.33
#
#             closeTime companyName  delayedPrice  delayedPriceTime  \
# symbol
# AAPL    1536609600401  Apple Inc.       223.929     1536692751888
#
#         extendedChange    ...          marketCap    open       openTime  \
# symbol                    ...
# AAPL                 0    ...      1079681658040  217.91  1536672600480
#
#         peRatio  previousClose       primaryExchange      sector  week52High  \
# symbol
# AAPL      21.58         218.33  Nasdaq Global Select  Technology      229.67
#
#         week52Low  ytdChange
# symbol
# AAPL       149.16    0.30586
#
# [1 rows x 39 columns]

# %%
pyEX.relevantDF(symbol)
# Out:
#    peers symbols
# 0   True     XLK

# %%
pyEX.sectorPerformanceDF()
# Out:
#       lastUpdated                    name  performance    type
# 0   1536693641626                  Energy      0.01127  sector
# 1   1536693144471  Communication Services      0.01088  sector
# 2   1536693509291              Technology      0.00820  sector
# 3   1536693646851  Consumer Discretionary      0.00750  sector
# 4   1536693026528             Real Estate      0.00327  sector
# 5   1536693551562               Materials      0.00220  sector
# 6   1536693604997              Financials      0.00106  sector
# 7   1536693653781             Industrials      0.00013  sector
# 8   1536693608855             Health Care     -0.00060  sector
# 9   1536693554718               Utilities     -0.00064  sector
# 10  1536693207672        Consumer Staples     -0.00147  sector

# %%
pyEX.splitsDF(symbol, timeframe='ytd')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.volumeByVenueDF(symbol)
# Out:
#     avgMarketPercent        date  marketPercent venue      venueName   volume
# 0           0.001059  2018-08-10       0.000680  XASE  NYSE American    16899
# 1           0.001245  2018-08-10       0.001043  XCIS  NYSE National    25923
# 2           0.009873  2018-08-10       0.006223  BATY       Cboe BYX   154624
# 3           0.008033  2018-08-10       0.008666  XPHL     Nasdaq PSX   215305
# 4           0.009412  2018-08-10       0.009871  EDGA      Cboe EDGA   245237
# 5           0.016532  2018-08-10       0.013727  XBOS      Nasdaq BX   341054
# 6           0.018277  2018-08-10       0.016596  XNYS           NYSE   412332
# 7           0.024119  2018-08-10       0.021018  IEXG            IEX   522198
# 8           0.058238  2018-08-10       0.051591  EDGX      Cboe EDGX  1281783
# 9           0.008867  2018-08-10       0.069947  XCHI            CHX  1737858
# 10          0.092972  2018-08-10       0.103852  ARCX      NYSE Arca  2580224
# 11          0.091778  2018-08-10       0.111274  BATS       Cboe BZX  2764638
# 12          0.289976  2018-08-10       0.250970  XNGS         Nasdaq  6235401
# 13          0.370004  2018-08-10       0.334542   TRF   Off Exchange  8311774

# %%
pyEX.symbolsDF()
# Out:
#             date     iexId  isEnabled  \
# 0     2018-08-10         2       True
# 1     2018-08-10     12042       True
# 2     2018-08-10      7653       True
# 3     2018-08-10      9169       True
# 4     2018-08-10         5       True
# 5     2018-08-10      8148       True
# 6     2018-08-10      7760       True
# 7     2018-08-10         7       True
# 8     2018-08-10         8       True
# 9     2018-08-10      7790       True
# 10    2018-08-10         9       True
# 11    2018-08-10        10       True
# 12    2018-08-10        11       True
# 13    2018-08-10        12       True
# 14    2018-08-10        13       True
# 15    2018-08-10        14       True
# 16    2018-08-10        15       True
# 17    2018-08-10        16       True
# 18    2018-08-10      6667       True
# 19    2018-08-10        17       True
# 20    2018-08-10      5129       True
# 21    2018-08-10        19       True
# 22    2018-08-10        20       True
# 23    2018-08-10        21       True
# 24    2018-08-10        22       True
# 25    2018-08-10        23       True
# 26    2018-08-10      8607       True
# 27    2018-08-10      9600       True
# 28    2018-08-10      9607       True
# 29    2018-08-10        36       True
# ...          ...       ...        ...
# 8663  2018-08-10      7707       True
# 8664  2018-08-10      7708       True
# 8665  2018-08-10      7709       True
# 8666  2018-08-10     14265       True
# 8667  2018-08-10      7907       True
# 8668  2018-08-10      7908       True
# 8669  2018-08-10      7909       True
# 8670  2018-08-10      7910       True
# 8671  2018-08-10     13391       True
# 8672  2018-08-10      7911       True
# 8673  2018-08-10     12759       True
# 8674  2018-08-10     10257       True
# 8675  2018-08-10  10000000       True
# 8676  2018-08-10  10000001       True
# 8677  2018-08-10  10000002       True
# 8678  2018-08-10  10000003       True
# 8679  2018-08-10  10000004       True
# 8680  2018-08-10  10000005       True
# 8681  2018-08-10  10000006       True
# 8682  2018-08-10  10000007       True
# 8683  2018-08-10  10000008       True
# 8684  2018-08-10  10000009       True
# 8685  2018-08-10  10000010       True
# 8686  2018-08-10  10000011       True
# 8687  2018-08-10  10000012       True
# 8688  2018-08-10  10000013       True
# 8689  2018-08-10  10000014       True
# 8690  2018-08-10  10000015       True
# 8691  2018-08-10  10000016       True
# 8692  2018-08-10  10000017       True
#
#                                                    name    symbol    type
# 0                             Agilent Technologies Inc.         A      cs
# 1                                     Alcoa Corporation        AA      cs
# 2                                           Altaba Inc.      AABA      cs
# 3                                     AAC Holdings Inc.       AAC      cs
# 4                       AdvisorShares Dorsey Wright ADR      AADR      et
# 5                          American Airlines Group Inc.       AAL      cs
# 6                  Altisource Asset Management Corp Com      AAMC      cs
# 7                         Atlantic American Corporation      AAME      cs
# 8                                          Aaron's Inc.       AAN      cs
# 9                          Applied Optoelectronics Inc.      AAOI      cs
# 10                                            AAON Inc.      AAON      cs
# 11                           Advance Auto Parts Inc W/I       AAP      cs
# 12                                           Apple Inc.      AAPL      cs
# 13                           American Assets Trust Inc.       AAT      cs
# 14                                Almaden Minerals Ltd.       AAU      cs
# 15                              Advantage Oil & Gas Ltd       AAV      cs
# 16                         Atlas Air Worldwide Holdings      AAWW      cs
# 17    iShares MSCI All Country Asia ex Japan Index Fund      AAXJ      et
# 18                                 Axon Enterprise Inc.      AAXN      cs
# 19                 AllianceBernstein Holding L.P. Units        AB      cs
# 20                             Renmin Tianli Group Inc.      ABAC      cs
# 21                                              ABB Ltd       ABB      cs
# 22                                          AbbVie Inc.      ABBV      cs
# 23                        AmerisourceBergen Corporation       ABC      cs
# 24                                       Ameris Bancorp      ABCB      cs
# 25                          Cambium Learning Group Inc.      ABCD      cs
# 26                               Alcentra Capital Corp.      ABDC      cs
# 27                             Abeona Therapeutics Inc.      ABEO      cs
# 28                                                          ABEOW     N/A
# 29    Ambev S.A. American Depositary Shares (Each re...      ABEV      cs
# ...                                                 ...       ...     ...
# 8663          Virtus Global Dividend & Income Fund Inc.       ZTR      cs
# 8664                                Zoetis Inc. Class A       ZTS      cs
# 8665                                        Zumiez Inc.      ZUMZ      cs
# 8666                                 Zuora Inc. Class A       ZUO      cs
# 8667                                                          ZVV     N/A
# 8668                                                         ZVVV     N/A
# 8669                                  NASDAQ TEST STOCK     ZVZZT     N/A
# 8670                                  NASDAQ TEST STOCK     ZWZZT     N/A
# 8671                                                        ZXIET     N/A
# 8672                                  NASDAQ TEST STOCK     ZXZZT     N/A
# 8673                                     Zymeworks Inc.      ZYME      cs
# 8674                       Zynerba Pharmaceuticals Inc.      ZYNE      cs
# 8675                                        Bitcoin USD   BTCUSDT  crypto
# 8676                                            EOS USD   EOSUSDT  crypto
# 8677                                       Ethereum USD   ETHUSDT  crypto
# 8678                                   Binance Coin USD   BNBUSDT  crypto
# 8679                                       Ontology USD   ONTUSDT  crypto
# 8680                                   Bitcoin Cash USD   BCCUSDT  crypto
# 8681                                        Cardano USD   ADAUSDT  crypto
# 8682                                         Ripple USD   XRPUSDT  crypto
# 8683                                            TrueUSD  TUSDUSDT  crypto
# 8684                                           TRON USD   TRXUSDT  crypto
# 8685                                       Litecoin USD   LTCUSDT  crypto
# 8686                               Ethereum Classic USD   ETCUSDT  crypto
# 8687                                          MIOTA USD  IOTAUSDT  crypto
# 8688                                           ICON USD   ICXUSDT  crypto
# 8689                                            NEO USD   NEOUSDT  crypto
# 8690                                        VeChain USD   VENUSDT  crypto
# 8691                                 Stellar Lumens USD   XLMUSDT  crypto
# 8692                                           Qtum USD  QTUMUSDT  crypto
#
# [8693 rows x 6 columns]

# %%
pyEX.corporateActionsDF(date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.dividendsDF(symbol)
# Out:
#    amount declaredDate      exDate flag indicated paymentDate qualified  \
# 0    0.63   2018-02-01  2018-02-09                 2018-02-15         Q
#
#    recordDate             type
# 0  2018-02-12  Dividend income

# %%
pyEX.nextDayExtDateDF(date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.directoryDF(date=None)
# Out:
#   AdjustedPreviousOfficialClosingPrice         CompanyName  \
# 0                              10.0000  ZEXIT Test Company
# 1                             100.0000  ZXIET Test Company
# 2                               1.0000  ZIEXT Test Company
#
#   CountryofIncorporation   DailyListTimestamp FinancialStatus FirstDateListed  \
# 0                    USA  2018-08-11T00:00:00               0      2017-09-15
# 1                    USA  2018-08-11T00:00:00               0      2017-09-15
# 2                    USA  2018-08-11T00:00:00               0      2017-09-15
#
#   IPOFlag InverseETPFlag IssueDescription IssueSubType      ...        \
# 0       N              N     Common Stock            C      ...
# 1       N              N     Common Stock            C      ...
# 2       N              N     Common Stock            C      ...
#
#   RoundLotSize SICCode        SecurityName SymbolinCMSSymbology  \
# 0          100    5678  ZEXIT Common Stock                ZEXIT
# 1          100    2345  ZXIET Common Stock                ZXIET
# 2          100    1234  ZIEXT Common Stock                ZIEXT
#
#   SymbolinCQSSymbology SymbolinINETSymbology TestIssue  \
# 0                ZEXIT                 ZEXIT         Y
# 1                ZXIET                 ZXIET         Y
# 2                ZIEXT                 ZIEXT         Y
#
#              TransferAgent WhenDistributedFlag WhenIssuedFlag
# 0  American Stock Transfer                   N              N
# 1  American Stock Transfer                   N              N
# 2  American Stock Transfer                   N              N
#
# [3 rows x 27 columns]

# %%
pyEX.topsDF(symbols=None)
# Out:
#       askPrice  askSize  bidPrice  bidSize  lastSalePrice  lastSaleSize  \
# 0            0        0         0        0        168.475             8
# 1            0        0         0        0         21.390            98
# 2            0        0         0        0          0.000             0
# 3            0        0         0        0          0.000             0
# 4            0        0         0        0          3.325           400
# 5            0        0         0        0         10.170           100
# 6            0        0         0        0         13.875           100
# 7            0        0         0        0          3.750           100
# 8            0        0         0        0         62.570             1
# 9            0        0         0        0          1.685           100
# 10           0        0         0        0         80.900           100
# 11           0        0         0        0         28.275           100
# 12           0        0         0        0         21.630            30
# 13           0        0         0        0          0.000             0
# 14           0        0         0        0         11.750           100
# 15           0        0         0        0         16.560           100
# 16           0        0         0        0         31.050           100
# 17           0        0         0        0         26.160             1
# 18           0        0         0        0          0.000             0
# 19           0        0         0        0         63.340           100
# 20           0        0         0        0          0.000             0
# 21           0        0         0        0         63.670           100
# 22           0        0         0        0         51.330           100
# 23           0        0         0        0          0.000             0
# 24           0        0         0        0          8.775             1
# 25           0        0         0        0          0.000             0
# 26           0        0         0        0         13.175           100
# 27           0        0         0        0         43.875             1
# 28           0        0         0        0         47.010            80
# 29           0        0         0        0         14.350           100
# ...        ...      ...       ...      ...            ...           ...
# 8644         0        0         0        0          0.000             0
# 8645         0        0         0        0          0.000             0
# 8646         0        0         0        0         12.100            65
# 8647         0        0         0        0         23.360           100
# 8648         0        0         0        0         70.550             9
# 8649         0        0         0        0          0.000             0
# 8650         0        0         0        0          0.000             0
# 8651         0        0         0        0          3.280           100
# 8652         0        0         0        0         21.690           100
# 8653         0        0         0        0         22.975           100
# 8654         0        0         0        0         25.050           100
# 8655         0        0         0        0         18.310            78
# 8656         0        0         0        0          0.000             0
# 8657         0        0         0        0         91.495            20
# 8658         0        0         0        0         90.430           100
# 8659         0        0         0        0         26.680           200
# 8660         0        0         0        0         15.390           100
# 8661         0        0         0        0          7.195             3
# 8662         0        0         0        0          3.075           400
# 8663         0        0         0        0         56.620           100
# 8664         0        0         0        0         84.125             3
# 8665         0        0         0        0          9.090           100
# 8666         0        0         0        0          2.155           100
# 8667         0        0         0        0          0.000             0
# 8668         0        0         0        0         22.505            64
# 8669         0        0         0        0        180.500           100
# 8670         0        0         0        0          0.000             0
# 8671         0        0         0        0          0.000             0
# 8672         0        0         0        0          0.000             0
# 8673         0        0         0        0        121.220           100
#
#        lastSaleTime    lastUpdated  marketPercent  \
# 0     1533931194107  1533933793387        0.05792
# 1     1533921565002  1533931200000        0.00698
# 2                 0  1533931200000        0.00000
# 3                 0  1533931200000        0.00000
# 4     1533930830526  1533931200000        0.04211
# 5     1533931155936  1533931200000        0.01096
# 6     1533931173779  1533931327589        0.00746
# 7     1533930000018  1533931200000        0.01955
# 8     1533929191233  1533931200000        0.00117
# 9     1533931180072  1533931200000        0.01551
# 10    1533930444720  1533931330982        0.03305
# 11    1533931176143  1533931323224        0.03830
# 12    1533931035719  1533931200000        0.01281
# 13                0  1533931200000        0.00000
# 14    1533923042832  1533931200000        0.00389
# 15    1533931109938  1533931200000        0.08073
# 16    1533931191916  1533931599911        0.02299
# 17    1533930833042  1533931200000        0.00079
# 18                0  1533931200000        0.00000
# 19    1533931187579  1533931324724        0.02380
# 20                0  1533931200000        0.00000
# 21    1533924938424  1533931200068        0.00489
# 22    1533931197881  1533933725478        0.01587
# 23                0  1533931200000        0.00000
# 24    1533931179676  1533931200000        0.01449
# 25                0  1533931200000        0.00000
# 26    1533930314076  1533931200000        0.01268
# 27    1533925351092  1533931200000        0.00007
# 28    1533907807652  1533931200000        0.01313
# 29    1533918390054  1533931200000        0.02402
# ...             ...            ...            ...
# 8644              0  1533900151929        0.00000
# 8645              0  1533931200000        0.00000
# 8646  1533931175123  1533931200432        0.05837
# 8647  1533928250797  1533931200365        0.05025
# 8648  1533931061947  1533931393843        0.05281
# 8649              0  1533931200000        0.00000
# 8650              0  1533931200000        0.00000
# 8651  1533914777367  1533931200000        0.01040
# 8652  1533926011956  1533931200000        0.00316
# 8653  1533927720772  1533931200000        0.01967
# 8654  1533920081599  1533931200000        0.00746
# 8655  1533930859095  1533931200179        0.03205
# 8656              0  1533931200000        0.00000
# 8657  1533931047987  1533933603888        0.19292
# 8658  1533931121118  1533931839228        0.02532
# 8659  1533931198093  1533931200000        0.01084
# 8660  1533931175771  1533931323849        0.01701
# 8661  1533931145125  1533931200000        0.00467
# 8662  1533931195003  1533931200000        0.02770
# 8663  1533931176039  1533931324911        0.01949
# 8664  1533931061105  1533932015900        0.01600
# 8665  1533927539849  1533931200000        0.05562
# 8666  1533918067904  1533931200000        0.00258
# 8667              0  1533931200000        0.00000
# 8668  1533931194625  1533931292951        0.01788
# 8669  1533931120944  1533931200000        0.02143
# 8670              0  1533931200000        0.00000
# 8671              0  1533931200000        0.00000
# 8672              0  1533931200000        0.00000
# 8673  1533929104393  1533931208494        0.03697
#
#                               sector   securityType symbol  volume
# 0                          materials    commonstock    KWR    1378
# 1                                n/a           misc   MHNC     298
# 2                                n/a            etp   DWTR       0
# 3                                n/a        warrant  TACOW       0
# 4        healthcareequipmentservices    commonstock   INFU     400
# 5              diversifiedfinancials    commonstock     AI    3610
# 6            consumerdurablesapparel    commonstock    NLS    1434
# 7                          materials    commonstock    NSU   13001
# 8                                n/a            etp   VYMI     178
# 9                             energy    commonstock    EPE   30792
# 10             diversifiedfinancials    commonstock   FCFS    4121
# 11                      capitalgoods    commonstock    ATU    8964
# 12                               n/a  closedendfund    STK    1130
# 13                         retailing    commonstock    DIT       0
# 14                               n/a  closedendfund    EIM     200
# 15      pharmaceuticalsbiotechnology    commonstock   EIDX    7500
# 16                  softwareservices    commonstock    DBX  507047
# 17                               n/a           misc    EZT       1
# 18      pharmaceuticalsbiotechnology    commonstock    CVM       0
# 19                  softwareservices    commonstock    MMS   16464
# 20                               n/a  closedendfund    HTD       0
# 21                               n/a            etp    DFE     300
# 22                         utilities    commonstock    PEG   35639
# 23                               n/a            etp   FPXI       0
# 24                            energy    commonstock     FI   17386
# 25                               n/a            etp   SYLD       0
# 26                  consumerservices    commonstock    RLH    2116
# 27                               n/a            etp   SMIN       1
# 28                               n/a            etp   GAMR     355
# 29                            energy    royaltytrst    MTR     100
# ...                              ...            ...    ...     ...
# 8644                             n/a            etp   ARVR       0
# 8645                             n/a            etp   SPXN       0
# 8646  commercialprofessionalservices    commonstock   PICO    6365
# 8647                             n/a           misc    JSM     400
# 8648                softwareservices    commonstock   LDOS   22117
# 8649                             n/a        warrant  RWGE+       0
# 8650     technologyhardwareequipment    commonstock    OCC       0
# 8651    pharmaceuticalsbiotechnology    commonstock   NVLN     100
# 8652                             n/a  closedendfund   GBAB     100
# 8653                             n/a  closedendfund    NIE     825
# 8654                             n/a            etp   QYLD     807
# 8655    pharmaceuticalsbiotechnology            adr   DBVT    2738
# 8656                             n/a           misc  SNHNL       0
# 8657                             n/a            etp    BIL   55447
# 8658                consumerservices    commonstock   JACK   20658
# 8659    pharmaceuticalsbiotechnology    commonstock   TSRO    9734
# 8660                      realestate           reit    UMH    1403
# 8661                softwareservices    commonstock   RMNI    1006
# 8662    pharmaceuticalsbiotechnology    commonstock   ACRX    9621
# 8663       householdpersonalproducts    commonstock    EPC   14521
# 8664                    capitalgoods    commonstock   AMWD    1460
# 8665                  transportation    commonstock   CAAP   10360
# 8666                    capitalgoods    commonstock   BWEN     100
# 8667    pharmaceuticalsbiotechnology    commonstock   ARCT       0
# 8668    pharmaceuticalsbiotechnology            adr   TEVA   73054
# 8669     technologyhardwareequipment    commonstock   COHR    9061
# 8670                             n/a           misc  BAC-L       0
# 8671                             n/a            etp    FYT       0
# 8672    pharmaceuticalsbiotechnology            adr   IMRN       0
# 8673     semiconductorssemiconductor    commonstock   CCMP    2859
#
# [8674 rows x 13 columns]

# %%
pyEX.lastDF(symbols=None)
# Out:
#         price  size symbol           time
# 0      58.100   100    BNS  1533930989261
# 1       3.140   100   ACET  1533930360033
# 2       7.890   500   SPPP  1533926214839
# 3      13.025   100   HMTV  1533931108397
# 4      21.660    11    IDX  1533930940747
# 5       0.000     0   RAAX              0
# 6      25.110    19   IBDH  1533913248210
# 7      25.580    53   KEMP  1532546303461
# 8       0.000     0  TRTLU              0
# 9      31.805    43    RPD  1533931187143
# 10     23.750   193  NNN-F  1533839482404
# 11      3.750   100    OCC  1533142567780
# 12     81.160    11    AGM  1533931101457
# 13     22.125   100    ETH  1533931178637
# 14     28.250   100    MSB  1533670004648
# 15     37.820   100   TRNO  1533931150149
# 16      7.020   100     QD  1533931175638
# 17     14.485   100   OXFD  1533930448327
# 18      1.050   200    SLS  1533929936221
# 19      9.090   100   CAAP  1533927539849
# 20     25.975   200   MNTA  1533931198225
# 21     26.240   100  DCP-B  1533660673682
# 22     26.290   100  BATRA  1533919889975
# 23    571.515    25    MTD  1533930535046
# 24     23.000   100    CEE  1533908912749
# 25      8.270   500   TVIZ  1533908048028
# 26     30.190   100    GIL  1533931197102
# 27     25.350  1600  ETP-C  1533919174751
# 28     22.795   200    PST  1533931122245
# 29     52.970   100   COF+  1533067175400
# ...       ...   ...    ...            ...
# 9537   23.405    14  FRT-C  1533914258000
# 9538    7.700    61  GNE-A  1532974260737
# 9539  126.505    21   STRA  1533930942204
# 9540   20.500   200   SNSR  1533844798053
# 9541    1.470   100    DSS  1533325112927
# 9542   32.100   124    FXO  1533930963518
# 9543   18.155   100    PGZ  1533916039672
# 9544   23.560   140  SAN-B  1533665471538
# 9545   52.800   100   FSLR  1533931197823
# 9546    2.520    13   BOSC  1533912467647
# 9547    1.430    37  ROSEW  1533045279226
# 9548   24.530     6    EAB  1533747437754
# 9549    2.100   100   MPVD  1533841459496
# 9550   31.245   100     LB  1533931180972
# 9551    8.200   100   UFAB  1533754382068
# 9552    0.000     0    DYN              0
# 9553   38.800   100     DQ  1533930457897
# 9554   46.090   100   ETSY  1533931182557
# 9555   10.220   100   KAAC  1533930080314
# 9556  104.670   100    XPO  1533931197010
# 9557   33.720   100   SPXH  1521564023719
# 9558   68.670   100    HXL  1533931191587
# 9559    8.450   100   ASB+  1529091544729
# 9560   10.310  1100     BB  1533931193655
# 9561   49.975   200   MEAR  1533755291507
# 9562    5.235   400   TXMD  1533931156261
# 9563    9.260   100   DZSI  1533220086599
# 9564   54.665   100    SNE  1533931191144
# 9565    6.180   100   AMBO  1533325158101
# 9566   17.590   100   MRBK  1533844790011
#
# [9567 rows x 4 columns]

# %%
pyEX.histDF(date=None)
# Out:
#                                             20161212  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161213  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161214  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161215  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161216  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161219  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161220  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161221  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161222  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20161223  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                          ...                          \
# 0                        ...
#
#                                             20180730  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180731  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180801  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180802  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180803  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180806  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180807  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180808  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180809  \
# 0  [{'link': 'https://www.googleapis.com/download...
#
#                                             20180810
# 0  [{'link': 'https://www.googleapis.com/download...
#
# [1 rows x 426 columns]

# %%
pyEX.deepDF(symbol=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
pyEX.bookDF(symbol)
# Out:
#   asks bids  quote.avgTotalVolume quote.calculationPrice  quote.change  \
# 0   []   []              23511202                  close         -0.62
#
#    quote.changePercent  quote.close  quote.closeTime quote.companyName  \
# 0             -0.00298       207.53    1533931200303        Apple Inc.
#
#    quote.delayedPrice                        ...                          \
# 0              207.53                        ...
#
#    quote.previousClose  quote.primaryExchange  quote.sector  quote.symbol  \
# 0               208.15   Nasdaq Global Select    Technology          AAPL
#
#    quote.week52High  quote.week52Low  quote.ytdChange  \
# 0            209.78           149.16         0.215604
#
#    systemEvent.systemEvent  systemEvent.timestamp  \
# 0                        C          1533935400006
#
#                                               trades
# 0  [{'price': 207.56, 'size': 100, 'tradeId': 742...
#
# [1 rows x 45 columns]

# %%
pyEX.tradesDF(symbol)
# Out:
#                                                 AAPL
# 0  [{'price': 207.56, 'size': 100, 'tradeId': 742...

# %%
pyEX.systemEventDF()
# Out:
#   systemEvent      timestamp
# 0           C  1533935400006

# %%
pyEX.tradingStatusDF(symbol)
# Out:
#   AAPL.reason AAPL.status  AAPL.timestamp
# 0                       T   1533900151928

# %%
pyEX.opHaltStatusDF(symbol)
# Out:
#    AAPL.isHalted  AAPL.timestamp
# 0          False   1533900151928

# %%
pyEX.ssrStatusDF(symbol)
# Out:
#   AAPL.detail  AAPL.isSSR  AAPL.timestamp
# 0                   False   1533900151928

# %%
pyEX.securityEventDF(symbol)
# Out:
#   AAPL.securityEvent  AAPL.timestamp
# 0        MarketClose   1533931200000

# %%
pyEX.tradeBreakDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
pyEX.auctionDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
pyEX.statsDF()
# Out:
#                     volume  symbolsTraded   routedVolume       notional  \
# lastUpdated  1533935705532  1533934770065  1533935705532  1533935705532
# value            156589012           5516       30565165     7997154403
#
#               marketShare
# lastUpdated  1.533936e+12
# value        2.327000e-02

# %%
pyEX.recentDF()
# Out:
#          date  isHalfday  litVolume  marketShare  routedVolume     volume
# 0  2018-08-09      False   40794162      0.02702      36295473  161235148
# 1  2018-08-08      False   40163047      0.02668      29986653  161004670
# 2  2018-08-07      False   42872256      0.02671      39619098  169676558
# 3  2018-08-06      False   38947711      0.02448      38033260  146519412
# 4  2018-08-03      False   42117609      0.02701      33036659  163032593
# 5  2018-08-02      False   48705654      0.02760      41153974  186840652
# 6  2018-08-01      False   50400792      0.02781      38771846  192348185

# %%
pyEX.recordsDF()
# Out:
#                       volume symbolsTraded routedVolume     notional
# avg30Value         162076154          5581     34881346  8.60055e+09
# previousDayValue   161235148          5500     36295473  8.13554e+09
# recordDate        2018-02-09    2018-02-06   2016-11-10   2018-02-06
# recordValue        286354807          6381     74855222  1.72697e+10

# %%
pyEX.summaryDF(date=None)
# Out:
#    averageDailyRoutedVolume  averageDailyVolume  averageFillSize  \
# 0               49724407.57         147992555.8              201
#
#    averageMarketShare  averageOrderSize  bin10000Percent  bin10000Trades  \
# 0             0.02435               711          0.00102            5008
#
#    bin1000Percent  bin100Percent  bin101Percent            ...             \
# 0         0.02435        0.73035        0.01605            ...
#
#    venueXCHIFirstWaveRate  venueXCHIFirstWaveWeight  venueXCISFirstWaveRate  \
# 0                 0.82809                   0.00193                 0.94866
#
#    venueXCISFirstWaveWeight  venueXNGSFirstWaveRate  venueXNGSFirstWaveWeight  \
# 0                   0.00272                 0.99161                   0.22478
#
#    venueXNYSFirstWaveRate  venueXNYSFirstWaveWeight  venueXPHLFirstWaveRate  \
# 0                 0.98846                   0.22319                 0.97001
#
#    venueXPHLFirstWaveWeight
# 0                   0.00866
#
# [1 rows x 50 columns]

# %%
pyEX.dailyDF(date=None, last='')
pyEX.marketsDF()
# Out:
#       lastUpdated  marketPercent   mic       tapeA      tapeB      tapeC  \
# 0   1533935705274        0.36054   TRF  1112748264  471232286  841964062
# 1   1533935702782        0.15667  XNGS   351830252  168821295  533522886
# 2   1533933900056        0.13066  XNYS   828276285   23814515   27056447
# 3   1533935702479        0.09591  ARCX   172371142  295297358  177705564
# 4   1533935672432        0.06212  BATS   197201722  108757337  112055439
# 5   1533935702777        0.05595  EDGX   138629869   78363987  159462013
# 6   1533934782935        0.04894  BATY   168670096   85878109   74765356
# 7   1533935659478        0.03078  XBOS   110535283   37950863   58613126
# 8   1533934770066        0.02327  IEXG    89410918   18603313   48574781
# 9   1533935230080        0.01265  EDGA    37318551   24738586   23065402
# 10  1533934735113        0.00755  XPHL    15463177   21317365   14020000
# 11  1533935310078        0.00675  XCIS    22894943   10643766   11900699
# 12  1533932848949        0.00498  XCHI     9362168   11481477   12678125
# 13  1533932297444        0.00323  XASE     4865139   14223134    2631624
#
#    tapeId      venueName      volume
# 0             TRF Volume  2425944612
# 1       Q         NASDAQ  1054174433
# 2       N           NYSE   879147247
# 3       P      NYSE Arca   645374064
# 4       Z       BATS BZX   418014498
# 5       K           EDGX   376455869
# 6       Y       BATS BYX   329313561
# 7       B      NASDAQ BX   207099272
# 8       V            IEX   156589012
# 9       J           EDGA    85122539
# 10      X     NASDAQ PSX    50800542
# 11      C  NYSE National    45439408
# 12      M            CHX    33521770
# 13      A  NYSE American    21719897
