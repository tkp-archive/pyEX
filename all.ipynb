# %%
import pyEX
symbol = 'AAPL'

# %%
pyEX.bookDF(symbol)
# Out:
#    avgTotalVolume calculationPrice  change  changePercent   close  \
# 0      32970994.0            close   -2.37       -0.01077  217.66
#
#                 closeTime companyName  delayedPrice        delayedPriceTime  \
# 0 2018-09-21 20:00:00.016  Apple Inc.        217.66 2018-09-21 20:00:00.208
#
#    extendedChange    ...                   openTime  peRatio previousClose  \
# 0            0.06    ...    2018-09-21 13:30:00.368    21.01        220.03
#
#         primaryExchange      sector symbol   type week52High week52Low  \
# 0  Nasdaq Global Select  Technology   AAPL  quote     229.67    149.16
#
#   ytdChange
# 0  0.267296
#
# [1 rows x 41 columns]

# %%
pyEX.chartDF(symbol, timeframe='1m').head()
# Out:
#             change  changeOverTime  changePercent   close    high   label  \
# date
# 2018-08-23    0.44        0.000000          0.205  215.49  217.05  Aug 23
# 2018-08-24    0.67        0.003109          0.311  216.16  216.90  Aug 24
# 2018-08-27    1.78        0.011369          0.823  217.94  218.74  Aug 27
# 2018-08-28    1.76        0.019537          0.808  219.70  220.54  Aug 28
# 2018-08-29    3.28        0.034758          1.493  222.98  223.49  Aug 29
#
#                low    open  unadjustedVolume    volume      vwap
# date
# 2018-08-23  214.60  214.65          18883224  18883224  215.9624
# 2018-08-24  215.11  216.60          18476356  18476356  216.0586
# 2018-08-27  216.33  217.15          20525117  20525117  217.7725
# 2018-08-28  218.92  219.01          22776766  22776766  219.6874
# 2018-08-29  219.41  220.15          27254804  27254804  221.8049

# %%
pyEX.chartDF(symbol, timeframe='1d').head()
# Out:
#                    average  changeOverTime    close     high     label  \
# date       minute
# 2018-09-21 09:30   220.938        0.000000  221.025  221.090  09:30 AM
#            09:31   220.733       -0.000928  220.340  221.100  09:31 AM
#            09:32   220.236       -0.003177  220.205  220.420  09:32 AM
#            09:33   220.344       -0.002689  220.410  220.550  09:33 AM
#            09:34   220.531       -0.001842  220.620  220.695  09:34 AM
#
#                       low  marketAverage  marketChangeOverTime  marketClose  \
# date       minute
# 2018-09-21 09:30   220.71        220.999              0.000000      221.060
#            09:31   220.20        220.830             -0.000765      220.400
#            09:32   220.12        220.250             -0.003389      220.215
#            09:33   219.98        220.229             -0.003484      220.470
#            09:34   220.31        220.538             -0.002086      220.615
#
#                    marketHigh  marketLow  marketNotional  \
# date       minute
# 2018-09-21 09:30       221.10    220.570    3.550297e+09
#            09:31       221.17    220.190    8.187162e+07
#            09:32       220.46    220.120    4.116364e+07
#            09:33       220.58    219.951    6.558228e+07
#            09:34       220.70    220.291    3.367620e+07
#
#                    marketNumberOfTrades  marketOpen  marketVolume  \
# date       minute
# 2018-09-21 09:30                   2041      220.57      16064788
#            09:31                   2053      221.05        370745
#            09:32                   1805      220.42        186895
#            09:33                   2694      220.22        297791
#            09:34                   1273      220.46        152700
#
#                       notional  numberOfTrades     open  volume
# date       minute
# 2018-09-21 09:30   2237434.785              68  220.995   10127
#            09:31   1149798.940              52  221.050    5209
#            09:32   3398676.435              95  220.420   15432
#            09:33   4481573.315             104  220.200   20339
#            09:34   1616275.680              62  220.475    7329

# %%
pyEX.companyDF(symbol)
# Out:
#                     CEO companyName  \
# symbol
# AAPL    Timothy D. Cook  Apple Inc.
#
#                                               description  \
# symbol
# AAPL    Apple Inc is designs, manufactures and markets...
#
#                     exchange           industry issueType      sector  \
# symbol
# AAPL    Nasdaq Global Select  Computer Hardware        cs  Technology
#
#                                                      tags  \
# symbol
# AAPL    [Technology, Consumer Electronics, Computer Ha...
#
#                      website
# symbol
# AAPL    http://www.apple.com

# %%
pyEX.collectionsDF('sector', 'Health Care').head()
# Out:
#         avgTotalVolume calculationPrice  change  changePercent     close  \
# symbol
# LLY            3339723            close  0.2600        0.00245  106.3300
# CYH            2031571            close -0.1800       -0.05014    3.4100
# LHCG            221774            close  0.4800        0.00490   98.5000
# APRI            603539            close -0.0067       -0.02301    0.2845
# HSGX           1343867            close  0.0059        0.00988    0.6029
#
#                      closeTime                    companyName  delayedPrice  \
# symbol
# LLY    2018-09-21 20:02:54.364          Eli Lilly and Company      106.3300
# CYH    2018-09-21 20:05:04.168  Community Health Systems Inc.        3.4100
# LHCG   2018-09-21 20:00:00.803                      LHC Group       98.5000
# APRI   2018-09-21 20:00:00.715       Apricus Biosciences Inc.        0.2845
# HSGX   2018-09-21 20:00:00.637        Histogenics Corporation        0.6029
#
#               delayedPriceTime  extendedChange    ...        marketCap  \
# symbol                                            ...
# LLY    2018-09-21 20:02:54.364          0.0000    ...     114197128728
# CYH    2018-09-21 20:05:04.168          0.0000    ...        396425247
# LHCG   2018-09-21 20:00:00.803          0.0000    ...       3086315275
# APRI   2018-09-21 20:00:00.715         -0.0045    ...          6669092
# HSGX   2018-09-21 20:00:00.637          0.0021    ...         17358398
#
#            open                openTime  peRatio previousClose  \
# symbol
# LLY     106.310 2018-09-21 13:35:17.644    21.14      106.0700
# CYH       3.540 2018-09-21 13:30:09.381    -3.79        3.5900
# LHCG     97.870 2018-09-21 13:30:00.239    36.08       98.0200
# APRI      0.274 2018-09-21 13:30:00.530    -0.41        0.2912
# HSGX      0.630 2018-09-21 13:30:00.492    -0.64        0.5970
#
#                 primaryExchange      sector week52High week52Low ytdChange
# symbol
# LLY     New York Stock Exchange  Healthcare    107.840  73.69000  0.283203
# CYH     New York Stock Exchange  Healthcare      7.890   2.66000 -0.288979
# LHCG       Nasdaq Global Select  Healthcare    100.900  58.65100  0.603407
# APRI      NASDAQ Capital Market  Healthcare      3.342   0.25000 -0.882168
# HSGX      NASDAQ Capital Market  Healthcare      3.350   0.51011 -0.698864
#
# [5 rows x 39 columns]

# %%
pyEX.cryptoDF().head()
# Out:
#           askPrice       askSize avgTotalVolume   bidPrice      bidSize  \
# symbol
# BTCUSDT  6688.2300      1.096392           None  6688.0000     0.669967
# EOSUSDT     5.9329     10.080000           None     5.9233     3.370000
# ETHUSDT   241.6500      9.928780           None   241.4300     0.222010
# BNBUSDT    10.1973      1.960000           None    10.1750     6.080000
# ONTUSDT     2.0330  15276.866000           None     2.0320  3891.280000
#
#         calculationPrice  change  changePercent        close  \
# symbol
# BTCUSDT         realtime  7.0900        0.00106  6726.109908
# EOSUSDT         realtime  0.0640        0.01091     5.981850
# ETHUSDT         realtime  3.2100        0.01346   242.288159
# BNBUSDT         realtime -0.0106       -0.00104    10.279355
# ONTUSDT         realtime  0.0130        0.00644     2.067140
#
#                       closeTime    ...    marketCap       open  \
# symbol                             ...
# BTCUSDT 2018-09-23 15:38:24.143    ...         None  6678.9900
# EOSUSDT 2018-09-23 15:38:24.254    ...         None     5.8654
# ETHUSDT 2018-09-23 15:38:24.217    ...         None   238.4500
# BNBUSDT 2018-09-23 15:38:23.036    ...         None    10.1856
# ONTUSDT 2018-09-23 15:38:24.484    ...         None     2.0200
#
#                        openTime peRatio previousClose primaryExchange  \
# symbol
# BTCUSDT 2018-09-22 15:38:24.143    None     6677.0200          crypto
# EOSUSDT 2018-09-22 15:38:24.254    None        5.8609          crypto
# ETHUSDT 2018-09-22 15:38:24.217    None      238.4200          crypto
# BNBUSDT 2018-09-22 15:38:23.036    None       10.1920          crypto
# ONTUSDT 2018-09-22 15:38:24.484    None        2.0270          crypto
#
#                  sector  week52High week52Low ytdChange
# symbol
# BTCUSDT  cryptocurrency        None      None      None
# EOSUSDT  cryptocurrency        None      None      None
# ETHUSDT  cryptocurrency        None      None      None
# BNBUSDT  cryptocurrency        None      None      None
# ONTUSDT  cryptocurrency        None      None      None
#
# [5 rows x 43 columns]

# %%
pyEX.delayedQuoteDF(symbol)
# Out:
#         delayedPrice        delayedPriceTime  delayedSize    high     low  \
# symbol
# AAPL          217.66 2018-09-21 20:00:00.208          100  221.36  217.29
#
#         processedTime
# symbol
# AAPL    1537560901166

# %%
pyEX.dividendsDF(symbol, timeframe='ytd')
# Out:
#             amount declaredDate flag indicated paymentDate qualified  \
# exDate
# 2018-02-09    0.63   2018-02-01                 2018-02-15         Q
#
#            recordDate             type
# exDate
# 2018-02-09 2018-02-12  Dividend income

# %%
pyEX.earningsDF(symbol)
# Out:
#                EPSSurpriseDollar  actualEPS announceTime  consensusEPS  \
# EPSReportDate
# 2018-07-31                  0.17       2.34          AMC          2.17
# 2018-05-01                  0.04       2.73          AMC          2.69
# 2018-02-01                  0.07       3.89          AMC          3.82
# 2017-11-02                  0.20       2.07          AMC          1.87
#
#                estimatedChangePercent  estimatedEPS fiscalEndDate  \
# EPSReportDate
# 2018-07-31                   0.299401          2.17    2018-06-30
# 2018-05-01                   0.280952          2.69    2018-03-31
# 2018-02-01                   0.136905          3.82    2017-12-31
# 2017-11-02                   0.119760          1.87    2017-09-30
#
#               fiscalPeriod  numberOfEstimates  symbolId  yearAgo  \
# EPSReportDate
# 2018-07-31         Q3 2018                 10        11     1.67
# 2018-05-01         Q2 2018                 10        11     2.10
# 2018-02-01         Q1 2018                  9        11     3.36
# 2017-11-02         Q4 2017                 10        11     1.67
#
#                yearAgoChangePercent symbol
# EPSReportDate
# 2018-07-31                 0.401198   AAPL
# 2018-05-01                 0.300000   AAPL
# 2018-02-01                 0.157738   AAPL
# 2017-11-02                 0.239521   AAPL

# %%
pyEX.earningsTodayDF()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.spreadDF(symbol).head()
# Out:
#        effectiveQuoted  effectiveSpread  priceImprovement      venueName  \
# venue
# XBOS          0.907927         0.017840          0.001311      Nasdaq BX
# XCHI          0.531676         0.017017          0.007904            CHX
# XCIS          0.967942         0.016349          0.000381  NYSE National
# BATY          0.861067         0.016219          0.001715       Cboe BYX
# XPHL          0.870991         0.015569          0.001828     Nasdaq PSX
#
#         volume
# venue
# XBOS   8472482
# XCHI     58982
# XCIS   1637699
# BATY   5528920
# XPHL   4537196

# %%
pyEX.financialsDF(symbol)
# Out:
#              cashChange     cashFlow  costOfRevenue  currentAssets  \
# reportDate
# 2018-06-30 -13088000000  14488000000    32844000000   115761000000
# 2018-03-31  17568000000  15130000000    37715000000   130053000000
# 2017-12-31   7202000000  28293000000    54381000000   143810000000
# 2017-09-30   1718000000  15122000000    32648000000   128645000000
#
#             currentCash  currentDebt  grossProfit    netIncome  \
# reportDate
# 2018-06-30  31971000000  17472000000  20421000000  11519000000
# 2018-03-31  45059000000  20478000000  23422000000  13822000000
# 2017-12-31  27491000000  18478000000  33912000000  20065000000
# 2017-09-30  20289000000  18473000000  19931000000  10714000000
#
#             operatingExpense operatingGainsLosses  operatingIncome  \
# reportDate
# 2018-06-30        7809000000                 None      12612000000
# 2018-03-31        7528000000                 None      15894000000
# 2017-12-31        7638000000                 None      26274000000
# 2017-09-30        6811000000                 None      13120000000
#
#             operatingRevenue  researchAndDevelopment  shareholderEquity  \
# reportDate
# 2018-06-30       53265000000              3701000000       114949000000
# 2018-03-31       61137000000              3378000000       126878000000
# 2017-12-31       88293000000              3407000000       140199000000
# 2017-09-30       52579000000              2997000000       134047000000
#
#              totalAssets    totalCash     totalDebt totalLiabilities  \
# reportDate
# 2018-06-30  349197000000  70970000000  114600000000             None
# 2018-03-31  367502000000  87940000000  121840000000             None
# 2017-12-31  406794000000  77153000000  122400000000             None
# 2017-09-30  375319000000  74181000000  115680000000             None
#
#             totalRevenue symbol
# reportDate
# 2018-06-30   53265000000   AAPL
# 2018-03-31   61137000000   AAPL
# 2017-12-31   88293000000   AAPL
# 2017-09-30   52579000000   AAPL

# %%
pyEX.ipoTodayDF()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.ipoUpcomingDF().head()
# Out:
#                                  address     amount  \
# symbol
# VIOT    WANSHENG SQUARE, RM 1302 TOWER C  114000000
# ARCE               RUA ELVIRA FERRAZ 250  183333332
# SVMK                   ONE CURIOSITY WAY  135000000
# CBNK                   One Church Street   30087936
# ETTX                  35 GATEHOUSE DRIVE   75000005
#
#                                              auditor  \
# symbol
# VIOT                                   Not Specified
# ARCE                                   Not Specified
# SVMK                Computershare Trust Company, N.A
# CBNK    American Stock Transfer & Trust Company, LLC
# ETTX                Computershare Trust Company, N.A
#
#                                       businessDescription  \
# symbol
# VIOT    Our Mission &#10;  &#10; IoT @ Home: Redefinin...
# ARCE    Our mission is to transform the way students l...
# SVMK    We are a leading global provider of survey sof...
# CBNK    We are Capital Bancorp, Inc., a bank holding c...
# ETTX    We are a clinical-stage biopharmaceutical comp...
#
#                               ceo         cik                         city  \
# symbol
# VIOT                Xiaoping Chen  0001742770  GUANGZHOU, GUANGDONG 510220
# ARCE    Ari de Sá Cavalcante Neto  0001740594     SAO PAULO - SP 04552-040
# SVMK           Alexander J. Lurie  0001739936                    SAN MATEO
# CBNK              Edward F. Barry  0001419536                    Rockville
# ETTX             Manoussos Perros  0001724344                      WALTHAM
#
#                                     companyCounsel  \
# symbol
# VIOT    [Skadden, Arps, Slate, Meagher & Flom LLP]
# ARCE                   [Davis Polk & Wardwell LLP]
# SVMK      [Wilson Sonsini Goodrich & Rosati, P.C.]
# CBNK                      [Holland and Knight LLP]
# ETTX                                  [Cooley LLP]
#
#                                        companyDescription  \
# symbol
# VIOT    Our Mission &#10;  &#10; IoT @ Home: Redefinin...
# ARCE    Our mission is to transform the way students l...
# SVMK    We are a leading global provider of survey sof...
# CBNK    We are Capital Bancorp, Inc., a bank holding c...
# ETTX    We are a clinical-stage biopharmaceutical comp...
#
#                                companyName  ...   status  stockholderEquity  \
# symbol                                      ...
# VIOT             VIOMI TECHNOLOGY CO., LTD  ...    Filed          -14835000
# ARCE                    ARCO PLATFORM LTD.  ...    Filed           73171000
# SVMK                             SVMK INC.  ...    Filed           27609000
# CBNK                   CAPITAL BANCORP INC  ...    Filed           86994094
# ETTX    ENTASIS THERAPEUTICS HOLDINGS INC.  ...    Filed          -71717000
#
#        totalAssets totalExpenses totalLiabilities  \
# symbol
# VIOT     153671000       3843836        105403000
# ARCE     103380000       4246881         30253000
# SVMK     578828000       8000000        551219000
# CBNK    1067786156       1250000        980792062
# ETTX      41503000       3500000          8507000
#
#                                  underwriterCounsel  \
# symbol
# VIOT         [Cleary Gottlieb Steen & Hamilton LLP]
# ARCE                           [White and Case LLP]
# SVMK                         [Latham & Watkins LLP]
# CBNK                      [Covington & Burling LLP]
# ETTX    [Wilmer Cutler Pickering Hale and Dorr LLP]
#
#                                              underwriters  \
# symbol
# VIOT                             [Needham & Company, LLC]
# ARCE    [Allen & Company LLC, BTG Pactual US Capital L...
# SVMK    [Code Advisors LLC, Credit Suisse Securities (...
# CBNK    [Hovde Group, LLC, Sandler O’Neill & Partners,...
# ETTX    [SunTrust Robinson Humphrey, Inc, Wedbush Secu...
#
#                             url  \
# symbol
# VIOT           www.viomi.com.cn
# ARCE    www.arcoeducacao.com.br
# SVMK       www.surveymonkey.com
# CBNK      www.capitalbankmd.com
# ETTX          www.entasistx.com
#
#                                             useOfProceeds    zip
# symbol
# VIOT    We estimate that we will receive net proceeds ...
# ARCE    We estimate that the net proceeds from our iss...
# SVMK    We estimate that the net proceeds to us from t...  94403
# CBNK    Assuming an initial public offering price of $...  20850
# ETTX    We estimate that the net proceeds from our iss...  02451
#
# [5 rows x 39 columns]

# %%
pyEX.thresholdDF(date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.shortInterestDF(symbol, date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.marketShortInterestDF(date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.stockStatsDF(symbol)
# Out:
#              EBITDA EPSSurpriseDollar  EPSSurprisePercent      beta  \
# symbol
# AAPL    47576000000              None               1.487  1.350038
#
#                 cash companyName  consensusEPS  day200MovingAvg  \
# symbol
# AAPL    151334000000  Apple Inc.          2.69        184.13023
#
#         day30ChangePercent  day50MovingAvg        ...         shortInterest  \
# symbol                                            ...
# AAPL              0.048812       209.81448        ...              47549672
#
#         shortRatio  ttmEPS  week52change week52high  week52low  \
# symbol
# AAPL          1.54   10.36       44.0453     229.67     149.16
#
#         year1ChangePercent year2ChangePercent  year5ChangePercent  \
# symbol
# AAPL              0.467626           0.994932            2.391521
#
#         ytdChangePercent
# symbol
# AAPL            0.278066
#
# [1 rows x 49 columns]

# %%
pyEX.largestTradesDF(symbol).head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.listDF(option='mostactive')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.logoNotebook(symbol)
# Out:
# <img src="https://storage.googleapis.com/iex/api/logos/AAPL.png"/>

# %%
pyEX.newsDF(symbol, count=10)
# Out:
#                                                               headline  \
# datetime
# 2018-09-22 17:56:09  Amazon And Apple At A Trillion Dollar: A Follo...
# 2018-09-22 15:08:00  How former Facebook and Google engineer Bret T...
#
#                                                                  image  \
# datetime
# 2018-09-22 17:56:09  https://api.iextrading.com/1.0/stock/aapl/news...
# 2018-09-22 15:08:00  https://api.iextrading.com/1.0/stock/aapl/news...
#
#                                                                related  \
# datetime
# 2018-09-22 17:56:09  AAPL,AMZN,CON102,NASDAQ01,RET10217,SPECRTIL,WO...
# 2018-09-22 15:08:00               AAPL,BOX,CRM,FB,GOOGL,MSFT,TWTR,YELP
#
#                            source  \
# datetime
# 2018-09-22 17:56:09  SeekingAlpha
# 2018-09-22 15:08:00          CNBC
#
#                                                                summary  \
# datetime
# 2018-09-22 17:56:09     In  my last post , I looked at Apple (AAPL)...
# 2018-09-22 15:08:00                              No summary available.
#
#                                                                    url
# datetime
# 2018-09-22 17:56:09  https://api.iextrading.com/1.0/stock/aapl/arti...
# 2018-09-22 15:08:00  https://api.iextrading.com/1.0/stock/aapl/arti...

# %%
pyEX.marketNewsDF(count=10)
# Out:
#                                                               headline  \
# datetime
# 2018-09-23 07:00:08  On This Day: Hurricane Rita evacuees die in bu...
# 2018-09-23 07:00:07                                        The Almanac
# 2018-09-23 06:00:00  Give Your Skin the Love and Attention It Deser...
# 2018-09-23 01:22:14  DHS rule would deny visas, green cards to immi...
#
#                                                                  image  \
# datetime
# 2018-09-23 07:00:08  https://api.iextrading.com/1.0/stock/market/ne...
# 2018-09-23 07:00:07  https://api.iextrading.com/1.0/stock/market/ne...
# 2018-09-23 06:00:00  https://api.iextrading.com/1.0/stock/market/ne...
# 2018-09-23 01:22:14  https://api.iextrading.com/1.0/stock/market/ne...
#
#                                                                related  \
# datetime
# 2018-09-23 07:00:08  ARGENTIN,CALIFORN,ENGLAND1,Europe,FINLAND1,HEL...
# 2018-09-23 07:00:07  ARGENTIN,CALIFORN,ENGLAND1,Entertainment,Europ...
# 2018-09-23 06:00:00  Consumer Goods,Consumer Affairs,Pharmaceutical...
# 2018-09-23 01:22:14  Broadcasting - TV,Federal,HOMELAND,LEGALLAW,Na...
#
#                           source  \
# datetime
# 2018-09-23 07:00:08          UPI
# 2018-09-23 07:00:07          UPI
# 2018-09-23 06:00:00  PR Newswire
# 2018-09-23 01:22:14          UPI
#
#                                                                summary  \
# datetime
# 2018-09-23 07:00:08     Sept. 23 (UPI) --   On this date in history...
# 2018-09-23 07:00:07       Today is Sunday Sept. 23, the 266th day o...
# 2018-09-23 06:00:00         New-generation nutraceutical protects a...
# 2018-09-23 01:22:14     Sept. 22 (UPI) --   The Trump administratio...
#
#                                                                    url
# datetime
# 2018-09-23 07:00:08  https://api.iextrading.com/1.0/stock/market/ar...
# 2018-09-23 07:00:07  https://api.iextrading.com/1.0/stock/market/ar...
# 2018-09-23 06:00:00  https://api.iextrading.com/1.0/stock/market/ar...
# 2018-09-23 01:22:14  https://api.iextrading.com/1.0/stock/market/ar...

# %%
pyEX.ohlcDF(symbol)
# Out:
#    close.price              close.time    high     low  open.price  \
# 0       217.66 2018-09-21 20:00:00.016  221.36  217.29         221
#
#        open.time
# 0  1537536600368

# %%
pyEX.marketOhlcDF().head()
# Out:
#        close  high   low  open
# symbol
# AMOV    None  None  None  None
# CBB-B   None  None  None  None
# CCM     None  None  None  None
# CMS-B   None  None  None  None
# GBAB    None  None  None  None

# %%
pyEX.peersDF(symbol)
# Out:
#        symbol
# symbol
# MSFT     MSFT
# NOK       NOK
# IBM       IBM
# HPQ       HPQ
# GOOGL   GOOGL
# BB         BB
# XLK       XLK

# %%
pyEX.yesterdayDF(symbol)
# Out:
#         change  changePercent   close       date    high     low    open  \
# symbol
# AAPL     -2.37         -1.077  217.66 2018-09-21  221.36  217.29  220.78
#
#         unadjustedVolume    volume      vwap
# symbol
# AAPL            96246748  96246748  218.4944

# %%
pyEX.marketYesterdayDF().head()
# Out:
#         change  changePercent  close       date   high      low   open  \
# symbol
# AAWW     -1.20         -1.859  63.35 2018-09-21  64.85  63.3000  64.75
# AAV       0.00          0.000   2.50 2018-09-21   2.55   2.4500   2.50
# AAXJ      0.32          0.451  71.27 2018-09-21  71.42  71.1000  71.20
# AA        0.86          2.003  43.79 2018-09-21  44.00  42.9200  43.36
# AAOI     -0.15         -0.456  32.72 2018-09-21  33.09  32.4971  32.85
#
#         unadjustedVolume   volume     vwap
# symbol
# AAWW              373273   373273  63.8534
# AAV                64411    64411   2.5118
# AAXJ             1137312  1137312  71.2675
# AA               4939859  4939859  43.6804
# AAOI              841285   841285  32.7602

# %%
pyEX.priceDF(symbol)
# Out:
#     price
# 0  217.66

# %%
pyEX.quoteDF(symbol)
# Out:
#         avgTotalVolume calculationPrice  change  changePercent   close  \
# symbol
# AAPL          32970994            close   -2.37       -0.01077  217.66
#
#                      closeTime companyName  delayedPrice  \
# symbol
# AAPL   2018-09-21 20:00:00.016  Apple Inc.        217.66
#
#               delayedPriceTime  extendedChange    ...         marketCap  open  \
# symbol                                            ...
# AAPL   2018-09-21 20:00:00.208            0.06    ...     1051281693160   221
#
#                       openTime  peRatio previousClose       primaryExchange  \
# symbol
# AAPL   2018-09-21 13:30:00.368    21.01        220.03  Nasdaq Global Select
#
#             sector week52High week52Low ytdChange
# symbol
# AAPL    Technology     229.67    149.16  0.267296
#
# [1 rows x 39 columns]

# %%
pyEX.relevantDF(symbol)
# Out:
#    peers symbols
# 0   True    MSFT
# 1   True     NOK
# 2   True     IBM
# 3   True     HPQ
# 4   True   GOOGL
# 5   True      BB
# 6   True     XLK

# %%
pyEX.sectorPerformanceDF()
# Out:
#                                    lastUpdated  performance    type
# name
# Energy                 2018-09-21 20:00:00.405      0.00661  sector
# Industrials            2018-09-21 20:00:00.377      0.00646  sector
# Utilities              2018-09-21 20:00:00.386      0.00426  sector
# Consumer Staples       2018-09-21 20:00:00.405      0.00161  sector
# Health Care            2018-09-21 20:00:00.382      0.00135  sector
# Real Estate            2018-09-21 20:00:00.338      0.00000  sector
# Materials              2018-09-21 20:00:00.358     -0.00216  sector
# Financials             2018-09-21 20:00:00.486     -0.00390  sector
# Technology             2018-09-21 20:00:00.457     -0.00395  sector
# Consumer Discretionary 2018-09-21 20:00:00.363     -0.00442  sector
# Communication Services 2018-09-21 20:00:00.332     -0.00448  sector

# %%
pyEX.splitsDF(symbol, timeframe='5y')
# Out:
#            declaredDate  forFactor paymentDate     ratio recordDate  toFactor
# exDate
# 2014-06-09   2014-04-23          1  2014-06-06  0.142857 2014-06-02         7

# %%
pyEX.volumeByVenueDF(symbol)
# Out:
#        avgMarketPercent date  marketPercent      venueName  volume
# venue
# XASE           0.001302  NaT              0  NYSE American       0
# XCIS           0.002669  NaT              0  NYSE National       0
# XPHL           0.007412  NaT              0     Nasdaq PSX       0
# XNYS           0.007463  NaT              0           NYSE       0
# BATY           0.008453  NaT              0       Cboe BYX       0
# EDGA           0.008651  NaT              0      Cboe EDGA       0
# XCHI           0.011142  NaT              0            CHX       0
# XBOS           0.012764  NaT              0      Nasdaq BX       0
# IEXG           0.025582  NaT              0            IEX       0
# EDGX           0.053745  NaT              0      Cboe EDGX       0
# BATS           0.080959  NaT              0       Cboe BZX       0
# ARCX           0.098964  NaT              0      NYSE Arca       0
# XNGS           0.278684  NaT              0         Nasdaq       0
# TRF            0.402209  NaT              0   Off Exchange       0

# %%
pyEX.symbolsDF()
# Out:
#                date     iexId  isEnabled  \
# symbol
# A        2018-09-21         2       True
# AA       2018-09-21     12042       True
# AAAU     2018-09-21     14924       True
# AABA     2018-09-21      7653       True
# AAC      2018-09-21      9169       True
# AADR     2018-09-21         5       True
# AAL      2018-09-21      8148       True
# AAMC     2018-09-21      7760       True
# AAME     2018-09-21         7       True
# AAN      2018-09-21         8       True
# AAOI     2018-09-21      7790       True
# AAON     2018-09-21         9       True
# AAP      2018-09-21        10       True
# AAPL     2018-09-21        11       True
# AAT      2018-09-21        12       True
# AAU      2018-09-21        13       True
# AAV      2018-09-21        14       True
# AAWW     2018-09-21        15       True
# AAXJ     2018-09-21        16       True
# AAXN     2018-09-21      6667       True
# AB       2018-09-21        17       True
# ABAC     2018-09-21      5129       True
# ABB      2018-09-21        19       True
# ABBV     2018-09-21        20       True
# ABC      2018-09-21        21       True
# ABCB     2018-09-21        22       True
# ABCD     2018-09-21        23       True
# ABDC     2018-09-21      8607       True
# ABEO     2018-09-21      9600       True
# ABEOW    2018-09-21      9607       True
# ...             ...       ...        ...
# ZTR      2018-09-21      7707       True
# ZTS      2018-09-21      7708       True
# ZUMZ     2018-09-21      7709       True
# ZUO      2018-09-21     14265       True
# ZVV      2018-09-21      7907       True
# ZVVV     2018-09-21      7908       True
# ZVZZT    2018-09-21      7909       True
# ZWZZT    2018-09-21      7910       True
# ZXIET    2018-09-21     13391       True
# ZXZZT    2018-09-21      7911       True
# ZYME     2018-09-21     12759       True
# ZYNE     2018-09-21     10257       True
# BTCUSDT  2018-09-21  10000000       True
# EOSUSDT  2018-09-21  10000001       True
# ETHUSDT  2018-09-21  10000002       True
# BNBUSDT  2018-09-21  10000003       True
# ONTUSDT  2018-09-21  10000004       True
# BCCUSDT  2018-09-21  10000005       True
# ADAUSDT  2018-09-21  10000006       True
# XRPUSDT  2018-09-21  10000007       True
# TUSDUSDT 2018-09-21  10000008       True
# TRXUSDT  2018-09-21  10000009       True
# LTCUSDT  2018-09-21  10000010       True
# ETCUSDT  2018-09-21  10000011       True
# IOTAUSDT 2018-09-21  10000012       True
# ICXUSDT  2018-09-21  10000013       True
# NEOUSDT  2018-09-21  10000014       True
# VENUSDT  2018-09-21  10000015       True
# XLMUSDT  2018-09-21  10000016       True
# QTUMUSDT 2018-09-21  10000017       True
#
#                                                        name    type
# symbol
# A                                 Agilent Technologies Inc.      cs
# AA                                        Alcoa Corporation      cs
# AAAU                               Perth Mint Physical Gold     N/A
# AABA                                            Altaba Inc.      cs
# AAC                                       AAC Holdings Inc.      cs
# AADR                        AdvisorShares Dorsey Wright ADR      et
# AAL                            American Airlines Group Inc.      cs
# AAMC                   Altisource Asset Management Corp Com      cs
# AAME                          Atlantic American Corporation      cs
# AAN                                            Aaron's Inc.      cs
# AAOI                           Applied Optoelectronics Inc.      cs
# AAON                                              AAON Inc.      cs
# AAP                              Advance Auto Parts Inc W/I      cs
# AAPL                                             Apple Inc.      cs
# AAT                              American Assets Trust Inc.      cs
# AAU                                   Almaden Minerals Ltd.      cs
# AAV                                 Advantage Oil & Gas Ltd      cs
# AAWW                           Atlas Air Worldwide Holdings      cs
# AAXJ      iShares MSCI All Country Asia ex Japan Index Fund      et
# AAXN                                   Axon Enterprise Inc.      cs
# AB                     AllianceBernstein Holding L.P. Units      cs
# ABAC                               Renmin Tianli Group Inc.      cs
# ABB                                                 ABB Ltd      cs
# ABBV                                            AbbVie Inc.      cs
# ABC                           AmerisourceBergen Corporation      cs
# ABCB                                         Ameris Bancorp      cs
# ABCD                            Cambium Learning Group Inc.      cs
# ABDC                                 Alcentra Capital Corp.      cs
# ABEO                               Abeona Therapeutics Inc.      cs
# ABEOW                                                           N/A
# ...                                                     ...     ...
# ZTR               Virtus Global Dividend & Income Fund Inc.      cs
# ZTS                                     Zoetis Inc. Class A      cs
# ZUMZ                                            Zumiez Inc.      cs
# ZUO                                      Zuora Inc. Class A      cs
# ZVV                                                             N/A
# ZVVV                                                            N/A
# ZVZZT                                     NASDAQ TEST STOCK     N/A
# ZWZZT                                     NASDAQ TEST STOCK     N/A
# ZXIET                                    ZXIET Test Company     N/A
# ZXZZT                                     NASDAQ TEST STOCK     N/A
# ZYME                                         Zymeworks Inc.      cs
# ZYNE                           Zynerba Pharmaceuticals Inc.      cs
# BTCUSDT                                         Bitcoin USD  crypto
# EOSUSDT                                             EOS USD  crypto
# ETHUSDT                                        Ethereum USD  crypto
# BNBUSDT                                    Binance Coin USD  crypto
# ONTUSDT                                        Ontology USD  crypto
# BCCUSDT                                    Bitcoin Cash USD  crypto
# ADAUSDT                                         Cardano USD  crypto
# XRPUSDT                                          Ripple USD  crypto
# TUSDUSDT                                            TrueUSD  crypto
# TRXUSDT                                            TRON USD  crypto
# LTCUSDT                                        Litecoin USD  crypto
# ETCUSDT                                Ethereum Classic USD  crypto
# IOTAUSDT                                          MIOTA USD  crypto
# ICXUSDT                                            ICON USD  crypto
# NEOUSDT                                             NEO USD  crypto
# VENUSDT                                         VeChain USD  crypto
# XLMUSDT                                  Stellar Lumens USD  crypto
# QTUMUSDT                                           Qtum USD  crypto
#
# [8700 rows x 5 columns]

# %%
pyEX.corporateActionsDF(date=None)
# Out:
#    CurrentCompanyName CurrentFinancialStatus CurrentLULDTierIndicator  \
# 0  ZIEXT Test Company                      0                        2
# 1  ZXIET Test Company                      0                        1
#
#   CurrentListingCenter CurrentRoundLotSize CurrentSecurityName  \
# 0                                      100  ZIEXT Common Stock
# 1                    V                 100  ZXIET Common Stock
#
#   CurrentSymbolinCMSSymbology CurrentSymbolinCQSSymbology  \
# 0                       ZIEXT                       ZIEXT
# 1                       ZXIET                       ZXIET
#
#   CurrentSymbolinINETSymbology  DailyListTimestamp      ...        \
# 0                        ZIEXT 2018-09-23 11:00:00      ...
# 1                        ZXIET 2018-09-23 11:00:00      ...
#
#   NewSymbolinCQSSymbology NewSymbolinINETSymbology  \
# 0
# 1
#
#                                    NotesforEachEntry             RecordID  \
# 0  ZIEXT Test Company is changing its name to ZIE...  CA20180921130304483
# 1  ZXIET Test Company is changing its name to ZXI...  CA20180921125550003
#
#      RecordUpdateTime RedemptionDate SeparationDate SettlementDate  \
# 0 2018-09-21 13:53:18              0              0              0
# 1 2018-09-21 13:53:31              0              0              0
#
#   WhenDistributedFlag WhenIssuedFlag
# 0                   N              N
# 1                   N              N
#
# [2 rows x 34 columns]

# %%
pyEX.dividendsDF(symbol)
# Out:
#             amount declaredDate flag indicated paymentDate qualified  \
# exDate
# 2018-02-09    0.63   2018-02-01                 2018-02-15         Q
#
#            recordDate             type
# exDate
# 2018-02-09 2018-02-12  Dividend income

# %%
pyEX.nextDayExtDateDF(date=None)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.directoryDF(date=None)
# Out:
#   AdjustedPreviousOfficialClosingPrice              CompanyName  \
# 0                             100.0000       ZXIET Test Company
# 1                               2.0000       ZIEXT Test Company
# 2                              10.0000  ZEXIT Test Incorporated
#
#   CountryofIncorporation  DailyListTimestamp FinancialStatus FirstDateListed  \
# 0                    USA 2018-09-23 11:00:00               0      2017-09-15
# 1                    USA 2018-09-23 11:00:00               0      2017-09-15
# 2                    USA 2018-09-23 11:00:00               0      2018-09-18
#
#   IPOFlag InverseETPFlag IssueDescription IssueSubType      ...       SICCode  \
# 0       N              N     Common Stock            C      ...          2345
# 1       N              N     Common Stock            C      ...          1234
# 2                      N     Common Stock            C      ...          5678
#
#                   SecurityName  Status SymbolinCMSSymbology  \
# 0  IEX Test Common Stock ZXIET  Active                ZXIET
# 1  IEX Test Common Stock ZIEXT  Active                ZIEXT
# 2  IEX Test Common Stock ZEXIT  Active                ZEXIT
#
#   SymbolinCQSSymbology SymbolinINETSymbology TestIssue  \
# 0                ZXIET                 ZXIET         Y
# 1                ZIEXT                 ZIEXT         Y
# 2                ZEXIT                 ZEXIT         Y
#
#                        TransferAgent WhenDistributedFlag WhenIssuedFlag
# 0                                                      N              N
# 1                                                      N              N
# 2  Computershare Trust Company, N.A.                                  N
#
# [3 rows x 28 columns]

# %%
pyEX.topsDF(symbols=None).head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.lastDF(symbols=None).head()
# Out:
#         price  size                    time
# symbol
# BNS     60.40    50 2018-09-21 19:59:33.020
# ACET     3.02   107 2018-09-21 19:57:28.323
# SPPP     8.71   100 2018-09-21 15:22:00.895
# HMTV    13.75   100 2018-09-21 19:51:39.578
# IDX     21.06    41 2018-09-21 19:55:01.102

# %%
pyEX.histDF(date=None).head()
# Out:
#             feed                                               link protocol  \
# date
# 2016-12-12  TOPS  https://www.googleapis.com/download/storage/v1...   IEXTP1
# 2016-12-13  TOPS  https://www.googleapis.com/download/storage/v1...   IEXTP1
# 2016-12-14  TOPS  https://www.googleapis.com/download/storage/v1...   IEXTP1
# 2016-12-15  TOPS  https://www.googleapis.com/download/storage/v1...   IEXTP1
# 2016-12-16  TOPS  https://www.googleapis.com/download/storage/v1...   IEXTP1
#
#                  size version
# date
# 2016-12-12  672322139     1.5
# 2016-12-13  688995088     1.5
# 2016-12-14  875045142     1.5
# 2016-12-15  361647108     1.5
# 2016-12-16  672176197     1.5

# %%
pyEX.deepDF(symbol=None).head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
pyEX.topsBookDF(symbol).head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.tradesDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.systemEventDF()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
pyEX.tradingStatusDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.opHaltStatusDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.ssrStatusDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.securityEventDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pyEX.tradeBreakDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
pyEX.auctionDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
pyEX.officialPriceDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
pyEX.statsDF()
# Out:
#                     volume  symbolsTraded   routedVolume       notional  \
# lastUpdated  1537564517639  1537563572875  1537564517639  1537564517639
# value            204173663           5830       37960835    10331464780
#
#               marketShare
# lastUpdated  1.537565e+12
# value        1.875000e-02

# %%
pyEX.recentDF()
# Out:
#             isHalfday  litVolume  marketShare  routedVolume     volume
# date
# 2018-09-20      False   52985357      0.02765      37779893  193314389
# 2018-09-19      False   48981536      0.02725      30337529  180236223
# 2018-09-18      False   50692486      0.02838      33595912  183543217
# 2018-09-17      False   41640527      0.02392      28825712  151403510
# 2018-09-14      False   42572521      0.02507      32995246  158668864
# 2018-09-13      False   43972291      0.02507      37414534  170854520
# 2018-09-12      False   46640382      0.02528      32154569  181265976
# 2018-09-11      False   40960616      0.02615      30822109  167081911
# 2018-09-10      False   38486911      0.02668      27110550  152419730
# 2018-09-07      False   42165971      0.02627      34243128  165553626
# 2018-09-06      False   47156378      0.02606      38340753  175143688
# 2018-09-05      False   51634758      0.02534      39624479  179977524
# 2018-09-04      False   47838080      0.02636      31202403  174720320

# %%
pyEX.recordsDF()
# Out:
#                        volume symbolsTraded routedVolume     notional
# avg30Value        1.59721e+08          5675     31143369  8.38054e+09
# previousDayValue    193314389          5843     37779893  9.81861e+09
# recordDate         2018-02-09    2018-02-06   2016-11-10   2018-02-06
# recordValue         286354807          6381     74855222  1.72697e+10

# %%
pyEX.summaryDF(date=None)
# Out:
#    averageDailyRoutedVolume  averageDailyVolume  averageFillSize  \
# 0               51255879.55         154349743.9              196
#
#    averageMarketShare  averageOrderSize  bin10000Percent  bin10000Trades  \
# 0             0.02503               638          0.00099            5156
#
#    bin1000Percent  bin100Percent  bin101Percent            ...             \
# 0         0.02367        0.73508         0.0154            ...
#
#    venueXCHIFirstWaveRate  venueXCHIFirstWaveWeight  venueXCISFirstWaveRate  \
# 0                 0.82406                   0.00134                 0.92786
#
#    venueXCISFirstWaveWeight  venueXNGSFirstWaveRate  venueXNGSFirstWaveWeight  \
# 0                   0.00512                 0.98878                   0.22151
#
#    venueXNYSFirstWaveRate  venueXNYSFirstWaveWeight  venueXPHLFirstWaveRate  \
# 0                 0.98639                   0.20362                 0.96635
#
#    venueXPHLFirstWaveWeight
# 0                   0.00843
#
# [1 rows x 50 columns]

# %%
pyEX.dailyDF(date=None, last='')
# Out:
#         date  isHalfday  litVolume  marketShare  routedVolume     volume
# 0 2018-09-20          0   52985357      0.02765      37779893  193314389

# %%
pyEX.marketsDF()
# Out:
#                lastUpdated  marketPercent   mic       tapeA      tapeB  \
# 0  2018-09-21 21:15:16.837        0.31000   TRF  1542170640  563488723
# 1  2018-09-21 20:45:00.043        0.24960  XNYS  2660310528   27442112
# 2  2018-09-21 21:15:13.895        0.19998  XNGS   361605467  166079429
# 3  2018-09-21 21:15:15.339        0.06013  ARCX   185057631  289587309
# 4  2018-09-21 21:15:10.733        0.04186  BATS   215366817  104401565
# 5  2018-09-21 21:15:17.374        0.03379  EDGX   138705375   84112812
# 6  2018-09-21 21:09:44.109        0.03344  BATY   182909256   85233497
# 7  2018-09-21 21:14:47.502        0.01892  XBOS   107492202   34556469
# 8  2018-09-21 20:59:32.875        0.01875  IEXG   115924288   21319472
# 9  2018-09-21 21:15:11.226        0.00843  XASE     6687557   80402287
# 10 2018-09-21 21:14:36.133        0.00842  EDGA    40614052   25465730
# 11 2018-09-21 21:14:49.203        0.00691  XCIS    37207138   19878785
# 12 2018-09-21 20:31:18.024        0.00535  XCHI    26655580   18922072
# 13 2018-09-21 20:59:00.646        0.00443  XPHL    17079196   16864796
#
#          tapeC tapeId      venueName      volume
# 0   1270352470            TRF Volume  3376011833
# 1     30473688      N           NYSE  2718226328
# 2   1650196148      Q         NASDAQ  2177881044
# 3    180230368      P      NYSE Arca   654875308
# 4    136064936      Z       BATS BZX   455833318
# 5    145144870      K           EDGX   367963057
# 6     95995641      Y       BATS BYX   364138394
# 7     64023814      B      NASDAQ BX   206072485
# 8     66929903      V            IEX   204173663
# 9      4694377      A  NYSE American    91784221
# 10    25584392      J           EDGA    91664174
# 11    18196378      C  NYSE National    75282301
# 12    12654110      M            CHX    58231762
# 13    14289809      X     NASDAQ PSX    48233801
